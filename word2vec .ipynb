# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk # natural language tool kit
import contractions
import string
import re

# %%
initialFrame = pd.read_csv('train.tsv', delimiter = '\t')

# %%
# Cleans the initial frame
def cleanInitialFrame(df):
    cleanList = [] # list to grow
    currentSentence = 0 # tracks current sentence
    sentenceIDs = {0} 
    # Iterate row by row
    for index, row in df.iterrows():
        # If it's the first element, add to list
        if (row['SentenceId'] == currentSentence):
            continue
        else:
            cleanList.append([row['PhraseId'], row['SentenceId'], row['Phrase'], row['Sentiment']]);
            currentSentence = row['SentenceId']
    
    # Return a clean frame
    return pd.DataFrame(cleanList, columns = ['PhraseId', 'SentenceId', 'Phrase', 'Sentiment'])

def lowerAllPhrases(df):
    phrases_list = list(df['Phrase'])

    for i in range(len(phrases_list)):
        phrases_list[i] = phrases_list[i].lower()
    count = 0;
    for index, row in df.iterrows():
        df.at[index,'Phrase'] = phrases_list[count]
        count += 1
    return df

# Remove non-ascii characters using str.replace()
def asciiClean(df):
    # iterate row by row
    for index, row in df.iterrows():
        old_str = row['Phrase']
        new_str = (old_str.encode('ascii','ignore')).decode()
        df.at[index, 'Phrase'] = new_str

def removeSpaces(df):
    for index, row in df.iterrows():
        df.at[index,'Phrase'] = re.sub(r'\s+\'', "'", row['Phrase'])
        
contractions.add('n\'t', 'not')
def expandContractions(df):
    for index, row in df.iterrows():
        phrase = []
        for i in row['Phrase'].split():
            phrase.append(contractions.fix(i))
        string_version = ' '.join(phrase)
        df.at[index, 'Phrase'] = string_version
        
def removePunctuation(df):
    regex = re.compile('[%s]' % re.escape(string.punctuation))
    for index,row in df.iterrows():
        phrase = []
        for i in row['Phrase'].split():
            phrase.append(regex.sub('', i))
        string_version = ' '.join(phrase)
        df.at[index, 'Phrase'] = string_version

# %%
initialFrame = cleanInitialFrame(initialFrame)
initialFrame = lowerAllPhrases(initialFrame)
asciiClean(initialFrame)
removeSpaces(initialFrame)
expandContractions(initialFrame)
removePunctuation(initialFrame)

# %%
initialFrame
# Out:
#       PhraseId  SentenceId                                             Phrase  \
# 0            1           1  a series of escapades demonstrating the adage ...
# 1           64           2  this quiet  introspective and entertaining ind...
# 2           82           3  even fans of ismail merchants work  i suspect ...
# 3          117           4  a positively thrilling combination of ethnogra...
# 4          157           5  aggressive selfglorification and a manipulativ...
# ...        ...         ...                                                ...
# 8524    155985        8540   either you are willing to go with this claust...
# 8525    155998        8541  despite these annoyances  the capable clayburg...
# 8526    156022        8542  lrb tries rrb to parody a genre that is alread...
# 8527    156032        8543  the movies downfall is to substitute plot for ...
# 8528    156040        8544  the film is darkly atmospheric  with herrmann ...
#
#       Sentiment
# 0             1
# 1             4
# 2             1
# 3             3
# 4             1
# ...         ...
# 8524          2
# 8525          2
# 8526          1
# 8527          1
# 8528          2
#
# [8529 rows x 4 columns]

# %%
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\andyv\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\andyv\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def removeStopWords(df):
    
    phrases_list = list(df['Phrase'])
    stop_words = set(stopwords.words('english'))

    for i in range(len(phrases_list)):
        word_tokens = word_tokenize(phrases_list[i])
        filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
        filtered_sentence = []
        for w in word_tokens:
            if w not in stop_words:
                filtered_sentence.append(w)
        phrases_list[i] = filtered_sentence
    
    for i in range(len(phrases_list)):
        phrases_list[i] = TreebankWordDetokenizer().detokenize(phrases_list[i])
    
    count = 0
    for index, row in df.iterrows():
        # df['Phrase'] = df['Phrase'].replace([row['Phrase']], phrases_list[count])
        df.at[index, 'Phrase'] = phrases_list[count]
        count += 1
    return df

# %%
initialFrame = removeStopWords(initialFrame)

# %%
def makeCorpus(df):
    corpus = []
    for index, row in df.iterrows():
        phrase = row.Phrase
        corpus.append(phrase)
    return corpus

# %%
corpus = makeCorpus(initialFrame)

# %%
corpus
# Out:
# ['series escapades demonstrating adage good goose also good gander occasionally amuses none amounts much story',
#  'quiet introspective entertaining independent worth seeking',
#  'even fans ismail merchants work suspect would hard time sitting one',
#  'positively thrilling combination ethnography intrigue betrayal deceit murder shakespearean tragedy juicy soap opera',
#  'aggressive selfglorification manipulative whitewash',
#  'comedydrama nearly epic proportions rooted sincere performance title character undergoing midlife crisis',
#  'narratively trouble every day plodding mess',
#  'importance earnest thick wit plays like reading bartletts familiar quotations',
#  'leave much',
#  'could hate reason',
#  'little recommend snow dogs unless one considers cliched dialogue perverse escapism source high hilarity',
#  'kung pow oedekerks realization childhood dream martialarts flick proves sometimes dreams youth remain',
#  'performances absolute joy',
#  'fresnadillo something serious say ways extravagant chance distort perspective throw us path good sense',
#  'still like moonlight mile better judgment damned',
#  'welcome relief baseball movies try hard mythic one sweet modest ultimately winning story',
#  'bilingual charmer like woman inspired',
#  'like less dizzily gorgeous companion mr wongs mood love much hong kong movie despite mainland setting',
#  'inept bigscreen remakes avengers wild wild west',
#  'everything would expect nothing',
#  'best indie year far',
#  'hatfield hicks make oddest couples sense movie becomes study gambles publishing world offering case study exists apart movies political ramifications',
#  'like going house party watching host defend frothing exgirlfriend',
#  'chuck norris grenade gag occurs 7 times windtalkers good indication seriousminded film',
#  'plot romantic comedy boilerplate start finish',
#  'arrives impeccable pedigree mongrel pep almost indecipherable plot complications',
#  'film clearly means preach exclusively converted',
#  'importance earnest offers opportunities occasional smiles chuckles give us reason theater beyond wildes wit actors performances',
#  'latest vapid actors exercise appropriate structure arthur schnitzlers reigen',
#  'vaudeville show wellconstructed narrative terms inoffensive actually rather sweet',
#  'nothing runofthemill action flick',
#  'hampered paralyzed selfindulgent script aims poetry ends sounding like satire',
#  'ice age first computergenerated feature cartoon feel like movies makes glacial pacing early',
#  'little sense going makers serve cliches considerable dash',
#  'cattaneo followed runaway success first film full monty something different',
#  'unnamed easily substitutable forces serve whatever terror heroes horror movies try avoid',
#  'almost feels movie interested entertaining amusing us',
#  'movies progression rambling incoherence gives new meaning phrase fatal script error',
#  'judge one soon dark gritty story takes totally unexpected directions keeps going',
#  'could young romantics date',
#  'tartakovskys team freakish powers visual charm five writers slip modern rut narrative banality',
#  'vincent gallo right home french shocker playing usual bad boy weirdo role',
#  'horror movies primary goal frighten disturb works spectacularly well shiverinducing nerverattling ride',
#  '100minute movie 25 minutes decent material',
#  'fortunately still option',
#  'less sensational truecrime helljaunt purists might like experimental storytelling lrb though less horrifying rrb',
#  'tricky satisfying david mamets airless cinematic games',
#  'sure filmmaker would disagree honestly see point',
#  'jones tackled meaty subject drawn engaging characters peppering pages memorable zingers',
#  'bloody sunday grace call prevention rather place blame making one best war movies ever made',
#  'takes clunky tvmovie approach detailing chapter life celebrated irish playwright poet drinker',
#  'finally coming miramaxs deep shelves couple aborted attempts waking reno makes strong case letting sleeping dogs lie',
#  'thanks largely williams interesting developments processed 60 minutes rest overexposed waste film',
#  'comes across relic bygone era convolutions feel silly rather plausible',
#  'perhaps cliche call film refreshing',
#  'lead performances oscarsize',
#  'run lives',
#  'mark pellingtons latest pop thriller kooky overeager spooky subtly love myth',
#  'claude chabrols camera way gently swaying back forth cradles characters veiling tension beneath otherwise tender movements',
#  'transforms one lrb shakespeares rrb deepest tragedies smart new comedy',
#  'screenplay james eric james horton director peter ofallon pat makes teeth hurt',
#  'arriving particularly dark moment history offers flickering reminders ties bind us',
#  'generic villains lack intrigue lrb funny accents rrb action scenes poorly delivered',
#  'characters deeply thought rightthinking films',
#  'film despite gratuitous cinematic distractions impressed upon still good fun',
#  'downright transparent scripts endless assault embarrassingly hamfisted sex jokes reek script rewrite designed garner film cooler pg13 rating',
#  'smart provocative drama nearly impossible gets skin man know evil monstrous lunatic',
#  'like driveby',
#  'many things stoner midnight flick scifi deconstruction gay fantasia love story sanguine title',
#  'funny romantic comedy two skittish new york middleagers stumble relationship struggle furiously fears foibles',
#  'ambition say something subjects willingness',
#  'lrb scherfig rrb made movie leave wondering characters lives clever credits roll',
#  'lrb rrb absorbing documentary',
#  'reeks rot hack work start finish',
#  'plays like series vignettes clips film still looking common throughline',
#  '',
#  'major problem windtalkers bulk movie centers wrong character',
#  'swimfan like fatal attraction eventually goes overboard loony melodramatic denouement high school swimming pool substitutes bathtub',
#  'heartfelt story involving one',
#  'unsettling memorable cinematic experience predecessors proud',
#  'pretty good execution story lot richer ones hollywood action screenwriters usually come',
#  'phillip noyce actors well cinematographer christopher doyle understand delicate forcefulness greenes prose screen version quiet american',
#  'pianist lacks quick emotional connections steven spielbergs schindlers list',
#  'inventive fun intoxicatingly sexy violent selfindulgent maddening',
#  'tells fascinating compelling story',
#  'written flatly david kendall directed barely something mary cowriter ed decter',
#  'highly recommended viewing courage ideas technical proficiency great acting',
#  'imax short wonderful big screen',
#  'shows us slice life different yet instantly recognizable',
#  'amid shock curiosity factors film corny examination young actress trying find way',
#  'lazy movie avoid solving one problem trying distract us solution another',
#  'comprehensible dummies guide something even nontechies enjoy',
#  'entertains much music comic antics perverse pleasure watching disney scrape bottom cracker barrel',
#  'writerdirector burr steers emphasizes q quirky mixed results',
#  'scarcely worth mention apart reporting number tumbleweeds blowing empty theatres graced company',
#  'invigorating surreal resonant rainbow emotion',
#  'analyze one crass contrived sequels fails makes secondguess affection original',
#  'report card live exalted tagline definite room improvement',
#  'particularly good film neither monsterous one',
#  'tsai may ploughing furrow often',
#  'lrb green rrb comedy equivalent saddam hussein ready go youn ask permission preemptive strike',
#  'surprisingly solid achievement director malcolm lee writer john ridley',
#  'massouds story epic also tragedy record tenacious humane fighter also prisoner lrb ultimately victim rrb history',
#  'changing lanes tries',
#  'shyamalan stop trying please mom',
#  'macabre stylized swedish fillm modern city religious civic virtues hold society place tatters',
#  'one recent memorys thoughtful films art ethics cost moral compromise',
#  'narrative consistently unimaginative probably way saved film aid wisecracking mystery science theater 3000 guys',
#  'filmmaker tian zhuangzhuang triumphantly returns narrative filmmaking visually masterful work quiet power',
#  'mawkish selfparody plays like weird masterpiece theater sketch neither point view compelling reason',
#  'takes one character like another believe puts battle wills impossible care funny',
#  'appreciate onesided theme lawrences overindulgent tirade knock enjoy big screen postcard selfglorified martin lawrence lovefest',
#  'whole film sneaky feel director trying dupe viewer taking important simply movie ugly look hollywood product',
#  'whenever threatens get bogged earnest dramaturgy stirring visual sequence like surge swirling rapids leap pinnacle pinnacle rouses us',
#  'swinging film makes seem hobby attracts young fit',
#  'entirely unprepared',
#  'devos delivers perfect performance captures innocence budding demons within wallflower',
#  '300 years russian history culture compressed evanescent seamless sumptuous stream consciousness',
#  'filmmakers want nothing else show us good time cheap b movie way succeed',
#  'mr polanski element alone abandoned still consoled art ever revealed source spiritual survival',
#  'spiderman better summer blockbuster endure last summer hopefully sets tone summer good stuff',
#  'absorbing character',
#  'violent vulgar forgettably entertaining',
#  'unsettling images warravaged land prove potent riveting unlikely story sarah harrison',
#  'winds revelatory narcissistic achieving honest insight relationships highconcept films candycoat pat storylines precious circumstances beautiful stars',
#  'mostly martha mostly unsurprising still sweet even delectable diversion',
#  'thoughtful surprisingly affecting portrait screwedup man dared mess powerful people seen eyes idealistic kid chooses champion ultimately losing',
#  'keenly observed refreshingly natural swimming gets details right promenade barely clad bodies myrtle beach sc adrenaline jolt sudden lunch rush diner',
#  'brilliant gag expense paid pay see',
#  'triumph film hews world carries us effortlessly darkness light',
#  'everyone involved seems coasting',
#  'fascinating dark thriller keeps hooked delicious pulpiness lurid fiction',
#  'suspect kind production would funnier director released outtakes theatrically used film bonus feature dvd',
#  'hard say might enjoy tolstoy groupies',
#  'daughter danang reveals efforts toward closure open new wounds',
#  'one years weirdly engaging unpredictable character pieces',
#  'intriguing downright intoxicating',
#  'although fairly involving far goes film end much fresh say growing catholic really anything',
#  'movie silly beyond comprehension even silly would still beyond comprehension',
#  'sleek arty',
#  'poor editing bad bluescreen ultracheesy dialogue highlight radical action',
#  'lrb chos face rrb amazing slapstick instrument creating scrapbook living mug shots',
#  'gets details time frame right completely misses emotions',
#  'initial strangeness inexorably gives way rote sentimentality mystical tenderness becomes narrative expedience',
#  'let us brush humanity psycho without making less psycho',
#  'like world film hartley created monster know handle',
#  'cowering begging feet scruffy giannini madonna gives best performance since abel ferrara beaten pulp dangerous game',
#  'clumsy key moments make big splash',
#  'eight legged freaks partly homage tarantula low budget bmovie thrillers 1950s and60s movie silly lrb sophomoric rrb romp horror hellish conditions',
#  'feels like light errol morris focusing eccentricity failing ultimately make something bigger scrapbook oddballs',
#  'spielbergs realization nearfuture america masterful',
#  'scientific law discerned producers would well heed mediocre movies start drag soon action speeds explosions start fall pieces',
#  'one cool actors never seems aware coolness',
#  'feels like work artist simply tired fighting fights putting weight world shoulders playing narrative form',
#  'stale uninspired',
#  'directors cut film love song movies also fully example kind lush allenveloping movie experience rhapsodizes',
#  'rare capability soothe break heart single stroke',
#  'eerily accurate depiction depression',
#  'featurelength film wears welcome tryingly title character',
#  'uncluttered resonant gem relays universal points without lectures confrontations',
#  'story alone could force scratch hole head',
#  'filmmakers postcamp comprehension made oldtime b movies goodbad makes eight legged freaks perfectly entertaining summer diversion',
#  'creaturefeature fan knows cross toxic chemicals bunch exotic creatures get lot running around screaming death',
#  'bet makes rather convoluted journey worth taking',
#  'takes sudden turn devolves bizarre sort romantic comedy steven shainbergs adaptation mary gaitskills harrowing short story brilliantly played deeply unsettling experience',
#  'kim kideok seems mind lrb emotionally least rrb adolescent audience demanding regular shocks bouts barely defensible sexual violence keep interested',
#  'reason exist employ hollywood kids people owe favors famous parents',
#  'wellmade emotionally scattered film whose hero gives heart dog',
#  'love cinema paradiso find new scenes interesting find movie improved',
#  'campanella gets tone right funny middle sad middle hopeful',
#  'nothing amiable unfocused bagatelle plays like looselyconnected string actingworkshop exercises',
#  'sharp movie otherwise dull subjects',
#  'wallace gets bit heavy handed message times visual flair waxes poetic far much taste',
#  'charming funny lrb ultimately silly rrb movie',
#  'one thing wild film imax films chimps lots chimps blown size house',
#  'starts mediocre spirals downward thuds bottom pool utterly incompetent conclusion',
#  'childrens film truest sense',
#  'horrendously amateurish filmmaking plainly dull visually ugly incomprehensible',
#  'beautifully crafted engaging filmmaking attract upscale audiences hungry quality nostalgic twisty yarn keep guessing',
#  'awkwardly contrived exercise magic realism',
#  'punch lines miss unfortunately outnumber hits threetoone',
#  'like smoke signals film also imbued strong themes familial ties spirituality powerful moving without stooping base melodrama',
#  'evokes style flash doublecross made mamets house games last falls heist much fun',
#  'film aims funny uplifting moving sometimes',
#  'brief 42 minutes need x less blab',
#  'spalding gray equivalent teen grossout comedy',
#  'great deal corny dialogue preposterous moments',
#  'uneven lot fun',
#  'result might look like vulgar',
#  'film rehashes several old themes capped pointless extremes insanely violent graphic',
#  'dragons real stars reign fire wo disappointed',
#  'never plays dramatic even dramatic things happen people',
#  'manages please intended audience children without placing parents comalike state',
#  'movie generates plot points degree randomness usually achieved lottery drawing',
#  'though film never veers comic course unintentional parallels might inadvertently evoke memories emotions anything humorous',
#  'film depress life',
#  'saw tv would probably turn convinced already seen movie',
#  'get impression writer director burr steers knows territory sense humor yet lose smug selfsatisfaction usually associated better private schools',
#  'superior horror flick',
#  'movies heavyhanded screenplay navigates fast fade pomposity pretentiousness',
#  'little weak funny',
#  'fit well together neither well told',
#  'latently gay liking read hardly enough',
#  'sophisticated literate pictures usually amusing little catch',
#  'storytelling feels slight',
#  'monte cristo smartly emphasizes wellwrought story omits needless chase scenes swordfights revenge unfolds',
#  'fairy tale comes renowned indian film culture allows americans finally revel splendor',
#  'welldone supernatural thriller keen insights parapsychological phenomena soulful nuances grieving process',
#  'bond save us latest eccentric superwealthy megalomaniac bent world domination destruction',
#  'depressing ruthlessly pained depraved movie equivalent staring open wound',
#  'damon brings proper conviction role lrb jason bourne rrb',
#  'parents beware downright movie penance',
#  'rich luscious cares',
#  'singularly offputting romantic comedy',
#  'director boris von sychowski instead opts routine slasher film probably fun make sit',
#  'would nice screenwriters trusted audiences understand complex story left films predictable denouement',
#  'superfluous sequel plagued old familiar feeling let us get thing everyone shown appointed time place visible enthusiasm mighty hard find',
#  'earnest roughshod document serves workable primer regions recent history would make terrific 10thgrade learning tool',
#  'cloaks familiar antifeminist equation lrb career kids misery rrb tiresome romanticcomedy duds',
#  'film plays things nicen safe often play like milquetoast movie week blown big screen',
#  'work transcends boymeetsgirl posturing typical love stories',
#  'even predictable clicheridden endeavor predecessor',
#  'plays like bad blend overripe episode tvs dawsons creek recycled dumbeddown version love story',
#  'script covers huge heavy topics bland surfacey way offer insight instance good things happen bad people',
#  'film bad improve upon experience staring blank screen',
#  'threw loads money idea much even made teenage boys wrestling fans',
#  'difficult imagine confused less interesting sloppily made film could possibly come road 2002',
#  'though film wellintentioned one could rent original get love story parable',
#  'jolting charleston rhythms story sizzle old news finally found right vent lrb accurate',
#  '',
#  'williams plays sy another openfaced smiling madmen like killer insomnia',
#  'phonedin business usual',
#  'lackadaisical plotting mindless action benjamins evokes bottom tier blaxploitation flicks 1970s',
#  'ah yes would fighting urge doze',
#  'thoughtless random superficial humour lot bad scouse accents',
#  'era big stars high production values standard procedure narc strikes defiantly retro chord outpaces contemporaries daring verve',
#  'riproaring comedy action fest put hairs chest',
#  'thoughtful whatif heart well mind',
#  'miyazaki one world cinemas wondrously gifted artists storytellers',
#  'chronicle one mans quest president man singlehandedly turned plane full hardbitten cynical journalists essentially campaigns end extended publicity department',
#  'provides kind laugh therapy need movie comedies offbeat humor amusing characters happy ending',
#  'feels strangely hollow emotional core',
#  'time commercialism squeezed life whatever idealism american moviemaking ever godfrey reggios career shines like lonely beacon',
#  'director roger michell many little things right difficult cuss severely bungling big stuff',
#  'robert harmons lessismore approach delivers real bumpin thenight chills greatest triumph keeping creepy crawlies hidden films thick shadows',
#  'movie may highest production values ever seen work artist one whose view america history awkwardness human life generous deep',
#  'feral uncomfortable',
#  'sillier cuter shorter first lrb best remember rrb still good time cinema',
#  'enjoyable expected though laughs come fairly basic comedic constructs',
#  'blackandwhite unrealistic',
#  'film predictable reassuring manner beautifully sung holiday carol',
#  'camouflage carvey considering paper bag wear head goes public avoid recognized man bilked unsuspecting moviegoers',
#  'scares mood ominous pervasive unknown threat lurks proceedings adds almost constant mindset suspense',
#  'computer animation handsome various amusing sidekicks add muchneeded levity otherwise bleak tale overall film never rises mediocrity',
#  'offers flash rock videos fused solid performances eerie atmosphere',
#  'breezy blend art history esoteric musings philosophy',
#  'former gong show addict admit complaint get recreations famous moments show',
#  'genuinely unnerving',
#  'increasingly diverse french director created film one honestly describe looking sounding simply feeling like film recent history',
#  'one joyous films leaps national boundaries celebrates universal human nature',
#  'difficult worthy film bites chew linking massacre armenians 1915 difficult relationships present',
#  'halfway movie humor dwindles',
#  'witty often surprising dark little morality tale disguised romantic comedy',
#  'one senses world traveler earlier film freundlich bears grievous obscure complaint fathers circles obsessively without making contact',
#  'fact even better',
#  'preachy parable stylized touch john woo bullet ballet',
#  'proves movie formulas need messing like bigbug movie',
#  'uplifting largely bogus story',
#  'thanks confident filmmaking pair fascinating performances way destination really special walk woods',
#  'superbly photographed staged mendes series riveting set pieces likes mainstream audiences rarely seen',
#  'mesmerizing cinematic poem first frame last',
#  'first 10 minutes worth seeing',
#  'become apparent franchises best years long past',
#  'screenwriter chris ver weils directing debut goodnatured never dull virtues small easily overshadowed predictability',
#  'much storytelling moves away solondzs social critique casting audience intellectual lector contemplation auteurs professional injuries',
#  'ultimately sarahs dedication finding husband seems psychotic romantic nothing movie makes convincing case one womans broken heart outweighs loss witness',
#  'jokes flat action looks fake',
#  'mildly enjoyable toothless adaptation much better book',
#  'festers dungpile would swear watching monkeys flinging feces',
#  'addition overcooked hamfisted direction actors reaching back row dialogue sounds like horrible poetry',
#  'vile incoherent mess scummy ripoff david cronenbergs brilliant videodrome',
#  'first movie tries smart kind dumb',
#  'sent copyof film review dvd',
#  'silly humbuggery',
#  'sharp original despite visual virtues blade ii cut',
#  'smart arch rather coldblooded comedy',
#  'lrb rrb rather thinlyconceived movie',
#  'flamelike roiling blackandwhite inspires trembling gratitude',
#  'robinsons web suspense matches pageturning frenzy clancy creates',
#  'slight sweet film',
#  'got david lynch jones',
#  'earnest tentative even aims shock',
#  'time favor could given audiences time day concentrating elements revealing alienation among culture people sadly hostile odds one another recklessness retaliation',
#  'austin powers goldmember right stuff silly summer entertainment enough laughs sustain interest end',
#  'puzzles lack emphasis music britney spears first movie',
#  'filmmakers might want look',
#  'maintaining appearance clinical objectivity sad occasionally horrifying often inspiring film among wisemans warmest',
#  'simply doubt film asks right questions right time history country',
#  'dreary movie',
#  'sadly though many actors throw spark two first appear ca generate enough heat cold vacuum comedy start reaction',
#  'filmmakers ivan prince fellow comes across shallow glib though meanspirited indication responsible putting together movies particular value merit',
#  'using stock plot boy injects enough freshness proceedings provide enjoyable 100 minutes movie theater',
#  'beating austin powers films game blaxploitation spoof downplays raunch favor gags rely strength cleverness opposed extent outrageousness',
#  'begins conventional thriller evolves gorgeously atmospheric meditation lifechanging chance encounters',
#  'buy popcorn',
#  'latenight cable sexploitation romp masquerading thriller ruthless social order governs college cliques',
#  'wellintentioned effort still burdened actors offbeat sensibilities earnest emotional core emerge degree accessibility',
#  'lrb allens rrb making piffle long hollywood ending may way saying piffle airhead movie business deserves right',
#  'seeing film lacks momentum position remains mostly undeterminable directors experiment successful one',
#  'judith zazas extended bedroom sequence intimate sensual funny psychologically selfrevealing makes passes sex movies look like cheap hysterics',
#  'uneven performances spotty script add biting satire teeth',
#  'irritating soulsearching garbage',
#  'solid spooky entertainment worthy price ticket',
#  'ultimately clarity matters breaking codes making movies',
#  'comparison earlier films seems disappointingly thin slice lowerclass london life despite title amounts surprisingly little',
#  'proves mainly south korean filmmakers make undemanding action movies alacrity hollywood counterparts',
#  'except much much better',
#  'happy heady jumble thought storytelling insane comic undertaking ultimately coheres sane breathtakingly creative film',
#  'one joke putting toilet seat',
#  'rrb',
#  'original base concept help get caught',
#  'appears made people idea narrative logic cohesion entirely foreign concept',
#  'ignore cliches concentrate city seas interpersonal drama ai halfbad',
#  'dreadful day irish history given passionate somewhat flawed treatment',
#  'see',
#  'nothing episode smackdown',
#  'guilty pleasure best worth seeing unless want laugh',
#  'perhaps better celebration unfairly dismissed heroes would film painfully forced false fabricated',
#  'relative letdown',
#  'hey arnold',
#  'though scratches surface least provides strong itch explore',
#  'band performances featured drumline red hot lrb rrb mere story point view films ice cold',
#  'nonmystery mystery',
#  'leigh one rare directors feels acting heart soul cinema',
#  'cast delivers without sham rawnerved story',
#  'monumental achievement practically every facet inept filmmaking joyless idiotic annoying heavyhanded visually atrocious often downright creepy',
#  'filmmakers heart right place',
#  'one highlypraised disappointments misfortune watch quite time',
#  'rocks standup magic wanes',
#  'roman polanski directs pianist like surgeon mends broken heart meticulously without passion',
#  'sadly garth progressed nicely wayne',
#  'wit empathy spare waydowntown acknowledges silent screams workaday inertia stops short indulging characters striving solipsism',
#  'labours storytelling',
#  'remember back thrillers actually thrilled',
#  'otherwise goodnaturedness mr deeds embrace sheer goofiness cameos less thanlikely new york celebrities certainly raises film anything sandlers attached',
#  'fails fundamentally every conventional level achieves kind goofy grandeur',
#  'hohum affair always watchable yet hardly memorable',
#  'saw movie well probably accurate call movie',
#  'though uniformly well acted especially young ballesta galan lrb firsttime actor rrb writerdirector achero manass film schematic obvious',
#  'resurrect dead man hard copy come aknocking',
#  'idea white man arriving foreign shores show wary natives true light abhorrent simplistic heaven quite likely like hell',
#  'hard believe relationship like holly marinas could survive hothouse emotions teendom longevity gets inexplicable characterizations turn crassly reductive',
#  'movie audience hours connect neat way introduces characters illuminate mysteries sex duty love',
#  'purports hollywood satire winds kind film target something deeper engaging',
#  'clever ninetenths',
#  'waterboy',
#  'going motions zip gone',
#  'scripts snazzy dialogue establishes realistic atmosphere involves us unfolding crisis lazy plotting ensures little emotional investment pays',
#  'good original',
#  'moviegoers would automatically bypass hiphop documentary give scratch second look',
#  'bigelow offers flashy twists turns occasionally fortify turgid fable',
#  'unsophisticated scifi drama takes seriously',
#  'stupid infantile redundant sloppy overthetop amateurish',
#  'resident evil comes taking john carpenters ghosts mars eliminating beheadings',
#  'movie resolutely avoids comic possibilities situation becomes one dumb high school comedy sex gags prom dates',
#  'without sex wonderful tale love destiny told well master storyteller',
#  'though goes anyone seen hunger cat people find little new tasty performance vincent gallo lifts tale cannibal lust ordinary',
#  'terrific date movie whatever orientation',
#  'expectation laughter quashed whatever obscenity hand even funniest idea funny',
#  'make movie depth man lacked',
#  'translation need try hard',
#  'frailty offers chills much like get sitting around campfire around midnight telling creepy stories give willies',
#  'less frontloaded shapely twohour version released 1990',
#  'ambitious movie like shiners organizing big fight pulls enough effects make ones come',
#  'movies suck despite flaws heaven one beast',
#  'well written directed brutal honesty respect audience',
#  'twenty years first release et remains wondrous hollywood fantasies apex steven spielbergs misunderstood career',
#  'gooding offers desperately ingratiating performance',
#  'stumbles every cheap trick book trying make outrage come even easier',
#  'nicely combines enigmatic features memento hallucinatory drug culture requiem dream',
#  'every individual see movie prism beliefs prejudices one thing take away sense peace possible',
#  'bunch good actors flailing around caper neither original terribly funny',
#  'illconceived expensive project winds looking like bunch talented thesps slumming',
#  'broders screenplay shallow offensive redundant pitifully real laughs',
#  'leguizamo jones excellent rest cast uniformly superb',
#  'trying figure rules country bear universe bears bears like humans hairier would tax einsteins brain',
#  'feardotcom makings interesting meditation ethereal nature internet otherworldly energies could channel simply becomes routine shocker',
#  'delia greta paula rank three multilayered sympathetic female characters year',
#  'beauty alexander paynes ode everyman details',
#  'town kind authentic feel one people stand everybody else background seems manufactured artificial',
#  'julie davis kathie lee gifford film directors sadly proving ego always go hand hand talent',
#  'much credit must given watercamera operating team king sonny miller michael stewart',
#  'film aussie david caesar channels notquitedead career guy ritchie',
#  'averse usually feelgood followyourdream hollywood fantasies one got',
#  'maybe formula filmmaking nothing wrong film wellcrafted one',
#  'would laugh tubaplaying dwarf rolled hill trash',
#  'loses sense humor vat failed jokes twitchy acting general boorishness',
#  'mistyeyed southern nostalgia piece treading line sappy sanguine winds mired teardrenched quicksand',
#  'oblivious existence film would sweet indeed',
#  'despite flaws belinsky still able create engaging story keeps guessing almost every turn',
#  'porn film without sex scenes',
#  'movie plays cartoons obvious strength snazziness neglecting less conspicuous writing strength',
#  'notwithstanding problem movies final half hour going recommend secretary based wonderful acting clinic put spader gyllenhaal also unique way shainberg goes telling heart sweet little girl',
#  'despite slick production values director roger michells ticktock pacing final effect like two guys yelling face two hours',
#  'barbershop goodhearted ensemble comedy variety quirky characters engaging story',
#  'soulless jumble ineptly assembled cliches pabulum plays like 95minute commercial nba properties',
#  'ambitious serious film manages virtually everything wrong sitting something akin act cinematic penance',
#  'consistently clever suspenseful',
#  'soderbergh skims fat 1972 film',
#  'hilarious musical comedy though stymied accents thick mud',
#  'movie like guys film criticism considered work',
#  'anyone suffers film deserves least big box consolation candy',
#  'bearable',
#  'cremaster 3 tough pill swallow minor miracle selfexpression',
#  'kouyate elicits strong performances cast delivers powerful commentary governments lie matter runs',
#  'see performance nothing else',
#  'asylum material gripping scenes jia family',
#  'walked away new version et hoped would moist eyes',
#  'attal pushes hard make comedy serious drama',
#  'plays like corny television production bygone era',
#  'powerful though flawed movie guaranteed put lump throat reaffirming washington possibly best actor working movies today',
#  'solondz may well one laughing joke',
#  'case two actors everything humanly possible create characters sweet believable defeated screenplay forces bizarre implausible behavior',
#  'enjoyment hinge personal threshold watching sad endearing characters extremely unconventional things',
#  'body smacks exhibitionism cathartic truth telling',
#  'though writerdirector bart freundlichs film ultimately becomes simplistic story dysfunctional parentchild relationship special qualities soulful gravity crudups anchoring performance',
#  'lrb carveys rrb characters overplayed exaggerated subtlety never trademark',
#  'beautifully animated epic never dull',
#  'charming witty also somewhat clumsy',
#  'one scene get stab soccer hooliganism doublebarreled ripoff quentin tarantinos climactic shootout meat loaf explodes',
#  'frustratingly refuses give pinochets crimes political context',
#  'paul bettany playing malcolm mcdowell',
#  'serviceable eurotrash action extravaganza decent sense humor plenty things go boom handguns bmws seaside chateaus',
#  'veterans dating wars smirk uneasily films nightmare versions everyday sexinthecity misadventures',
#  'sends away believer quite cheered',
#  'rollerball sequences feel sanitised stagey',
#  'interview assassin structured less documentary found relic film difficult time shaking blair witch project realtime roots',
#  'remarkable epic scope startling intimacy achieves despite breadth',
#  'nearly 212 hours film way indulgent',
#  'seems like something american european gay movies 20 years ago',
#  'claims sort bad guys good essential problem',
#  'mana gives us compelling damaged characters want help hurt',
#  'goodlooking relentlessly lowbrow outing plays like clueless south fork',
#  'evokes palpable sense disconnection made poignant incessant use cell phones',
#  'concept hoot',
#  'straightshooting family film awards animals respect rarely given',
#  'directive protect code costs also begins blur importance man code merge',
#  'eric schaeffer accomplished never may strictly speaking qualify revolutionary',
#  'obvious obnoxious didactic burlesque',
#  'one say balding 50yearold actor playing innocent boy carved log',
#  'ca seem get anywhere near storys center',
#  'even 50million us budget pinocchio never quite achieves feel fanciful motion picture',
#  'little intensity little less charm would saved film world hurt',
#  'like jagloms films honestly affecting seems contrived secondhand',
#  'maelstrom deliberately unsteady mixture stylistic elements',
#  'bring battle bots please',
#  'sweet home alabama going win academy awards datenight diversion definitely win hearts',
#  'love may air onscreen certainly feeling',
#  'long larded exposition somber cop drama ultimately feels flat scruffy sands titular community',
#  'young stars cute story ensuing complications manipulative message blatant resolutions convenient',
#  'ways lagaan quintessential bollywood',
#  'characteristically engorged sloppy comingofage movie',
#  'wry affectionate delight',
#  'credit director ramsay taking sometimes improbable story making feel realistic',
#  'auteurs ear way fears slights telegraphed blithe exchanges gives film lingering tug',
#  'gets better foster leaves little room',
#  'despite lavish formalism intellectual austerity film manages keep edge seat shapeshifting perils political intrigue brushes calamity',
#  'friday next kind film could made africanamericans broad racial insensitivity towards africanamericans',
#  'lively account seinfeld deadpan',
#  'brings awareness issue often overlooked womens depression',
#  'imagine film begins seven ripoff switch mix shining thing naked teenagers horror flick 1980s',
#  'definitely funny stuff laughing variety laughing',
#  'heartening tale small victories enduring hope',
#  'emotionally strong politically potent piece cinema',
#  'extremely unpleasant film',
#  'intellectually scary dramatically involving',
#  'puzzling experience',
#  'jonah soso addition biblical message either improve film lessen',
#  'hope movie widely seen debated appropriate ferocity thoughtfulness',
#  'intelligent moving',
#  'film busy hitting assigned marks take life',
#  'mark wahlberg may look classy a60s homage pokepie hat character dry dry dry',
#  'moral shrapnel mental shellshock linger long film ended',
#  'warren stumbles search emotions life experiences neglected years',
#  'stayed',
#  'pile useless actioners mtv schmucks know tell story four minutes',
#  'first time director sara sugarman stoops characters drop pants laughs last time fails provoke',
#  'point view contemporary interpretation joans prefeminist plight left thinking reason make movie present standards allow plenty nudity',
#  'strong directorial stamp every frame stylish film able visualize schizophrenia still confident enough step back look sick character sane eye',
#  'romantic riveting handsomely animated',
#  'overproduced piece dreck shockingly bad absolutely unnecessary',
#  'saccharine disposable',
#  'captures raw comic energy one flamboyant female comics',
#  'subtle poignant picture goodness flawed compromised sad',
#  'exceptionally acted quietly affecting cop drama',
#  'even summertime restless young audience deserves dignity action hero motivated something franchise possibilities',
#  'perfectly pitched comedy tragedy hope despair schmidt instead comes far closer many movies expressing way many us live someplace consuming selfabsorption insistently demanding otherness',
#  'nearly glows enthusiasm sensuality conniving wit',
#  'despite modest aspirations occasional charms dismissed',
#  'exaggerated broad comes annoying rather charming',
#  'strange funny twisted brilliant macabre',
#  'film throwntogether feel summercamp talent show hastily written underrehearsed arbitrarily plotted filled crude humor vulgar innuendo',
#  'cast comes even movie',
#  'rocksolid gangster movie fair amount suspense intriguing characters bizarre bank robberies plus heavy dose fatherandson dynamics',
#  'degrading strangely liberating see people working hard leading lives sexy intrigue revealed dispassionate gantz brothers ordinary pasty lumpen',
#  'innocuous enough make even jeanclaude van damme look good',
#  'essence magic makebelieve promise life soars material realm opposite truly magical movie',
#  'storytelling prowess special effects listless',
#  'stopped thinking good started nothing reacting feeling part grand locations thinking urgently protagonists struggled feeling mercy inventiveness gasping visual delights',
#  'newcomer helmer kevin donovan hamstrung badly handled screenplay really amusing concept hightech tux transforms wearer superman',
#  'one hour photo may seem disappointing generalities little nuances perhaps escape director mark romaneks selfconscious scrutiny happen finally get skin',
#  'confrontational stance todd solondz takes aim political correctness suburban families',
#  'processed comedy chop suey',
#  'eventually arrives heart simple selfreflection meditation',
#  'proves lovely trifle unfortunately little love cuteness',
#  'purely enjoyable might even notice fairly straightforward remake hollywood comedies father bride',
#  'intelligent multilayered profoundly humanist lrb mention gently political rrb meditation values knowledge education affects cultural geographical displacement',
#  'sure worse poor acting ensemble cast flat dialogue vincent r nebrida gutless direction laurice guillen',
#  'sexy peculiar always entertaining costume drama set renaissance spain fact based true events somehow makes compelling',
#  'santa clause 2 proves streamlined thought encounter original could ever hoped',
#  'goldmember none visual wit previous pictures looks though jay roach directed film back taxicab',
#  'sweet laughaminute crowd pleaser lifts spirits well corners mouth',
#  'highly recommended engrossing story horrifying historical event elements contributed',
#  'goes point nausea',
#  'lrb raimis rrb matured quite bit spiderman even though one plain white toast comic book films ever see',
#  'convincing arnie musclefest little much resonance real world events ultimately comes insultingly simplistic',
#  'unbelievably stupid film though occasionally fun enough make forget absurdity',
#  'icy stunts actors spout hilarious dialogue following dream letting mountain tell',
#  'modestly surprising movie',
#  'powerful sequel one best films year',
#  'combines improbable melodrama lrb gored bullfighters comatose ballerinas rrb subtly kinky bedside vigils sensational denouements yet end undeniably touched',
#  'one mr chabrols subtlest works also one uncanny',
#  'one strictly lightweight escapist film',
#  'actually sincere crime movie equivalent chick flick',
#  'title jeopardy question answer might steven seagal come across days',
#  'unambitious writing emerges movie using plot could come animatedmovie screenwriting textbook',
#  'us complaining film clocks around 90 minutes days plotting leaves lot desired',
#  'freedom watching stunts crude fastpaced insane',
#  'movie sucks',
#  'dignified ceos meet rustic retreat pee tree',
#  'sugarcoated rocky whose valuable messages forgotten 10 minutes last trombone honks',
#  'movie amateurishly square make ironic implications',
#  'sets romantic comedy apart hollywood romantic comedies lowkey way tackling seems like donetodeath material',
#  'films constant mood melancholy unhurried narrative masterfully controlled',
#  'barry sonnenfeld owes frank pug big time',
#  'one gets impression creators ask tell laughed hell lot jokes',
#  'schrader aims present unflinching look one mans downfall brought lack selfawareness',
#  'becomes long tedious like classroom play college history course',
#  'blue crush follows formula throws many conflicts keep story compelling',
#  'small gem movie defies classification thoughtprovoking funny scary sad',
#  'somewhere middle film compels demme experiments harvests movie moment gems field roughage dominates',
#  'story betterfocused incomprehensible anne rice novel based upon queen damned pointless meandering celebration gothvampire tortured woeisme lifestyle',
#  'color sense stuart little 2 immediate obvious pleasure would count little movie beautifully shaped delicately calibrated tone',
#  'parts',
#  'visual fertility treasure planet rivals top japanese animations recent vintage',
#  'toothless dog already cable loses bite big screen',
#  'make chans action sequences boring',
#  'comes whether tolerate leon barlow',
#  'wild thornberrys movie sibling rivalry general family chaos anyone relate',
#  'peralta captures luminous interviews amazingly evocative film three decades ago essence dogtown experience',
#  'movie dragged thought heard mysterious voice felt powerfully drawn toward light light exit sign',
#  'certainly appeal asian cult cinema fans asiaphiles interested see fuss',
#  'green ruins every single scene film completely wreaked seriously compromised',
#  'evokes frustration awkwardness euphoria growing without relying usual tropes',
#  'standing shadows motown best kind documentary one makes depleted yesterday feel much like brandnew tomorrow',
#  'ambitious project fairly inexperienced filmmaker good actors good poetry good music help sustain',
#  'thriller whose style structure rhythms integrated story separate',
#  'mostly pleasure watch',
#  'first question ask bad company anthony hopkins',
#  'nair writer laura cahill dare build movie around flawed rather unexceptional women emerging fine character study short plot rich tiny revelations real life',
#  'goofy nutty consistently funny',
#  'audiard successfully maintains suspense different levels throughout film gripping compelling',
#  'welles groupiescholar peter bogdanovich took long time finally provided broadside publishing giant william randolph hearst',
#  'excruciating 86 minutes one might sit summer involve dentist drill',
#  'skillful mr shyamalan undone pretensions',
#  'fans sobadthey good cinema may find fun jumbled mess',
#  'started wonder unpaid intern typed chris rock anthony hopkins terrorists univaclike script machine',
#  'mostly works universal themes earnest performances excellent use music indias popular gulzar jagjit singh',
#  'perceptive goodnatured movie',
#  'stand cheer flick sit ponder affair',
#  'one pleasures walters documentary parade veteran painters confounded dealers miscellaneous bohos expound upon subjects mysterious personality without ever explaining',
#  'adrift bentley hudson stare sniffle respectively ledger attempts vain prove moviestar intensity overcome bad hair design',
#  'real charm trifle deadpan comic face star jean reno resembles sly stallone hot sake halfsleep',
#  'element heartbreak watching older wiser eyes know happen greenes story ends',
#  'rather real figures',
#  'means great movie refreshingly forthright one',
#  'unlikable',
#  'show mugging',
#  'hashiguchi uses situation evoke japan bustling atop undercurrent loneliness isolation',
#  'rollicking adventure mateys regardless ages',
#  'next big things notsobig lrb notsohot rrb directorial debut',
#  'content clever pseudobio manages good time doles pieces famous directors life eisenstein delivers',
#  'overly long worshipful biodoc',
#  'visual spectacle full stunning images effects',
#  'something meditative lyrical babak payamis boldly quirky iranian drama secret ballot charming evoking little ditty manages show gentle humane side middle eastern world politics',
#  'easy cynical documentaries underdogs beat odds human spirit triumphs westbrooks foundation dalrymples film earn uplift',
#  'difference truly enjoyed mostly martha ne',
#  'ca remember last time saw movie wanted badly protagonist fail',
#  'falsehoods pile undermining movies reality stifling creators comic voice',
#  'early middle passages surprising much engage even touch us',
#  'limps along squirminducing fishoutofwater formula goes nowhere goes slowly',
#  'really funny fifteenminute short stretched beyond limits fill almost featurelength film',
#  'writer director otar iosselianis pleasant tale factory worker escapes holiday venice reveals need playful respite grind refresh souls',
#  'mechanical actioncomedy whose seeming purpose market charismatic jackie chan even younger audiences',
#  'chalk worst kind hubristic folly',
#  'though haynes style apes films period message rooted decade',
#  '',
#  'compelling allegory last days germanys democratic weimar republic',
#  'director jay russell stomps hobnail boots natalie babbitts gentle endearing 1975 childrens novel',
#  'indelible epic american story two families one black one white facing change inner outer lives',
#  'raw actionpacked experience ringside seat toughman contest',
#  'lrb film rrb works due mostly tongueincheek attitude screenplay',
#  'walk good girl mixed emotions disapproval justine combined tinge understanding actions',
#  'movie strains stay light comic side issue despite difficulty dealing destruction property potentially life',
#  'unfortunately story actors served hack script',
#  'insultingly inept artificial examination grief impacts upon relationships survivors',
#  'immersive powers giant screen hyperrealistic images put perfect use breathtakingly beautiful outerspace documentary space station 3d',
#  'tired unnecessary retread stale copy picture great begin',
#  'initial excitement settles warmed pastiche',
#  'muccino directed screenplay canny crowd pleaser last kiss provides enough sentimental catharsis satisfying evening multiplex',
#  'challenges nervy oddity like modern art',
#  'read lips viewed treasured extraordinary intelligence originality well lyrical variations game love',
#  'hour half joyful solo performance',
#  'like parade predecessors halloween gory slashfest',
#  'better tepid star trek insurrection falls short first contact villain could pick lint borg queen alice kriges cape finishes half parsec lrb nose rrb ahead generations',
#  'exploits lrb headbanger rrb stereotypes good fun adding bit heart unsettling subject matter',
#  'rather leaden dull',
#  'rice never clearly defines characters gives us reason care',
#  'although subject matter may still close recent national events film works mostly due superior cast characters',
#  'deeply felt vividly detailed story newcomers strange new world',
#  'films darker moments become smoothed overwhelming need tender inspirational tidings especially last cloying moments',
#  'opening strains average white bands pick pieces feel love',
# ...
#  'generic international version typical american horror film',
#  'result good gossip entertainingly delivered yet distinctly musty odour expiry date long gone',
#  'labour involved creating layered richness imagery chiaroscuro madness light astonishing',
#  'charlotte sometimes gem',
#  'stage director sam mendes showcases tom hanks depression era hitman dark tale revenge',
#  'brady',
#  'upper teens may get cynical',
#  'gift anyone loves dance cinema',
#  'small movie big heart',
#  'like comedian starts promisingly proceeds flop comedian runs steam half hour',
#  'feeling like 1920s trip great deal fun',
#  'essentially collection bits naughty',
#  'cartoon',
#  'disney aficionados notice distinct parallels story 1971 musical bedknobs broomsticks also dealt british children rediscovering power fantasy wartime',
#  'guys seem great knock back beer simply funny performers',
#  'motion picture utterly static picture',
#  'powerpuff girls arrive big screen superpowers supersimple animation superdooperadorability intact',
#  'coal easy come used would worthy substitute naughty childrens stockings',
#  'love opening scenes wintry new york city 1899',
#  'lrb jagloms rrb latest effort director sparkling repartee still worth hearing',
#  'shares first two films loosejointed structure laughoutloud bits far',
#  'movie trove delights',
#  'ichi killer takashi miike japans wildest filmmaker gives us crime fighter carrying emotional baggage batman',
#  'sentimental resolution explains way cal movie character good freundlichs world traveler might one daring surprising american movies year',
#  'thin period piece',
#  'wellexecuted spythriller',
#  'strippeddown dramatic constructs austere imagery abstract characters equal parts poetry politics obvious times evocative heartfelt',
#  'tale passionate tumultuous affair musset unfolds sands masculine persona love life beauty takes form',
#  'old garbage hollywood trying pass acceptable teen entertainment time',
#  'strident inelegant messagemovie posturing',
#  'affable maid manhattan jennifer lopezs aggressive sincere attempt take movies storm diva shrewdly surrounds company strictly alist players',
#  'gives intriguing twist french comingofage genre',
#  'would lying said ribcage ache end kung pow',
#  'capability effecting change inspiring hope',
#  'kitschy flashy overlong soap opera',
#  'white developed characters much caricatures onedimensional buffoons get laughs nothing else',
#  'one resurrection many',
#  'execrable',
#  'may nobrainer least funny nobrainer',
#  'liked movie know would liked gone one step',
#  'lrb allens rrb best works understand snobbery better satiric target middleamerica diversions could ever',
#  'gives poor dana carvey nothing really funny expects us laugh acts goofy time',
#  'bernal',
#  'ambitious moving bleak film',
#  'cinema around capture chaos france 1790s one imagines result would look like something like',
#  'slight enjoyable documentary',
#  'film inform educate',
#  'curious see darker side going young tv actors lrb dawson leery rrb see interesting storytelling devices might want check nothing attractive movie',
#  'end movie 6yearold nephew said guess come broken family uncles aliens',
#  'actors good pauline paulette van der groen described belgiums national treasure especially terrific pauline',
#  'curling may unique sport men brooms distinctly ordinary',
#  'yes right forrest gump angel death',
#  'metaphors abound easy take film face value enjoy slightly humorous tender story',
#  'comes across fairly weak retooling',
#  'orange juice far freshsqueezed',
#  'averting eyes solondz forces us consider unthinkable unacceptable unmentionable',
#  'remarkably alluring film set constrictive eisenhower era one suburban womans yearning face loss shatters cheery tranquil suburban life',
#  'ultimately frustrating patchwork uneasy marriage louis begleys source novel lrb schmidt rrb old payne screenplay',
#  'movie like year late tapping reality tv obsession even tardier exploiting novelty webcast',
#  'chais structure pacing disconcertingly slack',
#  'else doggie winks',
#  'need steeped in50s sociology pop culture movie lore appreciate emotional depth haynes work',
#  'decasia happened already many silent movies newsreels like',
#  'anything else kissing jessica stein injects freshness spirit romantic comedy genre held hostage generic scripts seek remake sleepless seattle',
#  'fast funny action cartoon suspenseful enough older kids scary schoolage crowd',
#  'big buildup payoff audience well characters messy murky unsatisfying',
#  'better predecessor may rate magical fun family fare recent holiday season',
#  'intelligence gay audiences grossly underestimated meaty plot welldeveloped characters sacrificed skin flash barely fizzle',
#  'film without surprise geared toward maximum comfort familiarity',
#  'definitely crowdpleaser roman colosseum',
#  'vh1 behind music special something little special behind music sell many records helped change nation',
#  'kids love fantasy adventure grownups appreciate whimsical humor',
#  'took three minutes dialogue 30 seconds plot turned 90minute movie feels five hours long',
#  'interminably bleak say nothing boring',
#  'naturally funny film home movie makes crave chris smiths next movie',
#  'bai brothers taken small slice history opened us understand told nice little story process',
#  'meatballs baremidriff generation',
#  'movie worst thing chan done united states',
#  'maintains interest end even leaves lingering animated thoughts',
#  'blushing gushing imamura squirts screen warm water red bridge',
#  'entertainment disposable hannabarberas halfhour cartoons ever',
#  'beautiful images solemn words disguise slack complacency lrb godards rrb vision gorgeous piano strings soundtrack drown tinny selfrighteousness voice',
#  'dylan thomas alive witness firsttime director ethan hawkes strained chelsea walls might tempted change landmark poem go gentle good theatre',
#  'affirms gifts involved starting spielberg going right ranks players oncamera brings together',
#  'somewhat disappointing meandering saga',
#  'action scenes things fall apart',
#  'palpable chemistry lopez male lead ralph fiennes plus script working girl scribe kevin wade workmanlike extreme',
#  'cleverly crafted ultimately hollow mockumentary',
#  'uneven movie charms funny moments quite enough',
#  'unintentionally surreal kids picture actors bad bear suits enact sort interspecies parody vh1 behind music episode',
#  'break heart many times',
#  'lax limp comedy seen meander wornout material',
#  'sitcomishly predictable cloying attempts poignant',
#  'though rude crude film deliver gutbusting laughs digs modern society things seen',
#  'lrb rrb mess',
#  'work lacks purpose strong pulse',
#  'sword fighting well done auteuil goofy pleasure',
#  'stereotype',
#  'imax screen enhances personal touch manual animation',
#  'kaufman jonze take huge risks ponder whole notion passion desire human beings passion lives emptiness one feels missing',
#  'god bless crudup aversion taking easy hollywood road cashing moviestar gorgeousness',
#  'comedy',
#  'unlike surf movies blue crush thrillingly uses modern technology take viewer inside wave',
#  'best part gangs daniel daylewis',
#  'waiting godard fruitful praise love directors epitaph',
#  'edgy thriller delivers surprising punch',
#  'movie would seem less trifle ms sugarman followed defiance saccharine',
#  'war roses trailertrash style',
#  'result powerful naturally dramatic piece lowbudget filmmaking',
#  'fifty car pileup cliches',
#  'whole stretches film may incomprehensible moviegoers already clad basic black',
#  'pitiful slapdash disaster',
#  'charlotte sometimes brilliant movie',
#  'end simply admiring bit performance',
#  'godard never made sheerly beautiful film unexpectedly moving meditation love history memory resistance artistic transcendence',
#  'erotic thriller neither erotic thrilling either',
#  'carrying spoton scottish burr duvall lrb also producer rrb peels layers character may well existed paper',
#  'solid piece journalistic work draws picture man political expedience became deadly foreign policy',
#  'hopkins squarely fills screen',
#  'irwin director never come adequate reason pay money get television free',
#  'everything title implies standardissue crime drama spat tinseltown assembly line',
#  'unfolds one politically audacious films recent decades country especially france',
#  'abandon leave wanting abandon theater',
#  'probably best case christianity since chesterton lewis',
#  'long desperate evening end',
#  'rather shapeless good time',
#  'feels like rejected xfiles episode credible account puzzling reallife happening',
#  'amount good intentions able overcome triviality story',
#  'lrb ramsay rrb visually transforms dreary expanse deadend distaste characters inhabit poem art music metaphor',
#  'film lrb rrb moments far',
#  'sweetly affecting story four sisters coping one way another lifes endgame',
#  'disturbing examination appears definition bad police shooting',
#  'distances throwing many red herrings many false scares genuine ones barely register',
#  'almost',
#  'every sequel skip two hours gained',
#  'done',
#  'exist hushed lines like back',
#  'somehow ms griffiths mr pryce bring wild welsh whimsy',
#  'densest distillation roberts movies ever made',
#  'lots effort intelligence display execution awkward static lifeless rumblings',
#  'one outstanding thrillers recent years',
#  'consider film celluloid litmus test intellectual emotional pedigree date giant step backward director admire',
#  'subtitled costume drama set remote african empire cell phones guns internal combustion engine politics thump timely tomorrow',
#  'opening contrived banter cliches loose ends screenplay comes second half',
#  'captivating new film',
#  'adored full monty resoundingly dying see old thing tired old setting keep reasonably entertained',
#  'worth catching griffiths warm winning central performance',
#  'sorvino makes princess seem smug cartoonish film really comes alive poor hermocrates leontine pathetically compare notes budding amours',
#  'making melodrama filmmaker cuts natural grain producing work interested asking questions answering',
#  'davis funny charming quirky feature film acting debut amy',
#  'uncomfortable movie suffocating sometimes almost senseless grey zone center though morbid one',
#  'lousy john q spits denzel washingtons fine performance title role',
#  'devoid pleasure sensuality even dubbed hedonistic',
#  'satin rouge new inventive journey encouraging see threedimensional average middleaged womans experience selfdiscovery handled sensitivity',
#  'pointed often tender examination pros cons unconditional love familial duties',
#  'another trumpet blast may new mexican cinema abornin',
#  'gorgeous look insufferably tedious turgid curiously constricted epic',
#  'sexy dangerous actress role reminds every turn elizabeth berkleys flopping dolphingasm',
#  'contrast neither dramatic comic weird fizzle',
#  'collateral damage trash earns extra points acting',
#  'think figured bielinskys great game trouble con mark',
#  'swimming young womans face casting actress whose face projects womans doubts yearnings succeeds',
#  'packed bursting incident scores characters fictional history',
#  'want call dominos',
#  'umpteenth summer skinny dip jerry bruckheimers putrid pond retread action twaddle',
#  'road paved good intentions leads video store',
#  'chris columbus sequel faster livelier good deal funnier original',
#  'full flatulence jokes mild sexual references kung pow',
#  'whole affair predictable',
#  'film good viewing alternative young women',
#  'read book film much better motherdaughter tale last summers divine secrets yaya sisterhood saying much',
#  'also many things made first one charming',
#  'sheridan',
#  'slight premise works ideal casting masterful british actor ian holm aged napoleon',
#  'never mind boobs fantasti',
#  'schmidt nicholsons goofy heartfelt mesmerizing king lear',
#  'things costner movies known sanctimonious selfrighteous eager earn love want slap',
#  'funny heartwarming film',
#  'piece handiwork shows indie tatters selfconscious seams places quietly moving moments intelligent subtlety',
#  'amused entertained unfolding bielinskys cleverly constructed scenario greatly impressed skill actors involved enterprise',
#  'distance picture provides satisfyingly unsettling ride dark places national psyche',
#  'little add beyond dark visions already relayed superb recent predecessors like swimming sharks player latest skewering may put insiders outsiders alike',
#  'unique necessarily equate good matter admirably filmmakers gone broke',
#  'respective charms sandra bullock hugh grant worn threadbare',
#  'like hanks character slow study action stilted tabloid energy embalmed',
#  'enthusiastically invokes percussion rhythm brass soul sense fierce competition helps make great marching bands half fun college football games',
#  'invigorating give damn',
#  'cacoyannis perhaps effective creating atmosphere dustcaked stagnation labored gentility',
#  'entertaining ultimately minor thriller',
#  'real star movie score songs translate well film really well directed',
#  'punitively affirmational parable',
#  'demme finally succeeds diminishing stature oscarwinning master lowly studio hack',
#  'horrid little propaganda film fascinating connections serbs also network american rightwing extremists',
#  'starproducer salma hayek director julie taymor infused frida visual style unique inherent titular characters paintings process created masterful work art',
#  'one nearly dreadful expected',
#  'trying capture novels deeper intimate resonances film ironically distanced us characters',
#  'real women curves wears empowerment sleeve even worst harangues easy swallow thanks remarkable performances ferrera ontiveros',
#  'whole heap nothing core slight comingofagecomingout tale',
#  'sensitive moving brilliantly constructed work',
#  'pulls rug ready hate one character really sympathize another character something happens send different direction',
#  'art direction often exquisite anthropomorphic animal characters beautifully realized clever makeup design leaving one hope eventual dvd release offer subtitles original italianlanguage soundtrack',
#  'probably easy make worthless film',
#  'creative animation work may look fully rendered pixars industry standard uses lighting effects innovative backgrounds equally impressive degree',
#  'often unfunny romp',
#  'makes sense went back school check girls film frat boys idea good time',
#  'clever especially compelling',
#  'exit sign',
#  'actors showcase accomplishes primary goal without use special effects rather emphasizing characters including supporting ones',
#  'emperors club ruthless placid way finds one conservative hidebound moviemaking traditions gives new texture new relevance new reality',
#  'halfanhour long tv special humor would fast furious ninety minutes drags',
#  'compelling mix trial movie escape movie unexpected fable ensures film never feels draggy',
#  'drowns sap',
#  'rare birds tries force quirkiness upon audience',
#  'solid refined piece moviemaking imbued passion attitude',
#  'red dragon never cuts corners',
#  'modeled',
#  'alternative medicine obviously merits ayurveda field favors',
#  'bland harmless',
#  'viewers asked often suspend belief holms performance film would total washout',
#  'small fortune salaries stunt cars might saved director tom dey spliced together bits pieces midnight run 48 hours lrb matter shrek rrb',
#  'good see michael caine whipping dirty words punching people stomach',
#  'thing breaks new ground treads old turf like hippopotamus ballerina',
#  'film exudes urbane sweetness woody allen seems bitterly forsaken',
#  'script dimwitted pairing teenspeak animal gibberish',
#  'cedar somewhat defuses provocative theme submerging hoary love triangle',
#  'might emerged hilarious lunacy hands woody allen mel brooks lrb least their70s heyday rrb comes across lame sophomoric debut indie feature',
#  'disappointed movie long time',
#  'comedic moment romantic comedy',
#  'admire yet recommend overstays natural running time',
#  'plenty enjoy small part thanks lau',
#  'action mechanical',
#  ...]

# %%
def wordVector(df):
    wordVec = []
    for index, row in df.iterrows():
        for i in row['Phrase'].split():
            wordVec.append(i)
    wordVec = set(wordVec)
    return wordVec

# %%
wordVec = wordVector(initialFrame)
wordVec
# Out:
# {'needles',
#  'brimming',
#  'runon',
#  'nearhypnotic',
#  'impact',
#  'sweep',
#  'damon',
#  'tragic',
#  'sinister',
#  'resident',
#  'speck',
#  'answers',
#  'veretes',
#  'showdon',
#  '50million',
#  'cookiecutter',
#  'amalgam',
#  'biggie',
#  'sacre',
#  'distorts',
#  'longfaced',
#  'carusos',
#  'happen',
#  'wahlberg',
#  'deal',
#  'favored',
#  'scarifying',
#  'kourys',
#  'electric',
#  'ruin',
#  'nowheresville',
#  'explanation',
#  'actioncomedy',
#  'screens',
#  'dismal',
#  'meditative',
#  'shindlers',
#  'guise',
#  'rooted',
#  'aging',
#  'latest',
#  'named',
#  'vice',
#  'squarely',
#  'gore',
#  'purposes',
#  'rings',
#  'utter',
#  'ponderous',
#  'nakata',
#  'commenting',
#  'irritates',
#  'participatory',
#  'reeks',
#  'chuck',
#  'dirgelike',
#  'purdys',
#  'cloying',
#  'remarkable',
#  'numbing',
#  'smiths',
#  'stink',
#  'crikey',
#  'diverting',
#  'decade',
#  'satirical',
#  'trivializing',
#  'schematic',
#  'profundity',
#  'commend',
#  'abyss',
#  'molehill',
#  'snooze',
#  'rated',
#  'norton',
#  'mourning',
#  'banger',
#  'item',
#  'wills',
#  'olympus',
#  'wo',
#  'concealment',
#  'nickelodeonesque',
#  'peculiar',
#  'decasia',
#  'place',
#  'balk',
#  'quasishakespearean',
#  'numb',
#  'scifi',
#  'ambiguous',
#  'diplomacy',
#  'wearer',
#  'pianist',
#  'recipe',
#  'bronx',
#  'unadorned',
#  'loneliest',
#  'hoods',
#  'wrapped',
#  'hideousness',
#  'profoundly',
#  'trades',
#  'friel',
#  'grisham',
#  'madonnas',
#  'pinned',
#  'argument',
#  'undo',
#  'lot',
#  'oddly',
#  'revives',
#  'package',
#  'bigbudgetallstar',
#  'passer',
#  'hanukkah',
#  'hannibal',
#  'absorbing',
#  'zap',
#  'razzledazzle',
#  'unfairly',
#  'sewage',
#  'pat',
#  'tufanos',
#  'enjoy',
#  'studios',
#  'albeit',
#  'demeanor',
#  'individuality',
#  'showbiz',
#  'converts',
#  'respite',
#  'appetizing',
#  'players',
#  'guarantee',
#  'highadrenaline',
#  'reigen',
#  'begun',
#  'psychologizing',
#  'holding',
#  'populating',
#  'hopkins',
#  'identification',
#  'rarely',
#  'raging',
#  'moldering',
#  'demme',
#  'six',
#  'marylouise',
#  'traffic',
#  'ong',
#  'venturesome',
#  'sportsmovie',
#  'playwright',
#  'sam',
#  'psychiatrist',
#  'half',
#  'surveillance',
#  'rewritten',
#  'sloppy',
#  'snaps',
#  'improbabilities',
#  'scrutinize',
#  'copycat',
#  'vs',
#  'eventual',
#  'goo',
#  'admission',
#  'cover',
#  'computeranimated',
#  'chronicles',
#  'sparkling',
#  'apple',
#  'amaris',
#  'holden',
#  'scotts',
#  'geriatric',
#  'schnieder',
#  'warmest',
#  'despair',
#  'reggios',
#  'tackles',
#  'learns',
#  'dimensions',
#  'krawczyk',
#  'connect',
#  'somewhat',
#  'social',
#  'sica',
#  'winces',
#  'indignant',
#  'ups',
#  'reversal',
#  'steals',
#  'espionage',
#  'locales',
#  'internal',
#  'duvall',
#  'ram',
#  'buscemi',
#  'selfdetermination',
#  'synthetic',
#  'sucker',
#  'admirably',
#  'rice',
#  'baio',
#  'deceptions',
#  'crowd',
#  '45ths',
#  'scherfig',
#  'attics',
#  'pained',
#  'close',
#  'catalytic',
#  'artist',
#  'gritty',
#  'temporal',
#  'cowrote',
#  'grayish',
#  'master',
#  'onenote',
#  'rodriguess',
#  'undone',
#  'truckzilla',
#  'script',
#  'allow',
#  'actioner',
#  'caretakers',
#  'triessohardtobecool',
#  'timeitis',
#  'hundred',
#  'consciousness',
#  'trueblue',
#  'malleable',
#  'independence',
#  'rubbo',
#  'suspenser',
#  'worst',
#  'shlockmeister',
#  'curmudgeonly',
#  'call',
#  'writer',
#  'captures',
#  'mistress',
#  '60',
#  '2day',
#  'dazed',
#  'goal',
#  'exasperatingly',
#  'forcefully',
#  'dour',
#  'typifies',
#  'paycheck',
#  'bedeviled',
#  'premise',
#  'gunfight',
#  'first',
#  'balance',
#  'innovative',
#  'fabricated',
#  'remote',
#  'enlightened',
#  'concrete',
#  'kirshner',
#  'jampacked',
#  'vectors',
#  'promotion',
#  'carlitos',
#  'temptingly',
#  'messy',
#  'compendium',
#  'province',
#  'derisions',
#  'astronomically',
#  'alloverthemap',
#  'lingers',
#  'outweigh',
#  'junior',
#  'revelatory',
#  'ambivalent',
#  'hilarious',
#  'worldatlarge',
#  'wig',
#  'characterized',
#  'insomnia',
#  'dispossessed',
#  'jersey',
#  'among',
#  'tame',
#  'subzero',
#  'sociopath',
#  'columbine',
#  'conceited',
#  'commanding',
#  'resides',
#  'mainstream',
#  'smoking',
#  'juwanna',
#  'suffice',
#  'strike',
#  'period',
#  'sirk',
#  'scientist',
#  'rhetoric',
#  'bakers',
#  'mishmash',
#  'ben',
#  'grossly',
#  'similarly',
#  'splash',
#  'hopefully',
#  'distinguishes',
#  'beast',
#  'lodging',
#  'work',
#  'bugged',
#  'rhames',
#  'tremendous',
#  'thi',
#  'precisely',
#  'dogtown',
#  'demographics',
#  'allied',
#  'full',
#  '100',
#  'waters',
#  'accurately',
#  'harvesting',
#  'graduated',
#  'scarlets',
#  'genocide',
#  'messagemovie',
#  'cuisine',
#  'mrs',
#  'populates',
#  'soapopera',
#  'delay',
#  'secretary',
#  'straightshooting',
#  'heroes',
#  'threetoone',
#  'stew',
#  'whiteonblack',
#  'joke',
#  'mercy',
#  'common',
#  'ash',
#  'alternately',
#  'exhilaratingly',
#  'envelops',
#  'costly',
#  'invulnerable',
#  'thin',
#  'genrebusting',
#  'unlimited',
#  'thus',
#  'inspiring',
#  'subplots',
#  'femme',
#  'unexpectedly',
#  'organized',
#  'preposterousness',
#  'grimace',
#  'notwithstanding',
#  'somewhere',
#  'complications',
#  'schemes',
#  'graffiti',
#  'quickcuts',
#  'stamp',
#  'happens',
#  'russo',
#  'scariest',
#  'sitcom',
#  'lists',
#  'relaxed',
#  'snoozer',
#  'climate',
#  'adorns',
#  'realization',
#  'trombone',
#  'masses',
#  'ranges',
#  'evaluate',
#  'cards',
#  'uppity',
#  'giannini',
#  'cad',
#  'decoder',
#  'gratefully',
#  'proves',
#  'waxes',
#  'hawaiian',
#  'solemnity',
#  'jr',
#  'clunkiness',
#  'gun',
#  'naturalism',
#  'ferocity',
#  'veggietales',
#  'useless',
#  'acted',
#  'fabian',
#  'timekiller',
#  'craig',
#  'creations',
#  'surge',
#  'sessions',
#  'farcically',
#  'winter',
#  'without',
#  'chain',
#  'recovering',
#  'kevin',
#  'prescription',
#  'roughage',
#  'requiring',
#  'disconnection',
#  'professionals',
#  'continuum',
#  'weaknesses',
#  'greater',
#  'selfsatisfaction',
#  'gaiety',
#  'emotional',
#  'marilyn',
#  'selfreferential',
#  'cinema',
#  'davies',
#  'anyones',
#  'superficiale',
#  'wearisome',
#  'witty',
#  'trace',
#  'contemptuous',
#  'exceptional',
#  'limbo',
#  'stomach',
#  'selfinflicted',
#  'removed',
#  'collegespawned',
#  'wordless',
#  'somehow',
#  'terminally',
#  'deserves',
#  'acting',
#  'comedian',
#  'crossingover',
#  'mistakenidentity',
#  'james',
#  'interdependence',
#  'radiates',
#  'lantern',
#  'prima',
#  'benigni',
#  'serious',
#  'latches',
#  'staid',
#  'lazily',
#  'reeses',
#  'ok',
#  'zealanders',
#  'qualify',
#  'maggio',
#  'offset',
#  'wonders',
#  'sporting',
#  'antsy',
#  'fresher',
#  'brawny',
#  'simpson',
#  'comeuppance',
#  'collegiate',
#  'inspection',
#  'regalia',
#  'cleaner',
#  'forceful',
#  'unmemorable',
#  'aptly',
#  'track',
#  'gesture',
#  'bodily',
#  'manhunter',
#  'kuras',
#  'disturbed',
#  'leigh',
#  'wireless',
#  'ladles',
#  'conclusion',
#  'analyze',
#  'exploit',
#  'motion',
#  'bangbang',
#  'edges',
#  'clearasil',
#  'bigscreen',
#  'confused',
#  'governments',
#  'cynics',
#  'lessthanthrilling',
#  'aaa',
#  'learning',
#  'madefortv',
#  'aristocrat',
#  'mixing',
#  'grip',
#  'medem',
#  'patric',
#  'fictional',
#  'greg',
#  'daddy',
#  'barkingmad',
#  'lovefest',
#  'tidings',
#  'extended',
#  'undeniable',
#  'spied',
#  'elves',
#  'exchange',
#  'payami',
#  'midsection',
#  'shortcomings',
#  'gaitskills',
#  'technosex',
#  'second',
#  'collegefriends',
#  'cooly',
#  'shag',
#  'howler',
#  'escaped',
#  'installments',
#  'dealing',
#  '1958',
#  'sopranos',
#  'runofthefilth',
#  'religions',
#  'daydreams',
#  'fogging',
#  'engulfed',
#  'ironically',
#  'sound',
#  'fudged',
#  'feardotcomcom',
#  'femalebonding',
#  'dip',
#  'lie',
#  'openmouthed',
#  'frustratingly',
#  'shearer',
#  'overstuffed',
#  'max',
#  'harmless',
#  'overshadowed',
#  'fastballs',
#  'tians',
#  'wizened',
#  'basic',
#  'civil',
#  'undercurrent',
#  'treasured',
#  'apart',
#  'downtime',
#  'smartly',
#  'broaches',
#  'anarchic',
#  'clueless',
#  'avary',
#  'scares',
#  'overture',
#  'torn',
#  'handled',
#  'yarnspinner',
#  'marginal',
#  'skills',
#  'civilization',
#  'learn',
#  'bangthedrum',
#  'emerging',
#  'conspicuously',
#  'megalomaniac',
#  'eventually',
#  'peoples',
#  'erotic',
#  'numbers',
#  'suggests',
#  'beenthere',
#  'contentedly',
#  'competence',
#  'unique',
#  'locale',
#  'rampant',
#  'collateral',
#  'riviera',
#  'excites',
#  'times',
#  'empathy',
#  'deep',
#  'wonderfully',
#  'rises',
#  'skateboard',
#  'duly',
#  'wicked',
#  'beg',
#  'gained',
#  'scathingly',
#  'composed',
#  'despairingly',
#  'hayek',
#  'collapses',
#  'stereo',
#  'goodnatured',
#  'object',
#  'impacts',
#  'asks',
#  'heartwrenching',
#  'soar',
#  'impudent',
#  'heroism',
#  'sarandon',
#  'deception',
#  'cloyingly',
#  'q',
#  'establishing',
#  'cumulative',
#  'eastwoods',
#  'wishing',
#  'disabled',
#  'sensuality',
#  'steadfast',
#  'nutty',
#  'pork',
#  'cry',
#  'demeanour',
#  'darkaspitch',
#  'cipher',
#  'odoriferous',
#  'classic',
#  'print',
#  'twodrinkminimum',
#  'purpose',
#  'glasses',
#  'trickster',
#  'assess',
#  'worlds',
#  'deckhand',
#  'redundant',
#  'fighter',
#  'rarity',
#  'frustration',
#  'murderer',
#  'sap',
#  'bunch',
#  'submusic',
#  'faltering',
#  'reek',
#  'quality',
#  'males',
#  'plympton',
#  'wai',
#  'punchdrunk',
#  'acknowledging',
#  'fest',
#  'cloak',
#  'riffs',
#  'antiwar',
#  'lola',
#  'home',
#  'villains',
#  'wobbly',
#  'rolled',
#  'pap',
#  'goodnaturedness',
#  'poopoo',
#  'irish',
#  'praiseworthy',
#  'graves',
#  'overburdened',
#  '100minute',
#  'splashing',
#  'succeeds',
#  'starproducer',
#  'reid',
#  'mary',
#  'silverhaired',
#  'cd',
#  'kidnapper',
#  'breathing',
#  'ganeshs',
#  'humane',
#  'canadians',
#  'luke',
#  'unrequited',
#  'budding',
#  'disintegrates',
#  'dominated',
#  'mass',
#  'possibly',
#  'though',
#  'hal',
#  'policy',
#  'drag',
#  'seller',
#  'ache',
#  'chilly',
#  'dv',
#  'optic',
#  'features',
#  'qual',
#  'believed',
#  'autobiographical',
#  'hawk',
#  'wounded',
#  'toys',
#  'filmmakers',
#  'yoda',
#  'fearlessly',
#  'slew',
#  'cheapo',
#  'recreational',
#  'mud',
#  'gordy',
#  'nationalism',
#  'rode',
#  'snowman',
#  'bull',
#  'phonograph',
#  'indulgent',
#  'rich',
#  'depend',
#  'captive',
#  'captivated',
#  'mythmaking',
#  'dictates',
#  'shocked',
#  'kafkainspired',
#  'professional',
#  'comprehensible',
#  'side',
#  'sayles',
#  'gap',
#  'adrien',
#  'costumed',
#  'halfdimensional',
#  'onto',
#  'blushing',
#  'nights',
#  'jolting',
#  'politesse',
#  'daytimedrama',
#  'today',
#  'informs',
#  'chelsea',
#  'passionately',
#  'mcgraths',
#  'pastry',
#  'thornberry',
#  'recovered',
#  'adopt',
#  'topical',
#  'bonding',
#  'awash',
#  'stakes',
#  'dispel',
#  'lifeatarms',
#  'institutionalized',
#  'pulpiness',
#  'coping',
#  'nobody',
#  'views',
#  'lint',
#  '1959',
#  'chen',
#  'bust',
#  'assignment',
#  'cq',
#  'nearfuture',
#  'polemical',
#  'notorious',
#  'buff',
#  'transparently',
#  'reminds',
#  'majorleague',
#  'spoofy',
#  'closes',
#  'streets',
#  'appropriate',
#  'advert',
#  'smell',
#  'flood',
#  'admit',
#  'fixated',
#  'damage',
#  'purposeless',
#  'michelle',
#  'contrast',
#  'depraved',
#  'country',
#  'spotty',
#  'stops',
#  'manipulation',
#  'conquers',
#  'directtovoid',
#  'perrys',
#  'narcotized',
#  'asit',
#  'bypass',
#  'glow',
#  'graphic',
#  'hardedged',
#  'partly',
#  'flawed',
#  'unbelievable',
#  'analytical',
#  'ferret',
#  'absorbed',
#  'shimizu',
#  'wertmullers',
#  'fourhour',
#  'jules',
#  'george',
#  'iq',
#  'merchandisedtothemax',
#  'succumb',
#  'frodos',
#  'sobadthey',
#  'seduced',
#  'tarantinos',
#  'personified',
#  'flowering',
#  'distracts',
#  'releases',
#  'aesthetic',
#  'vincent',
#  'magnifique',
#  'carol',
#  'whoop',
#  'publicity',
#  'myriad',
#  'quarter',
#  'stud',
#  'stayed',
#  'lasting',
#  'mimetic',
#  'tykwer',
#  'alike',
#  'reading',
#  'unfulfilled',
#  'flattened',
#  'champion',
#  'firsttimer',
#  'specific',
#  'digs',
#  'minds',
#  'illiterate',
#  'styles',
#  'favorite',
#  'laziest',
#  'advertised',
#  'channeling',
#  'bit',
#  'underrated',
#  'der',
#  'inseparable',
#  'vividly',
#  'taylors',
#  'reminders',
#  'provocative',
#  'civic',
#  'pander',
#  'jon',
#  'regret',
#  'cheeks',
#  'nonjudgmentally',
#  'sunk',
#  'oppressive',
#  'brother',
#  'house',
#  'lunacy',
#  'main',
#  'ventures',
#  'interestingly',
#  'minute',
#  'lucia',
#  'slaps',
#  'hands',
#  'cycle',
#  'easier',
#  'clubs',
#  'thinksitis',
#  'anteing',
#  'pokey',
#  'ease',
#  'caper',
#  'aids',
#  'wellconstructed',
#  'remains',
#  'officer',
#  'ateam',
#  'mitch',
#  'twoway',
#  'impressed',
#  'avoids',
#  'sources',
#  'eke',
#  'adult',
#  'generosity',
#  'bickering',
#  'revitalize',
#  'moralizing',
#  'indoor',
#  'destination',
#  'robust',
#  'concentrate',
#  'determine',
#  'cloaked',
#  'iheardajoke',
#  'narratively',
#  'goose',
#  'technical',
#  'asleep',
#  'surround',
#  'petes',
#  'vera',
#  'vu',
#  'subgenres',
#  'truffaut',
#  'website',
#  'uniformly',
#  'erupt',
#  'sendak',
#  'offended',
#  'interminably',
#  'vega',
#  'hitandmiss',
#  'person',
#  'tribute',
#  'doors',
#  'demand',
#  'anyplace',
#  'sympathize',
#  'ability',
#  'converted',
#  'goosebumps',
#  'diction',
#  'onehour',
#  'provided',
#  'plane',
#  'bella',
#  'starving',
#  'startled',
#  'mar',
#  'comic',
#  'pay',
#  'objects',
#  'elmo',
#  'evident',
#  'plotline',
#  'beheadings',
#  'yes',
#  'tend',
#  'moronic',
#  'urbanity',
#  'silentmovie',
#  'message',
#  'staring',
#  'believable',
#  'statement',
#  'endear',
#  'skilfully',
#  'overwhelming',
#  'policeprocedural',
#  'killed',
#  'nijinskys',
#  'thewliss',
#  'selfempowering',
#  'tvmovie',
#  'yu',
#  'scattershot',
#  'establish',
#  'fearless',
#  'wonton',
#  'awkward',
#  'aldrich',
#  'norma',
#  'unadulterated',
#  'betting',
#  'refugee',
#  'guiltsuffused',
#  'paulette',
#  'tad',
#  'nickleby',
#  'discreet',
#  'goofiest',
#  'production',
#  'drang',
#  'dey',
#  'grim',
#  'alienation',
#  'mouth',
#  'paints',
#  ...}

# %%
intValue = {}

for i,word in enumerate(wordVec):
    intValue[word] = i

phrases = []
for phrase in corpus:
    phrases.append(phrase.split())
    
WINDOW_SIZE = 2

data = []
for sentence in phrases:
    for idx, word in enumerate(sentence):
        for neighbor in sentence[max(idx - WINDOW_SIZE, 0) : min(idx + WINDOW_SIZE, len(sentence)) + 1] : 
            if neighbor != word:
                data.append([word, neighbor])

# %%
intValue
# Out:
# {'needles': 0,
#  'brimming': 1,
#  'runon': 2,
#  'nearhypnotic': 3,
#  'impact': 4,
#  'sweep': 5,
#  'damon': 6,
#  'tragic': 7,
#  'sinister': 8,
#  'resident': 9,
#  'speck': 10,
#  'answers': 11,
#  'veretes': 12,
#  'showdon': 13,
#  '50million': 14,
#  'cookiecutter': 15,
#  'amalgam': 16,
#  'biggie': 17,
#  'sacre': 18,
#  'distorts': 19,
#  'longfaced': 20,
#  'carusos': 21,
#  'happen': 22,
#  'wahlberg': 23,
#  'deal': 24,
#  'favored': 25,
#  'scarifying': 26,
#  'kourys': 27,
#  'electric': 28,
#  'ruin': 29,
#  'nowheresville': 30,
#  'explanation': 31,
#  'actioncomedy': 32,
#  'screens': 33,
#  'dismal': 34,
#  'meditative': 35,
#  'shindlers': 36,
#  'guise': 37,
#  'rooted': 38,
#  'aging': 39,
#  'latest': 40,
#  'named': 41,
#  'vice': 42,
#  'squarely': 43,
#  'gore': 44,
#  'purposes': 45,
#  'rings': 46,
#  'utter': 47,
#  'ponderous': 48,
#  'nakata': 49,
#  'commenting': 50,
#  'irritates': 51,
#  'participatory': 52,
#  'reeks': 53,
#  'chuck': 54,
#  'dirgelike': 55,
#  'purdys': 56,
#  'cloying': 57,
#  'remarkable': 58,
#  'numbing': 59,
#  'smiths': 60,
#  'stink': 61,
#  'crikey': 62,
#  'diverting': 63,
#  'decade': 64,
#  'satirical': 65,
#  'trivializing': 66,
#  'schematic': 67,
#  'profundity': 68,
#  'commend': 69,
#  'abyss': 70,
#  'molehill': 71,
#  'snooze': 72,
#  'rated': 73,
#  'norton': 74,
#  'mourning': 75,
#  'banger': 76,
#  'item': 77,
#  'wills': 78,
#  'olympus': 79,
#  'wo': 80,
#  'concealment': 81,
#  'nickelodeonesque': 82,
#  'peculiar': 83,
#  'decasia': 84,
#  'place': 85,
#  'balk': 86,
#  'quasishakespearean': 87,
#  'numb': 88,
#  'scifi': 89,
#  'ambiguous': 90,
#  'diplomacy': 91,
#  'wearer': 92,
#  'pianist': 93,
#  'recipe': 94,
#  'bronx': 95,
#  'unadorned': 96,
#  'loneliest': 97,
#  'hoods': 98,
#  'wrapped': 99,
#  'hideousness': 100,
#  'profoundly': 101,
#  'trades': 102,
#  'friel': 103,
#  'grisham': 104,
#  'madonnas': 105,
#  'pinned': 106,
#  'argument': 107,
#  'undo': 108,
#  'lot': 109,
#  'oddly': 110,
#  'revives': 111,
#  'package': 112,
#  'bigbudgetallstar': 113,
#  'passer': 114,
#  'hanukkah': 115,
#  'hannibal': 116,
#  'absorbing': 117,
#  'zap': 118,
#  'razzledazzle': 119,
#  'unfairly': 120,
#  'sewage': 121,
#  'pat': 122,
#  'tufanos': 123,
#  'enjoy': 124,
#  'studios': 125,
#  'albeit': 126,
#  'demeanor': 127,
#  'individuality': 128,
#  'showbiz': 129,
#  'converts': 130,
#  'respite': 131,
#  'appetizing': 132,
#  'players': 133,
#  'guarantee': 134,
#  'highadrenaline': 135,
#  'reigen': 136,
#  'begun': 137,
#  'psychologizing': 138,
#  'holding': 139,
#  'populating': 140,
#  'hopkins': 141,
#  'identification': 142,
#  'rarely': 143,
#  'raging': 144,
#  'moldering': 145,
#  'demme': 146,
#  'six': 147,
#  'marylouise': 148,
#  'traffic': 149,
#  'ong': 150,
#  'venturesome': 151,
#  'sportsmovie': 152,
#  'playwright': 153,
#  'sam': 154,
#  'psychiatrist': 155,
#  'half': 156,
#  'surveillance': 157,
#  'rewritten': 158,
#  'sloppy': 159,
#  'snaps': 160,
#  'improbabilities': 161,
#  'scrutinize': 162,
#  'copycat': 163,
#  'vs': 164,
#  'eventual': 165,
#  'goo': 166,
#  'admission': 167,
#  'cover': 168,
#  'computeranimated': 169,
#  'chronicles': 170,
#  'sparkling': 171,
#  'apple': 172,
#  'amaris': 173,
#  'holden': 174,
#  'scotts': 175,
#  'geriatric': 176,
#  'schnieder': 177,
#  'warmest': 178,
#  'despair': 179,
#  'reggios': 180,
#  'tackles': 181,
#  'learns': 182,
#  'dimensions': 183,
#  'krawczyk': 184,
#  'connect': 185,
#  'somewhat': 186,
#  'social': 187,
#  'sica': 188,
#  'winces': 189,
#  'indignant': 190,
#  'ups': 191,
#  'reversal': 192,
#  'steals': 193,
#  'espionage': 194,
#  'locales': 195,
#  'internal': 196,
#  'duvall': 197,
#  'ram': 198,
#  'buscemi': 199,
#  'selfdetermination': 200,
#  'synthetic': 201,
#  'sucker': 202,
#  'admirably': 203,
#  'rice': 204,
#  'baio': 205,
#  'deceptions': 206,
#  'crowd': 207,
#  '45ths': 208,
#  'scherfig': 209,
#  'attics': 210,
#  'pained': 211,
#  'close': 212,
#  'catalytic': 213,
#  'artist': 214,
#  'gritty': 215,
#  'temporal': 216,
#  'cowrote': 217,
#  'grayish': 218,
#  'master': 219,
#  'onenote': 220,
#  'rodriguess': 221,
#  'undone': 222,
#  'truckzilla': 223,
#  'script': 224,
#  'allow': 225,
#  'actioner': 226,
#  'caretakers': 227,
#  'triessohardtobecool': 228,
#  'timeitis': 229,
#  'hundred': 230,
#  'consciousness': 231,
#  'trueblue': 232,
#  'malleable': 233,
#  'independence': 234,
#  'rubbo': 235,
#  'suspenser': 236,
#  'worst': 237,
#  'shlockmeister': 238,
#  'curmudgeonly': 239,
#  'call': 240,
#  'writer': 241,
#  'captures': 242,
#  'mistress': 243,
#  '60': 244,
#  '2day': 245,
#  'dazed': 246,
#  'goal': 247,
#  'exasperatingly': 248,
#  'forcefully': 249,
#  'dour': 250,
#  'typifies': 251,
#  'paycheck': 252,
#  'bedeviled': 253,
#  'premise': 254,
#  'gunfight': 255,
#  'first': 256,
#  'balance': 257,
#  'innovative': 258,
#  'fabricated': 259,
#  'remote': 260,
#  'enlightened': 261,
#  'concrete': 262,
#  'kirshner': 263,
#  'jampacked': 264,
#  'vectors': 265,
#  'promotion': 266,
#  'carlitos': 267,
#  'temptingly': 268,
#  'messy': 269,
#  'compendium': 270,
#  'province': 271,
#  'derisions': 272,
#  'astronomically': 273,
#  'alloverthemap': 274,
#  'lingers': 275,
#  'outweigh': 276,
#  'junior': 277,
#  'revelatory': 278,
#  'ambivalent': 279,
#  'hilarious': 280,
#  'worldatlarge': 281,
#  'wig': 282,
#  'characterized': 283,
#  'insomnia': 284,
#  'dispossessed': 285,
#  'jersey': 286,
#  'among': 287,
#  'tame': 288,
#  'subzero': 289,
#  'sociopath': 290,
#  'columbine': 291,
#  'conceited': 292,
#  'commanding': 293,
#  'resides': 294,
#  'mainstream': 295,
#  'smoking': 296,
#  'juwanna': 297,
#  'suffice': 298,
#  'strike': 299,
#  'period': 300,
#  'sirk': 301,
#  'scientist': 302,
#  'rhetoric': 303,
#  'bakers': 304,
#  'mishmash': 305,
#  'ben': 306,
#  'grossly': 307,
#  'similarly': 308,
#  'splash': 309,
#  'hopefully': 310,
#  'distinguishes': 311,
#  'beast': 312,
#  'lodging': 313,
#  'work': 314,
#  'bugged': 315,
#  'rhames': 316,
#  'tremendous': 317,
#  'thi': 318,
#  'precisely': 319,
#  'dogtown': 320,
#  'demographics': 321,
#  'allied': 322,
#  'full': 323,
#  '100': 324,
#  'waters': 325,
#  'accurately': 326,
#  'harvesting': 327,
#  'graduated': 328,
#  'scarlets': 329,
#  'genocide': 330,
#  'messagemovie': 331,
#  'cuisine': 332,
#  'mrs': 333,
#  'populates': 334,
#  'soapopera': 335,
#  'delay': 336,
#  'secretary': 337,
#  'straightshooting': 338,
#  'heroes': 339,
#  'threetoone': 340,
#  'stew': 341,
#  'whiteonblack': 342,
#  'joke': 343,
#  'mercy': 344,
#  'common': 345,
#  'ash': 346,
#  'alternately': 347,
#  'exhilaratingly': 348,
#  'envelops': 349,
#  'costly': 350,
#  'invulnerable': 351,
#  'thin': 352,
#  'genrebusting': 353,
#  'unlimited': 354,
#  'thus': 355,
#  'inspiring': 356,
#  'subplots': 357,
#  'femme': 358,
#  'unexpectedly': 359,
#  'organized': 360,
#  'preposterousness': 361,
#  'grimace': 362,
#  'notwithstanding': 363,
#  'somewhere': 364,
#  'complications': 365,
#  'schemes': 366,
#  'graffiti': 367,
#  'quickcuts': 368,
#  'stamp': 369,
#  'happens': 370,
#  'russo': 371,
#  'scariest': 372,
#  'sitcom': 373,
#  'lists': 374,
#  'relaxed': 375,
#  'snoozer': 376,
#  'climate': 377,
#  'adorns': 378,
#  'realization': 379,
#  'trombone': 380,
#  'masses': 381,
#  'ranges': 382,
#  'evaluate': 383,
#  'cards': 384,
#  'uppity': 385,
#  'giannini': 386,
#  'cad': 387,
#  'decoder': 388,
#  'gratefully': 389,
#  'proves': 390,
#  'waxes': 391,
#  'hawaiian': 392,
#  'solemnity': 393,
#  'jr': 394,
#  'clunkiness': 395,
#  'gun': 396,
#  'naturalism': 397,
#  'ferocity': 398,
#  'veggietales': 399,
#  'useless': 400,
#  'acted': 401,
#  'fabian': 402,
#  'timekiller': 403,
#  'craig': 404,
#  'creations': 405,
#  'surge': 406,
#  'sessions': 407,
#  'farcically': 408,
#  'winter': 409,
#  'without': 410,
#  'chain': 411,
#  'recovering': 412,
#  'kevin': 413,
#  'prescription': 414,
#  'roughage': 415,
#  'requiring': 416,
#  'disconnection': 417,
#  'professionals': 418,
#  'continuum': 419,
#  'weaknesses': 420,
#  'greater': 421,
#  'selfsatisfaction': 422,
#  'gaiety': 423,
#  'emotional': 424,
#  'marilyn': 425,
#  'selfreferential': 426,
#  'cinema': 427,
#  'davies': 428,
#  'anyones': 429,
#  'superficiale': 430,
#  'wearisome': 431,
#  'witty': 432,
#  'trace': 433,
#  'contemptuous': 434,
#  'exceptional': 435,
#  'limbo': 436,
#  'stomach': 437,
#  'selfinflicted': 438,
#  'removed': 439,
#  'collegespawned': 440,
#  'wordless': 441,
#  'somehow': 442,
#  'terminally': 443,
#  'deserves': 444,
#  'acting': 445,
#  'comedian': 446,
#  'crossingover': 447,
#  'mistakenidentity': 448,
#  'james': 449,
#  'interdependence': 450,
#  'radiates': 451,
#  'lantern': 452,
#  'prima': 453,
#  'benigni': 454,
#  'serious': 455,
#  'latches': 456,
#  'staid': 457,
#  'lazily': 458,
#  'reeses': 459,
#  'ok': 460,
#  'zealanders': 461,
#  'qualify': 462,
#  'maggio': 463,
#  'offset': 464,
#  'wonders': 465,
#  'sporting': 466,
#  'antsy': 467,
#  'fresher': 468,
#  'brawny': 469,
#  'simpson': 470,
#  'comeuppance': 471,
#  'collegiate': 472,
#  'inspection': 473,
#  'regalia': 474,
#  'cleaner': 475,
#  'forceful': 476,
#  'unmemorable': 477,
#  'aptly': 478,
#  'track': 479,
#  'gesture': 480,
#  'bodily': 481,
#  'manhunter': 482,
#  'kuras': 483,
#  'disturbed': 484,
#  'leigh': 485,
#  'wireless': 486,
#  'ladles': 487,
#  'conclusion': 488,
#  'analyze': 489,
#  'exploit': 490,
#  'motion': 491,
#  'bangbang': 492,
#  'edges': 493,
#  'clearasil': 494,
#  'bigscreen': 495,
#  'confused': 496,
#  'governments': 497,
#  'cynics': 498,
#  'lessthanthrilling': 499,
#  'aaa': 500,
#  'learning': 501,
#  'madefortv': 502,
#  'aristocrat': 503,
#  'mixing': 504,
#  'grip': 505,
#  'medem': 506,
#  'patric': 507,
#  'fictional': 508,
#  'greg': 509,
#  'daddy': 510,
#  'barkingmad': 511,
#  'lovefest': 512,
#  'tidings': 513,
#  'extended': 514,
#  'undeniable': 515,
#  'spied': 516,
#  'elves': 517,
#  'exchange': 518,
#  'payami': 519,
#  'midsection': 520,
#  'shortcomings': 521,
#  'gaitskills': 522,
#  'technosex': 523,
#  'second': 524,
#  'collegefriends': 525,
#  'cooly': 526,
#  'shag': 527,
#  'howler': 528,
#  'escaped': 529,
#  'installments': 530,
#  'dealing': 531,
#  '1958': 532,
#  'sopranos': 533,
#  'runofthefilth': 534,
#  'religions': 535,
#  'daydreams': 536,
#  'fogging': 537,
#  'engulfed': 538,
#  'ironically': 539,
#  'sound': 540,
#  'fudged': 541,
#  'feardotcomcom': 542,
#  'femalebonding': 543,
#  'dip': 544,
#  'lie': 545,
#  'openmouthed': 546,
#  'frustratingly': 547,
#  'shearer': 548,
#  'overstuffed': 549,
#  'max': 550,
#  'harmless': 551,
#  'overshadowed': 552,
#  'fastballs': 553,
#  'tians': 554,
#  'wizened': 555,
#  'basic': 556,
#  'civil': 557,
#  'undercurrent': 558,
#  'treasured': 559,
#  'apart': 560,
#  'downtime': 561,
#  'smartly': 562,
#  'broaches': 563,
#  'anarchic': 564,
#  'clueless': 565,
#  'avary': 566,
#  'scares': 567,
#  'overture': 568,
#  'torn': 569,
#  'handled': 570,
#  'yarnspinner': 571,
#  'marginal': 572,
#  'skills': 573,
#  'civilization': 574,
#  'learn': 575,
#  'bangthedrum': 576,
#  'emerging': 577,
#  'conspicuously': 578,
#  'megalomaniac': 579,
#  'eventually': 580,
#  'peoples': 581,
#  'erotic': 582,
#  'numbers': 583,
#  'suggests': 584,
#  'beenthere': 585,
#  'contentedly': 586,
#  'competence': 587,
#  'unique': 588,
#  'locale': 589,
#  'rampant': 590,
#  'collateral': 591,
#  'riviera': 592,
#  'excites': 593,
#  'times': 594,
#  'empathy': 595,
#  'deep': 596,
#  'wonderfully': 597,
#  'rises': 598,
#  'skateboard': 599,
#  'duly': 600,
#  'wicked': 601,
#  'beg': 602,
#  'gained': 603,
#  'scathingly': 604,
#  'composed': 605,
#  'despairingly': 606,
#  'hayek': 607,
#  'collapses': 608,
#  'stereo': 609,
#  'goodnatured': 610,
#  'object': 611,
#  'impacts': 612,
#  'asks': 613,
#  'heartwrenching': 614,
#  'soar': 615,
#  'impudent': 616,
#  'heroism': 617,
#  'sarandon': 618,
#  'deception': 619,
#  'cloyingly': 620,
#  'q': 621,
#  'establishing': 622,
#  'cumulative': 623,
#  'eastwoods': 624,
#  'wishing': 625,
#  'disabled': 626,
#  'sensuality': 627,
#  'steadfast': 628,
#  'nutty': 629,
#  'pork': 630,
#  'cry': 631,
#  'demeanour': 632,
#  'darkaspitch': 633,
#  'cipher': 634,
#  'odoriferous': 635,
#  'classic': 636,
#  'print': 637,
#  'twodrinkminimum': 638,
#  'purpose': 639,
#  'glasses': 640,
#  'trickster': 641,
#  'assess': 642,
#  'worlds': 643,
#  'deckhand': 644,
#  'redundant': 645,
#  'fighter': 646,
#  'rarity': 647,
#  'frustration': 648,
#  'murderer': 649,
#  'sap': 650,
#  'bunch': 651,
#  'submusic': 652,
#  'faltering': 653,
#  'reek': 654,
#  'quality': 655,
#  'males': 656,
#  'plympton': 657,
#  'wai': 658,
#  'punchdrunk': 659,
#  'acknowledging': 660,
#  'fest': 661,
#  'cloak': 662,
#  'riffs': 663,
#  'antiwar': 664,
#  'lola': 665,
#  'home': 666,
#  'villains': 667,
#  'wobbly': 668,
#  'rolled': 669,
#  'pap': 670,
#  'goodnaturedness': 671,
#  'poopoo': 672,
#  'irish': 673,
#  'praiseworthy': 674,
#  'graves': 675,
#  'overburdened': 676,
#  '100minute': 677,
#  'splashing': 678,
#  'succeeds': 679,
#  'starproducer': 680,
#  'reid': 681,
#  'mary': 682,
#  'silverhaired': 683,
#  'cd': 684,
#  'kidnapper': 685,
#  'breathing': 686,
#  'ganeshs': 687,
#  'humane': 688,
#  'canadians': 689,
#  'luke': 690,
#  'unrequited': 691,
#  'budding': 692,
#  'disintegrates': 693,
#  'dominated': 694,
#  'mass': 695,
#  'possibly': 696,
#  'though': 697,
#  'hal': 698,
#  'policy': 699,
#  'drag': 700,
#  'seller': 701,
#  'ache': 702,
#  'chilly': 703,
#  'dv': 704,
#  'optic': 705,
#  'features': 706,
#  'qual': 707,
#  'believed': 708,
#  'autobiographical': 709,
#  'hawk': 710,
#  'wounded': 711,
#  'toys': 712,
#  'filmmakers': 713,
#  'yoda': 714,
#  'fearlessly': 715,
#  'slew': 716,
#  'cheapo': 717,
#  'recreational': 718,
#  'mud': 719,
#  'gordy': 720,
#  'nationalism': 721,
#  'rode': 722,
#  'snowman': 723,
#  'bull': 724,
#  'phonograph': 725,
#  'indulgent': 726,
#  'rich': 727,
#  'depend': 728,
#  'captive': 729,
#  'captivated': 730,
#  'mythmaking': 731,
#  'dictates': 732,
#  'shocked': 733,
#  'kafkainspired': 734,
#  'professional': 735,
#  'comprehensible': 736,
#  'side': 737,
#  'sayles': 738,
#  'gap': 739,
#  'adrien': 740,
#  'costumed': 741,
#  'halfdimensional': 742,
#  'onto': 743,
#  'blushing': 744,
#  'nights': 745,
#  'jolting': 746,
#  'politesse': 747,
#  'daytimedrama': 748,
#  'today': 749,
#  'informs': 750,
#  'chelsea': 751,
#  'passionately': 752,
#  'mcgraths': 753,
#  'pastry': 754,
#  'thornberry': 755,
#  'recovered': 756,
#  'adopt': 757,
#  'topical': 758,
#  'bonding': 759,
#  'awash': 760,
#  'stakes': 761,
#  'dispel': 762,
#  'lifeatarms': 763,
#  'institutionalized': 764,
#  'pulpiness': 765,
#  'coping': 766,
#  'nobody': 767,
#  'views': 768,
#  'lint': 769,
#  '1959': 770,
#  'chen': 771,
#  'bust': 772,
#  'assignment': 773,
#  'cq': 774,
#  'nearfuture': 775,
#  'polemical': 776,
#  'notorious': 777,
#  'buff': 778,
#  'transparently': 779,
#  'reminds': 780,
#  'majorleague': 781,
#  'spoofy': 782,
#  'closes': 783,
#  'streets': 784,
#  'appropriate': 785,
#  'advert': 786,
#  'smell': 787,
#  'flood': 788,
#  'admit': 789,
#  'fixated': 790,
#  'damage': 791,
#  'purposeless': 792,
#  'michelle': 793,
#  'contrast': 794,
#  'depraved': 795,
#  'country': 796,
#  'spotty': 797,
#  'stops': 798,
#  'manipulation': 799,
#  'conquers': 800,
#  'directtovoid': 801,
#  'perrys': 802,
#  'narcotized': 803,
#  'asit': 804,
#  'bypass': 805,
#  'glow': 806,
#  'graphic': 807,
#  'hardedged': 808,
#  'partly': 809,
#  'flawed': 810,
#  'unbelievable': 811,
#  'analytical': 812,
#  'ferret': 813,
#  'absorbed': 814,
#  'shimizu': 815,
#  'wertmullers': 816,
#  'fourhour': 817,
#  'jules': 818,
#  'george': 819,
#  'iq': 820,
#  'merchandisedtothemax': 821,
#  'succumb': 822,
#  'frodos': 823,
#  'sobadthey': 824,
#  'seduced': 825,
#  'tarantinos': 826,
#  'personified': 827,
#  'flowering': 828,
#  'distracts': 829,
#  'releases': 830,
#  'aesthetic': 831,
#  'vincent': 832,
#  'magnifique': 833,
#  'carol': 834,
#  'whoop': 835,
#  'publicity': 836,
#  'myriad': 837,
#  'quarter': 838,
#  'stud': 839,
#  'stayed': 840,
#  'lasting': 841,
#  'mimetic': 842,
#  'tykwer': 843,
#  'alike': 844,
#  'reading': 845,
#  'unfulfilled': 846,
#  'flattened': 847,
#  'champion': 848,
#  'firsttimer': 849,
#  'specific': 850,
#  'digs': 851,
#  'minds': 852,
#  'illiterate': 853,
#  'styles': 854,
#  'favorite': 855,
#  'laziest': 856,
#  'advertised': 857,
#  'channeling': 858,
#  'bit': 859,
#  'underrated': 860,
#  'der': 861,
#  'inseparable': 862,
#  'vividly': 863,
#  'taylors': 864,
#  'reminders': 865,
#  'provocative': 866,
#  'civic': 867,
#  'pander': 868,
#  'jon': 869,
#  'regret': 870,
#  'cheeks': 871,
#  'nonjudgmentally': 872,
#  'sunk': 873,
#  'oppressive': 874,
#  'brother': 875,
#  'house': 876,
#  'lunacy': 877,
#  'main': 878,
#  'ventures': 879,
#  'interestingly': 880,
#  'minute': 881,
#  'lucia': 882,
#  'slaps': 883,
#  'hands': 884,
#  'cycle': 885,
#  'easier': 886,
#  'clubs': 887,
#  'thinksitis': 888,
#  'anteing': 889,
#  'pokey': 890,
#  'ease': 891,
#  'caper': 892,
#  'aids': 893,
#  'wellconstructed': 894,
#  'remains': 895,
#  'officer': 896,
#  'ateam': 897,
#  'mitch': 898,
#  'twoway': 899,
#  'impressed': 900,
#  'avoids': 901,
#  'sources': 902,
#  'eke': 903,
#  'adult': 904,
#  'generosity': 905,
#  'bickering': 906,
#  'revitalize': 907,
#  'moralizing': 908,
#  'indoor': 909,
#  'destination': 910,
#  'robust': 911,
#  'concentrate': 912,
#  'determine': 913,
#  'cloaked': 914,
#  'iheardajoke': 915,
#  'narratively': 916,
#  'goose': 917,
#  'technical': 918,
#  'asleep': 919,
#  'surround': 920,
#  'petes': 921,
#  'vera': 922,
#  'vu': 923,
#  'subgenres': 924,
#  'truffaut': 925,
#  'website': 926,
#  'uniformly': 927,
#  'erupt': 928,
#  'sendak': 929,
#  'offended': 930,
#  'interminably': 931,
#  'vega': 932,
#  'hitandmiss': 933,
#  'person': 934,
#  'tribute': 935,
#  'doors': 936,
#  'demand': 937,
#  'anyplace': 938,
#  'sympathize': 939,
#  'ability': 940,
#  'converted': 941,
#  'goosebumps': 942,
#  'diction': 943,
#  'onehour': 944,
#  'provided': 945,
#  'plane': 946,
#  'bella': 947,
#  'starving': 948,
#  'startled': 949,
#  'mar': 950,
#  'comic': 951,
#  'pay': 952,
#  'objects': 953,
#  'elmo': 954,
#  'evident': 955,
#  'plotline': 956,
#  'beheadings': 957,
#  'yes': 958,
#  'tend': 959,
#  'moronic': 960,
#  'urbanity': 961,
#  'silentmovie': 962,
#  'message': 963,
#  'staring': 964,
#  'believable': 965,
#  'statement': 966,
#  'endear': 967,
#  'skilfully': 968,
#  'overwhelming': 969,
#  'policeprocedural': 970,
#  'killed': 971,
#  'nijinskys': 972,
#  'thewliss': 973,
#  'selfempowering': 974,
#  'tvmovie': 975,
#  'yu': 976,
#  'scattershot': 977,
#  'establish': 978,
#  'fearless': 979,
#  'wonton': 980,
#  'awkward': 981,
#  'aldrich': 982,
#  'norma': 983,
#  'unadulterated': 984,
#  'betting': 985,
#  'refugee': 986,
#  'guiltsuffused': 987,
#  'paulette': 988,
#  'tad': 989,
#  'nickleby': 990,
#  'discreet': 991,
#  'goofiest': 992,
#  'production': 993,
#  'drang': 994,
#  'dey': 995,
#  'grim': 996,
#  'alienation': 997,
#  'mouth': 998,
#  'paints': 999,
#  ...}

# %%
df = pd.DataFrame(data, columns = ['input', 'label'])

# %%
df
# Out:
#             input          label
# 0          series      escapades
# 1          series  demonstrating
# 2       escapades         series
# 3       escapades  demonstrating
# 4       escapades          adage
# ...           ...            ...
# 267267  avuncular        hearsts
# 267268  avuncular         forced
# 267269  avuncular       chortles
# 267270   chortles         forced
# 267271   chortles      avuncular
#
# [267272 rows x 2 columns]

# %%
from tqdm import tqdm

# %%
import tensorflow as tf
one_hot_encoding = len(wordVec)
def encoder(index):
    hot_encoding = np.zeros(one_hot_encoding, dtype='uint8')
    hot_encoding[index] = 1
    return hot_encoding
input_word = []
target_word = []

for index, row in tqdm(df.iterrows(), total=df.shape[0]):
    input_word.append(encoder(intValue[row['input']]))
# Out:
# 100%|██████████| 267272/267272 [00:19<00:00, 13975.81it/s]

# %%
for index, row in tqdm(df.iterrows(), total=df.shape[0]):
    target_word.append(encoder(intValue[row['label']]))
# Out:
# 100%|██████████| 267272/267272 [00:18<00:00, 14303.04it/s]

# %%
len(input_word[0])
# Out:
# 16576

# %%
input_word_train = np.asarray(input_word)
target_word_train = np.asarray(target_word)

# %%
tf.compat.v1.disable_eager_execution()
inp_pl = tf.compat.v1.placeholder(tf.bfloat16, shape=(None, one_hot_encoding))
y_label = tf.compat.v1.placeholder(tf.bfloat16, shape=(None, one_hot_encoding))

# %%
weight_layer = tf.Variable(tf.random.normal([one_hot_encoding, 2]))
bias = tf.Variable(tf.random.normal([1]))

# %%
hidden_layer = tf.add(tf.matmul(inp_pl, weight_layer), bias)
# Out:
# WARNING:tensorflow:From C:\Users\andyv\anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3692: sparse_mat_mul (from tensorflow.python.ops.gen_math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.linalg.matmul` instead

# %%
weight_layer2 = tf.Variable(tf.random.normal([2, one_hot_encoding]))
bias2 = tf.Variable(tf.random.normal([1]))
pred = tf.nn.softmax(tf.add( tf.matmul(hidden_layer, weight_layer2), bias2))

# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

# %%
loss = tf.reduce_mean(-tf.reduce_sum(y_label * tf.math.log(pred), axis=[1]))
gradientDescent = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\andyv\movieSentiment\word2vec .ipynb Cell 28' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/andyv/movieSentiment/word2vec%20.ipynb#ch0000024?line=0'>1</a> loss = tf.reduce_mean(-tf.reduce_sum(y_label * tf.math.log(pred), axis=[1]))
#       <a href='vscode-notebook-cell:/c%3A/Users/andyv/movieSentiment/word2vec%20.ipynb#ch0000024?line=1'>2</a> gradientDescent = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=150'>151</a> except Exception as e:
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=151'>152</a>   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=152'>153</a>   raise e.with_traceback(filtered_tb) from None
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=153'>154</a> finally:
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/util/traceback_utils.py?line=154'>155</a>   del filtered_tb
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:546, in _apply_op_helper(op_type_name, name, **keywords)
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=542'>543</a>         if k not in inferred_from:
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=543'>544</a>           inferred_from[k] = "Default in OpDef"
# --> <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=545'>546</a>     raise TypeError(
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=546'>547</a>         f"{prefix} type "
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=547'>548</a>         f"{dtypes.as_dtype(attrs[input_arg.type_attr]).name} of "
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=548'>549</a>         f"argument '{inferred_from[input_arg.type_attr]}'.")
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=550'>551</a> types = [values.dtype]
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/framework/op_def_library.py?line=551'>552</a> inputs.append(values)
#
# TypeError: Input 'y' of 'Mul' Op has type float32 that does not match type bfloat16 of argument 'x'.

# %%
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

iteration = 100000
for i in range(iteration):
    sess.run(gradientDescent, feed_dict = {inp_pl: input_word_train, y_label: target_word_train})
    # if i % 3000 == 0:
    #     print('iteration ' + str(i) + ' loss is: ', sess.run(loss, feed_dict = {inp_pl: input_word_train, y_label: target_word_train}))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# c:\Users\andyv\movieSentiment\word2vec .ipynb Cell 29' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/c%3A/Users/andyv/movieSentiment/word2vec%20.ipynb#ch0000028?line=4'>5</a> iteration = 100000
#       <a href='vscode-notebook-cell:/c%3A/Users/andyv/movieSentiment/word2vec%20.ipynb#ch0000028?line=5'>6</a> for i in range(iteration):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/andyv/movieSentiment/word2vec%20.ipynb#ch0000028?line=6'>7</a>     sess.run(gradientDescent, feed_dict = {inp_pl: input_word_train, y_label: target_word_train})
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py:967, in BaseSession.run(self, fetches, feed_dict, options, run_metadata)
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=963'>964</a> run_metadata_ptr = tf_session.TF_NewBuffer() if run_metadata else None
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=965'>966</a> try:
# --> <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=966'>967</a>   result = self._run(None, fetches, feed_dict, options_ptr,
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=967'>968</a>                      run_metadata_ptr)
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=968'>969</a>   if run_metadata:
#     <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=969'>970</a>     proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\client\session.py:1160, in BaseSession._run(self, handle, fetches, feed_dict, options, run_metadata)
#    <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=1157'>1158</a>   feed_handles[subfeed_t.ref()] = subfeed_val
#    <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=1158'>1159</a> else:
# -> <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=1159'>1160</a>   np_val = np.asarray(subfeed_val, dtype=subfeed_dtype)
#    <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=1161'>1162</a> if (not is_tensor_handle_feed and
#    <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=1162'>1163</a>     not subfeed_t.get_shape().is_compatible_with(np_val.shape)):
#    <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=1163'>1164</a>   raise ValueError(
#    <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=1164'>1165</a>       f'Cannot feed value of shape {str(np_val.shape)} for Tensor '
#    <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=1165'>1166</a>       f'{subfeed_t.name}, which has shape '
#    <a href='file:///c%3A/Users/andyv/anaconda3/lib/site-packages/tensorflow/python/client/session.py?line=1166'>1167</a>       f'{str(subfeed_t.get_shape())}')
#
# MemoryError: Unable to allocate 16.5 GiB for an array with shape (267272, 16576) and data type float32

# %%
vectors = sess.run(weight_layer + bias)
