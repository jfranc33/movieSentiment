# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk # natural language tool kit

# %%
initialFrame = pd.read_csv('train.tsv', delimiter = '\t');
initialTestFrame = pd.read_csv('test 2.tsv', delimiter = '\t');

# %%
initialFrame
# Out:
#         PhraseId  SentenceId  \
# 0              1           1
# 1              2           1
# 2              3           1
# 3              4           1
# 4              5           1
# ...          ...         ...
# 156055    156056        8544
# 156056    156057        8544
# 156057    156058        8544
# 156058    156059        8544
# 156059    156060        8544
#
#                                                    Phrase  Sentiment
# 0       A series of escapades demonstrating the adage ...          1
# 1       A series of escapades demonstrating the adage ...          2
# 2                                                A series          2
# 3                                                       A          2
# 4                                                  series          2
# ...                                                   ...        ...
# 156055                                          Hearst 's          2
# 156056                          forced avuncular chortles          1
# 156057                                 avuncular chortles          3
# 156058                                          avuncular          2
# 156059                                           chortles          2
#
# [156060 rows x 4 columns]

# %%
initialTestFrame
# Out:
#        PhraseId  SentenceId                                             Phrase
# 0        156061        8545  An intermittently pleasing but mostly routine ...
# 1        156062        8545  An intermittently pleasing but mostly routine ...
# 2        156063        8545                                                 An
# 3        156064        8545  intermittently pleasing but mostly routine effort
# 4        156065        8545         intermittently pleasing but mostly routine
# ...         ...         ...                                                ...
# 66287    222348       11855             A long-winded , predictable scenario .
# 66288    222349       11855               A long-winded , predictable scenario
# 66289    222350       11855                                    A long-winded ,
# 66290    222351       11855                                      A long-winded
# 66291    222352       11855                               predictable scenario
#
# [66292 rows x 3 columns]

# %%
# Cleans the initial frame
def cleanInitialFrame(df):
    cleanList = [] # list to grow
    currentSentence = 0 # tracks current sentence
    sentenceIDs = {0} 
    # Iterate row by row
    for index, row in df.iterrows():
        # If it's the first element, add to list
        if (row['SentenceId'] == currentSentence):
            continue
        else:
            cleanList.append([row['PhraseId'], row['SentenceId'], row['Phrase'], row['Sentiment']]);
            currentSentence = row['SentenceId']
    
    # Return a clean frame
    return pd.DataFrame(cleanList, columns = ['PhraseId', 'SentenceId', 'Phrase', 'Sentiment'])

# %%
# Cleans the initial frame
def cleanInitialTestFrame(df):
    cleanList = [] # list to grow
    currentSentence = 0 # tracks current sentence
    sentenceIDs = {0} 
    # Iterate row by row
    for index, row in df.iterrows():
        # If it's the first element, add to list
        if (row['SentenceId'] == currentSentence):
            continue
        else:
            cleanList.append([row['PhraseId'], row['SentenceId'], row['Phrase']]);
            currentSentence = row['SentenceId']
    
    # Return a clean frame
    return pd.DataFrame(cleanList, columns = ['PhraseId', 'SentenceId', 'Phrase'])

# %%
df = cleanInitialFrame(initialFrame)
df.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1        64           2  This quiet , introspective and entertaining in...
# 2        82           3  Even fans of Ismail Merchant 's work , I suspe...
# 3       117           4  A positively thrilling combination of ethnogra...
# 4       157           5  Aggressive self-glorification and a manipulati...
#
#    Sentiment
# 0          1
# 1          4
# 2          1
# 3          3
# 4          1

# %%
testdf = cleanInitialTestFrame(initialTestFrame)
testdf.head()
# Out:
#    PhraseId  SentenceId                                             Phrase
# 0    156061        8545  An intermittently pleasing but mostly routine ...
# 1    156076        8546  Kidman is really the only thing that 's worth ...
# 2    156154        8547  Once you get into its rhythm ... the movie bec...
# 3    156178        8548  I kept wishing I was watching a documentary ab...
# 4    156219        8549  Kinnear does n't aim for our sympathy , but ra...

# %%
def lowerAllPhrases(df):
    phrases_list = list(df['Phrase'])

    for i in range(len(phrases_list)):
        phrases_list[i] = phrases_list[i].lower()
    count = 0;
    for index, row in df.iterrows():
        df.at[index,'Phrase'] = phrases_list[count]
        count += 1

    return df

# %%
lowerAllPhrases(df)
df.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  a series of escapades demonstrating the adage ...
# 1        64           2  this quiet , introspective and entertaining in...
# 2        82           3  even fans of ismail merchant 's work , i suspe...
# 3       117           4  a positively thrilling combination of ethnogra...
# 4       157           5  aggressive self-glorification and a manipulati...
#
#    Sentiment
# 0          1
# 1          4
# 2          1
# 3          3
# 4          1

# %%
lowerAllPhrases(testdf)
testdf.head()
# Out:
#    PhraseId  SentenceId                                             Phrase
# 0    156061        8545  an intermittently pleasing but mostly routine ...
# 1    156076        8546  kidman is really the only thing that 's worth ...
# 2    156154        8547  once you get into its rhythm ... the movie bec...
# 3    156178        8548  i kept wishing i was watching a documentary ab...
# 4    156219        8549  kinnear does n't aim for our sympathy , but ra...

# %%
# Remove non-ascii characters using str.replace()
def asciiClean(df):
    # iterate row by row
    for index, row in df.iterrows():
        old_str = row['Phrase']
        new_str = (old_str.encode('ascii','ignore')).decode()
        df.at[index, 'Phrase'] = new_str

# %%
asciiClean(df)
df.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  a series of escapades demonstrating the adage ...
# 1        64           2  this quiet , introspective and entertaining in...
# 2        82           3  even fans of ismail merchant 's work , i suspe...
# 3       117           4  a positively thrilling combination of ethnogra...
# 4       157           5  aggressive self-glorification and a manipulati...
#
#    Sentiment
# 0          1
# 1          4
# 2          1
# 3          3
# 4          1

# %%
asciiClean(testdf)
testdf.head()
# Out:
#    PhraseId  SentenceId                                             Phrase
# 0    156061        8545  an intermittently pleasing but mostly routine ...
# 1    156076        8546  kidman is really the only thing that 's worth ...
# 2    156154        8547  once you get into its rhythm ... the movie bec...
# 3    156178        8548  i kept wishing i was watching a documentary ab...
# 4    156219        8549  kinnear does n't aim for our sympathy , but ra...

# %%
df[0:10]
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  a series of escapades demonstrating the adage ...
# 1        64           2  this quiet , introspective and entertaining in...
# 2        82           3  even fans of ismail merchant 's work , i suspe...
# 3       117           4  a positively thrilling combination of ethnogra...
# 4       157           5  aggressive self-glorification and a manipulati...
# 5       167           6  a comedy-drama of nearly epic proportions root...
# 6       199           7  narratively , trouble every day is a plodding ...
# 7       214           8  the importance of being earnest , so thick wit...
# 8       248           9              but it does n't leave you with much .
# 9       260          10            you could hate it for the same reason .
#
#    Sentiment
# 0          1
# 1          4
# 2          1
# 3          3
# 4          1
# 5          4
# 6          1
# 7          3
# 8          1
# 9          1

# %%
import re
def removeSpaces(df):
    for index, row in df.iterrows():
        # df['Phrase'] = df['Phrase'].replace([row['Phrase']], re.sub(r'\s+\'', "'", row['Phrase']))
        df.at[index,'Phrase'] = re.sub(r'\s+\'', "'", row['Phrase'])

# %%
removeSpaces(df)

# %%
removeSpaces(testdf)

# %%
df[0:10]
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  a series of escapades demonstrating the adage ...
# 1        64           2  this quiet , introspective and entertaining in...
# 2        82           3  even fans of ismail merchant's work , i suspec...
# 3       117           4  a positively thrilling combination of ethnogra...
# 4       157           5  aggressive self-glorification and a manipulati...
# 5       167           6  a comedy-drama of nearly epic proportions root...
# 6       199           7  narratively , trouble every day is a plodding ...
# 7       214           8  the importance of being earnest , so thick wit...
# 8       248           9              but it does n't leave you with much .
# 9       260          10            you could hate it for the same reason .
#
#    Sentiment
# 0          1
# 1          4
# 2          1
# 3          3
# 4          1
# 5          4
# 6          1
# 7          3
# 8          1
# 9          1

# %%
import contractions
contractions.add('n\'t', 'not')
def expandContractions(df):
    for index, row in df.iterrows():
        phrase = []
        for i in row['Phrase'].split():
            phrase.append(contractions.fix(i))
        string_version = ' '.join(phrase)
        df.at[index, 'Phrase'] = string_version

# %%
expandContractions(df)

# %%
expandContractions(testdf)

# %%
import string
def removePunctuation(df):
    regex = re.compile('[%s]' % re.escape(string.punctuation))
    for index,row in df.iterrows():
        phrase = []
        for i in row['Phrase'].split():
            phrase.append(regex.sub('', i))
        string_version = ' '.join(phrase)
        df.at[index, 'Phrase'] = string_version

# %%
removePunctuation(df)

# %%
removePunctuation(testdf)

# %%
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.tokenize.treebank import TreebankWordDetokenizer
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Allen\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Allen\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def removeStopWords(df):
    
    phrases_list = list(df['Phrase'])
    stop_words = set(stopwords.words('english'))

    for i in range(len(phrases_list)):
        word_tokens = word_tokenize(phrases_list[i])
        filtered_sentence = [w for w in word_tokens if not w.lower() in stop_words]
        filtered_sentence = []
        for w in word_tokens:
            if w not in stop_words:
                filtered_sentence.append(w)
        phrases_list[i] = filtered_sentence
    
    for i in range(len(phrases_list)):
        phrases_list[i] = TreebankWordDetokenizer().detokenize(phrases_list[i])
    
    count = 0
    for index, row in df.iterrows():
        # df['Phrase'] = df['Phrase'].replace([row['Phrase']], phrases_list[count])
        df.at[index, 'Phrase'] = phrases_list[count]
        count += 1

    return df

# %%
df.head(10)
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  a series of escapades demonstrating the adage ...
# 1        64           2  this quiet  introspective and entertaining ind...
# 2        82           3  even fans of ismail merchants work  i suspect ...
# 3       117           4  a positively thrilling combination of ethnogra...
# 4       157           5  aggressive selfglorification and a manipulativ...
# 5       167           6  a comedydrama of nearly epic proportions roote...
# 6       199           7  narratively  trouble every day is a plodding m...
# 7       214           8  the importance of being earnest  so thick with...
# 8       248           9               but it does not leave you with much
# 9       260          10             you could hate it for the same reason
#
#    Sentiment
# 0          1
# 1          4
# 2          1
# 3          3
# 4          1
# 5          4
# 6          1
# 7          3
# 8          1
# 9          1

# %%
df = removeStopWords(df)
df.head(10)
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  series escapades demonstrating adage good goos...
# 1        64           2  quiet introspective entertaining independent w...
# 2        82           3  even fans ismail merchants work suspect would ...
# 3       117           4  positively thrilling combination ethnography i...
# 4       157           5  aggressive selfglorification manipulative whit...
# 5       167           6  comedydrama nearly epic proportions rooted sin...
# 6       199           7        narratively trouble every day plodding mess
# 7       214           8  importance earnest thick wit plays like readin...
# 8       248           9                                         leave much
# 9       260          10                                  could hate reason
#
#    Sentiment
# 0          1
# 1          4
# 2          1
# 3          3
# 4          1
# 5          4
# 6          1
# 7          3
# 8          1
# 9          1

# %%
testdf = removeStopWords(testdf)
testdf.head(10)
# Out:
#    PhraseId  SentenceId                                             Phrase
# 0    156061        8545      intermittently pleasing mostly routine effort
# 1    156076        8546  kidman really thing worth watching birthday gi...
# 2    156154        8547          get rhythm movie becomes heady experience
# 3    156178        8548  kept wishing watching documentary wartime nava...
# 4    156219        8549  kinnear aim sympathy rather delivers performan...
# 5    156250        8550  ends well sort frenzied comic moments never click
# 6    156272        8551  hoot half great way american people see candid...
# 7    156324        8552  weight piece unerring professionalism chilly p...
# 8    156362        8553  film contains good jokes good scenes barely mo...
# 9    156405        8554  offbeat sometimes gross surprisingly appealing...

# %%
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Allen\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Allen\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Allen\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\omw-1.4.zip.

# %%
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag, word_tokenize     
def tag_words(df):
    allPhrases = list(df['Phrase'])
    for index,row in df.iterrows():
        tokenized = word_tokenize(allPhrases[index])
        tagged = nltk.pos_tag(tokenized)
        df.at[index, 'Phrase'] = tagged

def determine_root(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return None

def lemmatize_phrases(df):
    lemmatizer = WordNetLemmatizer()
    allPhrases = list(df['Phrase'])
    for index,row in df.iterrows():
        final_sentence = []
        final_tag = list(map(lambda x: (x[0], determine_root(x[1])), allPhrases[index]))
        for word, tag in final_tag:
            if tag is None:
                final_sentence.append(word)
            else:
                final_sentence.append(lemmatizer.lemmatize(word, tag))
        final_sentence = ' '.join(final_sentence)
        df.at[index, 'Phrase'] = final_sentence

# %%
tag_words(df)
lemmatize_phrases(df)

# %%
tag_words(testdf)
lemmatize_phrases(testdf)

# %%
df.head(10)
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  series escapades demonstrating adage good goos...
# 1        64           2  quiet introspective entertaining independent w...
# 2        82           3  even fan ismail merchant work suspect would ha...
# 3       117           4  positively thrill combination ethnography intr...
# 4       157           5  aggressive selfglorification manipulative whit...
# 5       167           6  comedydrama nearly epic proportion root sincer...
# 6       199           7            narratively trouble every day plod mess
# 7       214           8  importance earnest thick wit play like read ba...
# 8       248           9                                         leave much
# 9       260          10                                  could hate reason
#
#    Sentiment
# 0          1
# 1          4
# 2          1
# 3          3
# 4          1
# 5          4
# 6          1
# 7          3
# 8          1
# 9          1

# %%
# TO DO:
# * preprocessing
#     - replace all grammar with spaces
#     - lemmatize words
# * reduce to multi-dimensional vector
#     - We have options including: Bag of words
#     - BERT
#     - TF-IDF
# * classification
#     - try a bunch of classifiers
# * graphing
#     - graph the outputs of our classifiers
# * presentation
#     - create a presentation

# %%
class Selene(object):
    
    def __init__(self, df, testdf):
        
        self.df = df
        self.testdf = testdf
        self.wordsDict = {}
        self.wordSentOcc = {}
        self.wordSentVal = {}
    
    def train(self, printer = False):
        # Tokenizes phrases and finds frequency & sentiment
        self.setUniqueWords()
        self.setFrequencies()
        self.findSentFrequency()
        if printer:
            print("Here is the average value of the sentiment and probabilities of each word in the training data:")
            for key, value in self.wordSentVal.items():
                print(key, ": ", value)
    
    def test(self, weight = 0.1, minFreq = 3):
        self.getSentiment(weight, minFreq)
    
    # Finds unique words in the list of phrases and puts into list
    def setUniqueWords(self):
        
        phrases = list(self.df['Phrase'])
        
        for index, row in df.iterrows():
            sentence = row['Phrase']
            for w in word_tokenize(sentence): # word_tokens:
                if w.isalpha():
                    self.wordsDict[w] = [0,0,0,0,0,0]
                    
    def setFrequencies(self):
        
        for index, row in df.iterrows():
            sentence = row['Phrase']
            for word in sentence.split():
                if word in self.wordsDict:
                    self.wordsDict[word][0] += 1           
    
    # Finds frequencies of the sentiment per word
    def findSentFrequency(self):
                    
        for index, row in df.iterrows():
            sentiment = int(row['Sentiment'])
            for word in row['Phrase'].split():
                if word in self.wordsDict:
                    try:
                        self.wordsDict[word][sentiment + 1] += 1
                    except:
                        print(sentiment + 1)
                
        counter = 0;
        print("Words = [Frequency, 0 Freq, 1 Freq, 2 Freq, 3 Freq, 4 Freq, 5 Freq]")
        for key, value in self.wordsDict.items():
            print("Word #", counter, ":", key, "-", value)
            counter += 1
            
    # Finds probabilities for a word's sentiment
    def findProbabilities(self, key):
        
        prob0 = self.wordSentOcc[key][0 + 1] / self.wordsDict[key]
        prob1 = self.wordSentOcc[key][1 + 1] / self.wordsDict[key]
        prob2 = self.wordSentOcc[key][2 + 1] / self.wordsDict[key]
        prob3 = self.wordSentOcc[key][3 + 1] / self.wordsDict[key]
        prob4 = self.wordSentOcc[key][4 + 1] / self.wordsDict[key]
        return prob0, prob1, prob2, prob3, prob
    
    # Finds the average sentiment of a word
    def findWordSentVal(self):
        
        for key, value in self.wordSentOcc.items():
            sentVal = (((value[0 + 1] * 0) + (value[1 + 1] * 1) + (value[2 + 1] * 2)
                    + (value[3 + 1] * 3) + (value[4 + 1] * 4)) / self.wordsDict[key])
            prob0, prob1, prob2, prob3, prob4 = self.findProbabilities(key)
            self.wordSentVal[key] = {'Avg Value': sentVal,'P0': prob0,
                                     'P1': prob1, 'P2': prob2, 
                                     'P3': prob3, 'P4': prob4}
            

    
    # Gets probability weights
    def getWeight(self, word, weightPercent, minimumOccurances):
        
        mystery = np.random.rand(0, 1)
        if self.wordsDict[word] >= minimumOccurances:
            if (mystery >= 0 and mystery <= self.wordSentVal[word]['P0']):
                return 0
            if (mystery >= self.wordSentVal[word]['P0'] and mystery <= self.wordSentVal[word]['P0'] + self.wordSentVal[word]['P1']):
                return 1 * weightPercent
            if (mystery >= self.wordSentVal[word]['P0'] + self.wordSentVal[word]['P1'] and mystery <= 
                self.wordSentVal[word]['P1'] + self.wordSentVal[word]['P2']):
                return 2 * weightPercent
            if (mystery >= self.wordSentVal[word]['P1'] + self.wordSentVal[word]['P2'] and mystery <= 
                self.wordSentVal[word]['P2'] + self.wordSentVal[word]['P3']):
                return 3 * weightPercent
            if (mystery >= self.wordSentVal[word]['P2'] + self.wordSentVal[word]['P3'] and mystery <= 
                self.wordSentVal[word]['P3'] + self.wordSentVal[word]['P4']):
                return 4 * weightPercent 
        if self.wordsDict[word] < minimumOccurances:
            if (mystery >= 0 and mystery <= self.wordSentVal[word]['P0']):
                return 0
            if (mystery >= self.wordSentVal[word]['P0'] and mystery <= self.wordSentVal[word]['P0'] + self.wordSentVal[word]['P1']):
                return 1 * weightPercent
            if (mystery >= self.wordSentVal[word]['P0'] + self.wordSentVal[word]['P1'] and mystery <= 
                self.wordSentVal[word]['P1'] + self.wordSentVal[word]['P2']):
                return 2 * weightPercent
            if (mystery >= self.wordSentVal[word]['P1'] + self.wordSentVal[word]['P2'] and mystery <= 
                self.wordSentVal[word]['P2'] + self.wordSentVal[word]['P3']):
                return 3 * weightPercent
            if (mystery >= self.wordSentVal[word]['P2'] + self.wordSentVal[word]['P3'] and mystery <= 
                self.wordSentVal[word]['P3'] + self.wordSentVal[word]['P4']):
                return 4 * weightPercent 
    
    # Gets the sentiment of a phrase
    def getSentiment(self, weightPercent = .1, minimumOccurances = 3):
        
        Sentiments = []
        
        for index, row in self.testdf.iterrows():
            word_tokens = word_tokenize(row['Phrase'])
            for word in word_tokens:
                if word in self.wordSentVal.keys():
                    weight = self.getWeight(word, weightPercent, minimumOccurances)
                    phraseVal += self.wordSentVal[word]['Avg Value'] + weight
                # Neutral sentiment for unknown word
                if word not in self.wordSentVal.keys():
                    phraseVal += 2 
            sentVal = round(phraseVal/len(word_tokens))
            Sentiments.append(sentVal)
            
        # testdf['Sentiment'] = Sentiments
        return Sentiments

# %%
selene = Selene(df, testdf)

# %%
selene.train()
# Out:
# Words = [Frequency, 0 Freq, 1 Freq, 2 Freq, 3 Freq, 4 Freq, 5 Freq]
# Word # 0 : series - [49, 10, 16, 7, 11, 5]
# Word # 1 : escapades - [1, 0, 1, 0, 0, 0]
# Word # 2 : demonstrating - [1, 0, 1, 0, 0, 0]
# Word # 3 : adage - [3, 0, 1, 0, 1, 1]
# Word # 4 : good - [302, 25, 80, 55, 96, 46]
# Word # 5 : goose - [3, 1, 1, 1, 0, 0]
# Word # 6 : also - [115, 12, 15, 21, 44, 23]
# Word # 7 : gander - [1, 0, 1, 0, 0, 0]
# Word # 8 : occasionally - [27, 0, 8, 8, 8, 3]
# Word # 9 : amuse - [49, 2, 12, 7, 18, 10]
# Word # 10 : none - [28, 6, 14, 5, 2, 1]
# Word # 11 : amount - [25, 9, 7, 0, 8, 1]
# Word # 12 : much - [263, 30, 97, 55, 53, 28]
# Word # 13 : story - [378, 39, 94, 66, 124, 55]
# Word # 14 : quiet - [24, 1, 3, 4, 10, 6]
# Word # 15 : introspective - [3, 0, 0, 1, 1, 1]
# Word # 16 : entertaining - [30, 1, 4, 3, 6, 16]
# Word # 17 : independent - [4, 1, 1, 0, 1, 1]
# Word # 18 : worth - [78, 3, 10, 17, 32, 16]
# Word # 19 : seek - [15, 2, 5, 1, 2, 5]
# Word # 20 : even - [258, 52, 72, 36, 69, 29]
# Word # 21 : fan - [69, 2, 18, 13, 21, 15]
# Word # 22 : ismail - [1, 0, 1, 0, 0, 0]
# Word # 23 : merchant - [5, 0, 3, 1, 0, 1]
# Word # 24 : work - [278, 25, 52, 41, 97, 63]
# Word # 25 : suspect - [11, 1, 8, 0, 0, 2]
# Word # 26 : would - [233, 40, 81, 49, 50, 13]
# Word # 27 : hard - [92, 17, 34, 12, 20, 9]
# Word # 28 : time - [300, 43, 81, 61, 79, 36]
# Word # 29 : sit - [40, 8, 18, 6, 7, 1]
# Word # 30 : one - [571, 77, 133, 110, 133, 118]
# Word # 31 : positively - [5, 3, 0, 1, 1, 0]
# Word # 32 : thrill - [26, 3, 7, 5, 6, 5]
# Word # 33 : combination - [12, 2, 3, 3, 2, 2]
# Word # 34 : ethnography - [1, 0, 0, 0, 1, 0]
# Word # 35 : intrigue - [35, 2, 7, 4, 14, 8]
# Word # 36 : betrayal - [4, 0, 0, 0, 2, 2]
# Word # 37 : deceit - [1, 0, 0, 0, 1, 0]
# Word # 38 : murder - [22, 3, 4, 5, 7, 3]
# Word # 39 : shakespearean - [2, 0, 0, 0, 2, 0]
# Word # 189 : exgirlfriend - [1, 0, 1, 0, 0, 0]
# Word # 190 : chuck - [2, 0, 0, 2, 0, 0]
# Word # 191 : norris - [1, 0, 0, 1, 0, 0]
# Word # 192 : grenade - [2, 0, 1, 1, 0, 0]
# Word # 193 : gag - [37, 8, 8, 15, 4, 2]
# Word # 194 : occur - [3, 0, 1, 1, 1, 0]
# Word # 195 : windtalker - [7, 1, 4, 2, 0, 0]
# Word # 196 : indication - [3, 1, 1, 1, 0, 0]
# Word # 197 : seriousminded - [2, 0, 0, 1, 1, 0]
# Word # 198 : film - [1285, 141, 286, 229, 393, 236]
# Word # 199 : plot - [151, 33, 59, 29, 25, 5]
# Word # 200 : romantic - [77, 9, 15, 8, 24, 21]
# Word # 201 : comedy - [272, 38, 64, 39, 74, 57]
# Word # 202 : boilerplate - [1, 0, 0, 1, 0, 0]
# Word # 203 : start - [60, 9, 21, 13, 12, 5]
# Word # 204 : finish - [18, 0, 6, 6, 4, 2]
# Word # 205 : arrives - [3, 0, 2, 1, 0, 0]
# Word # 206 : impeccable - [6, 0, 0, 1, 2, 3]
# Word # 207 : pedigree - [5, 0, 2, 2, 1, 0]
# Word # 208 : mongrel - [1, 0, 0, 1, 0, 0]
# Word # 209 : pep - [1, 0, 0, 1, 0, 0]
# Word # 210 : almost - [91, 13, 23, 21, 23, 11]
# Word # 211 : indecipherable - [2, 0, 1, 1, 0, 0]
# Word # 212 : complication - [7, 2, 1, 2, 0, 2]
# Word # 213 : clearly - [17, 3, 6, 3, 3, 2]
# Word # 214 : mean - [46, 8, 10, 10, 16, 2]
# Word # 215 : preach - [3, 1, 0, 1, 0, 1]
# Word # 216 : exclusively - [1, 0, 0, 1, 0, 0]
# Word # 217 : convert - [3, 1, 0, 1, 1, 0]
# Word # 218 : offer - [80, 7, 20, 7, 29, 17]
# Word # 219 : opportunity - [20, 5, 8, 3, 2, 2]
# Word # 220 : occasional - [6, 0, 3, 0, 2, 1]
# Word # 221 : smile - [16, 0, 3, 4, 4, 5]
# Word # 222 : chuckle - [9, 1, 2, 3, 2, 1]
# Word # 223 : give - [174, 14, 41, 34, 52, 33]
# Word # 224 : theater - [47, 10, 13, 8, 12, 4]
# Word # 225 : beyond - [35, 7, 10, 6, 8, 4]
# Word # 226 : wilde - [7, 1, 2, 1, 0, 3]
# Word # 227 : actor - [105, 16, 21, 14, 34, 20]
# Word # 228 : late - [35, 4, 11, 4, 10, 6]
# Word # 229 : vapid - [7, 3, 4, 0, 0, 0]
# Word # 230 : exercise - [46, 10, 23, 5, 5, 3]
# Word # 231 : appropriate - [7, 1, 2, 1, 2, 1]
# Word # 232 : structure - [16, 1, 8, 3, 4, 0]
# Word # 233 : arthur - [2, 0, 2, 0, 0, 0]
# Word # 234 : schnitzlers - [2, 0, 1, 1, 0, 0]
# Word # 235 : reigen - [1, 0, 1, 0, 0, 0]
# Word # 236 : vaudeville - [3, 0, 1, 1, 1, 0]
# Word # 237 : show - [100, 17, 21, 21, 31, 10]
# Word # 238 : wellconstructed - [2, 0, 0, 2, 0, 0]
# Word # 239 : narrative - [47, 9, 11, 5, 16, 6]
# Word # 240 : term - [25, 4, 8, 6, 4, 3]
# Word # 241 : inoffensive - [8, 1, 3, 3, 1, 0]
# Word # 242 : actually - [56, 8, 14, 14, 12, 8]
# Word # 243 : rather - [85, 14, 26, 21, 16, 8]
# Word # 244 : runofthemill - [7, 0, 4, 2, 0, 1]
# Word # 245 : action - [125, 17, 50, 16, 24, 18]
# Word # 246 : hamper - [3, 1, 2, 0, 0, 0]
# Word # 247 : paralyzed - [1, 1, 0, 0, 0, 0]
# Word # 248 : selfindulgent - [8, 1, 4, 1, 2, 0]
# Word # 249 : script - [113, 27, 38, 17, 23, 8]
# Word # 250 : aim - [20, 3, 6, 4, 4, 3]
# Word # 251 : poetry - [16, 4, 2, 2, 5, 3]
# Word # 252 : end - [165, 21, 52, 36, 41, 15]
# Word # 253 : sound - [35, 6, 10, 4, 8, 7]
# Word # 254 : satire - [29, 7, 10, 3, 7, 2]
# Word # 255 : ice - [16, 1, 2, 9, 2, 2]
# Word # 256 : age - [43, 1, 5, 9, 15, 13]
# Word # 257 : first - [107, 10, 30, 22, 26, 19]
# Word # 258 : computergenerated - [5, 0, 2, 2, 1, 0]
# Word # 259 : feature - [66, 7, 15, 10, 15, 19]
# Word # 260 : cartoon - [23, 2, 6, 8, 7, 0]
# Word # 261 : feel - [227, 38, 79, 39, 46, 25]
# Word # 262 : glacial - [1, 0, 0, 1, 0, 0]
# Word # 263 : pace - [46, 10, 9, 11, 11, 5]
# Word # 264 : early - [11, 3, 1, 3, 1, 3]
# Word # 265 : maker - [13, 5, 1, 2, 4, 1]
# Word # 266 : serve - [33, 8, 11, 5, 6, 3]
# Word # 267 : cliche - [37, 7, 16, 7, 5, 2]
# Word # 268 : considerable - [17, 1, 3, 2, 9, 2]
# Word # 269 : dash - [5, 1, 0, 1, 2, 1]
# Word # 270 : cattaneo - [3, 0, 2, 1, 0, 0]
# Word # 271 : follow - [28, 2, 10, 6, 7, 3]
# Word # 272 : runaway - [1, 0, 0, 1, 0, 0]
# Word # 273 : success - [22, 1, 6, 5, 9, 1]
# Word # 274 : full - [75, 4, 22, 12, 23, 14]
# Word # 275 : monty - [12, 1, 3, 4, 2, 2]
# Word # 276 : different - [28, 0, 5, 4, 8, 11]
# Word # 277 : unnamed - [1, 0, 1, 0, 0, 0]
# Word # 278 : easily - [32, 3, 8, 5, 7, 9]
# Word # 279 : substitutable - [1, 0, 1, 0, 0, 0]
# Word # 280 : force - [36, 6, 8, 7, 11, 4]
# Word # 281 : whatever - [16, 2, 5, 3, 4, 2]
# Word # 282 : terror - [5, 0, 1, 2, 2, 0]
# Word # 283 : hero - [30, 2, 12, 4, 6, 6]
# Word # 284 : horror - [42, 8, 11, 3, 13, 7]
# Word # 285 : avoid - [12, 2, 3, 2, 4, 1]
# Word # 286 : interested - [16, 3, 5, 3, 3, 2]
# Word # 287 : entertain - [72, 3, 10, 12, 28, 19]
# Word # 338 : decent - [20, 1, 6, 3, 10, 0]
# Word # 339 : material - [75, 6, 32, 12, 21, 4]
# Word # 340 : fortunately - [2, 0, 0, 1, 1, 0]
# Word # 341 : option - [3, 1, 0, 1, 1, 0]
# Word # 342 : sensational - [5, 1, 0, 0, 3, 1]
# Word # 343 : truecrime - [1, 0, 0, 0, 1, 0]
# Word # 344 : helljaunt - [1, 0, 0, 0, 1, 0]
# Word # 345 : purist - [2, 0, 0, 0, 1, 1]
# Word # 346 : might - [111, 11, 40, 27, 25, 8]
# Word # 347 : experimental - [2, 0, 1, 0, 1, 0]
# Word # 348 : storytelling - [37, 1, 14, 3, 9, 10]
# Word # 349 : lrb - [351, 41, 98, 69, 95, 48]
# Word # 350 : though - [109, 8, 22, 30, 43, 6]
# Word # 351 : horrifying - [2, 1, 0, 0, 1, 0]
# Word # 352 : rrb - [352, 41, 99, 69, 95, 48]
# Word # 353 : tricky - [2, 0, 0, 0, 1, 1]
# Word # 354 : satisfying - [4, 1, 1, 0, 2, 0]
# Word # 355 : david - [24, 2, 6, 6, 4, 6]
# Word # 356 : mamet - [4, 0, 0, 1, 2, 1]
# Word # 357 : airless - [3, 1, 1, 0, 1, 0]
# Word # 358 : cinematic - [51, 9, 8, 6, 14, 14]
# Word # 359 : game - [36, 5, 7, 9, 8, 7]
# Word # 360 : sure - [40, 8, 11, 5, 11, 5]
# Word # 361 : filmmaker - [85, 12, 20, 14, 28, 11]
# Word # 362 : disagree - [1, 0, 1, 0, 0, 0]
# Word # 363 : honestly - [9, 0, 5, 0, 3, 1]
# Word # 364 : see - [244, 23, 54, 49, 64, 54]
# Word # 365 : point - [82, 9, 28, 21, 19, 5]
# Word # 366 : jones - [12, 0, 1, 4, 2, 5]
# Word # 367 : tackle - [9, 1, 1, 2, 4, 1]
# Word # 368 : meaty - [3, 0, 0, 1, 1, 1]
# Word # 369 : subject - [75, 11, 15, 15, 26, 8]
# Word # 370 : drawn - [2, 0, 0, 0, 1, 1]
# Word # 371 : engage - [57, 3, 11, 9, 20, 14]
# Word # 372 : pepper - [5, 0, 1, 1, 1, 2]
# Word # 373 : page - [3, 1, 0, 0, 1, 1]
# Word # 374 : memorable - [29, 2, 5, 6, 10, 6]
# Word # 375 : zinger - [2, 0, 1, 0, 0, 1]
# Word # 376 : bloody - [7, 0, 1, 2, 3, 1]
# Word # 377 : sunday - [3, 0, 0, 2, 0, 1]
# Word # 378 : grace - [21, 1, 2, 5, 4, 9]
# Word # 379 : call - [48, 5, 19, 11, 6, 7]
# Word # 380 : prevention - [1, 0, 0, 0, 0, 1]
# Word # 381 : place - [70, 3, 18, 13, 30, 6]
# Word # 382 : blame - [6, 1, 1, 1, 1, 2]
# Word # 383 : war - [60, 5, 14, 9, 24, 8]
# Word # 384 : ever - [104, 16, 23, 12, 20, 33]
# Word # 385 : clunky - [3, 1, 2, 0, 0, 0]
# Word # 386 : tvmovie - [1, 0, 1, 0, 0, 0]
# Word # 387 : approach - [29, 3, 8, 6, 7, 5]
# Word # 388 : detail - [30, 0, 6, 6, 9, 9]
# Word # 389 : chapter - [1, 0, 1, 0, 0, 0]
# Word # 390 : life - [180, 16, 26, 35, 66, 37]
# Word # 391 : celebrate - [6, 0, 1, 1, 4, 0]
# Word # 392 : irish - [6, 1, 2, 1, 2, 0]
# Word # 393 : playwright - [3, 0, 1, 2, 0, 0]
# Word # 394 : poet - [4, 0, 1, 2, 1, 0]
# Word # 395 : drinker - [1, 0, 1, 0, 0, 0]
# Word # 396 : finally - [29, 2, 7, 6, 7, 7]
# Word # 397 : come - [190, 29, 62, 32, 45, 22]
# Word # 398 : miramaxs - [1, 0, 0, 1, 0, 0]
# Word # 399 : deep - [31, 1, 7, 3, 13, 7]
# Word # 400 : shelf - [7, 1, 3, 2, 1, 0]
# Word # 401 : abort - [1, 0, 0, 1, 0, 0]
# Word # 402 : attempt - [47, 9, 22, 6, 10, 0]
# Word # 403 : wake - [9, 0, 4, 3, 1, 1]
# Word # 404 : reno - [13, 0, 2, 7, 3, 1]
# Word # 405 : strong - [52, 2, 5, 11, 23, 11]
# Word # 406 : let - [41, 4, 7, 9, 18, 3]
# Word # 407 : sleep - [7, 2, 2, 2, 1, 0]
# Word # 408 : lie - [16, 2, 0, 4, 7, 3]
# Word # 409 : thanks - [19, 1, 2, 2, 5, 9]
# Word # 410 : largely - [15, 4, 2, 4, 3, 2]
# Word # 411 : williams - [18, 1, 4, 4, 4, 5]
# Word # 412 : interesting - [30, 3, 8, 9, 7, 3]
# Word # 413 : development - [12, 2, 4, 0, 5, 1]
# Word # 414 : process - [23, 1, 6, 5, 8, 3]
# Word # 415 : rest - [24, 5, 4, 5, 6, 4]
# Word # 416 : overexpose - [2, 1, 0, 0, 1, 0]
# Word # 417 : waste - [29, 12, 14, 0, 2, 1]
# Word # 418 : across - [20, 4, 4, 2, 7, 3]
# Word # 419 : relic - [2, 1, 1, 0, 0, 0]
# Word # 420 : bygone - [2, 1, 1, 0, 0, 0]
# Word # 421 : era - [19, 1, 3, 6, 9, 0]
# Word # 422 : convolution - [2, 1, 1, 0, 0, 0]
# Word # 423 : silly - [52, 9, 17, 15, 4, 7]
# Word # 424 : plausible - [1, 1, 0, 0, 0, 0]
# Word # 425 : perhaps - [19, 2, 5, 8, 2, 2]
# Word # 426 : refresh - [15, 0, 0, 0, 5, 10]
# Word # 427 : lead - [43, 6, 13, 5, 9, 10]
# Word # 428 : oscarsize - [1, 0, 0, 0, 0, 1]
# Word # 429 : run - [56, 12, 23, 6, 12, 3]
# Word # 430 : mark - [34, 1, 6, 8, 15, 4]
# Word # 431 : pellingtons - [1, 0, 0, 0, 1, 0]
# Word # 432 : pop - [17, 2, 2, 3, 6, 4]
# Word # 433 : thriller - [98, 10, 17, 19, 36, 16]
# Word # 434 : kooky - [2, 0, 0, 0, 2, 0]
# Word # 435 : overeager - [1, 0, 0, 0, 1, 0]
# Word # 436 : spooky - [10, 0, 2, 2, 6, 0]
# Word # 636 : amid - [5, 1, 1, 2, 0, 1]
# Word # 637 : shock - [28, 2, 5, 10, 6, 5]
# Word # 638 : curiosity - [9, 1, 4, 3, 1, 0]
# Word # 639 : factor - [7, 1, 3, 0, 2, 1]
# Word # 640 : corny - [8, 0, 5, 1, 2, 0]
# Word # 641 : examination - [21, 0, 3, 3, 11, 4]
# Word # 642 : actress - [27, 3, 7, 4, 7, 6]
# Word # 643 : find - [134, 17, 33, 30, 37, 17]
# Word # 644 : lazy - [15, 6, 6, 2, 1, 0]
# Word # 645 : solve - [2, 0, 0, 2, 0, 0]
# Word # 646 : distract - [7, 0, 3, 3, 1, 0]
# Word # 647 : solution - [5, 0, 2, 1, 1, 1]
# Word # 648 : another - [104, 18, 33, 27, 20, 6]
# Word # 649 : comprehensible - [1, 0, 0, 0, 1, 0]
# Word # 650 : dummy - [2, 0, 0, 1, 1, 0]
# Word # 651 : guide - [3, 2, 0, 0, 1, 0]
# Word # 652 : nontechies - [1, 0, 0, 0, 1, 0]
# Word # 653 : enjoy - [51, 5, 8, 4, 29, 5]
# Word # 654 : entertains - [2, 0, 1, 0, 1, 0]
# Word # 655 : music - [63, 6, 9, 10, 16, 22]
# Word # 656 : comic - [59, 2, 14, 8, 22, 13]
# Word # 657 : antic - [5, 1, 1, 2, 0, 1]
# Word # 658 : pleasure - [39, 1, 8, 2, 19, 9]
# Word # 659 : disney - [25, 0, 9, 5, 5, 6]
# Word # 660 : scrape - [1, 0, 1, 0, 0, 0]
# Word # 661 : bottom - [9, 1, 4, 0, 4, 0]
# Word # 662 : cracker - [2, 0, 1, 1, 0, 0]
# Word # 663 : barrel - [8, 0, 3, 2, 3, 0]
# Word # 664 : writerdirector - [34, 2, 11, 5, 10, 6]
# Word # 665 : burr - [4, 0, 2, 0, 2, 0]
# Word # 666 : steer - [6, 0, 1, 1, 3, 1]
# Word # 667 : emphasize - [8, 1, 0, 3, 3, 1]
# Word # 668 : q - [4, 0, 1, 0, 3, 0]
# Word # 669 : quirky - [38, 2, 6, 3, 17, 10]
# Word # 670 : mixed - [11, 1, 6, 1, 2, 1]
# Word # 671 : result - [37, 4, 11, 8, 10, 4]
# Word # 672 : scarcely - [3, 1, 2, 0, 0, 0]
# Word # 673 : mention - [13, 2, 1, 2, 4, 4]
# Word # 674 : report - [13, 2, 4, 4, 1, 2]
# Word # 675 : number - [29, 5, 5, 8, 3, 8]
# Word # 676 : tumbleweed - [1, 1, 0, 0, 0, 0]
# Word # 677 : blow - [9, 1, 4, 3, 1, 0]
# Word # 678 : empty - [15, 3, 8, 3, 1, 0]
# Word # 679 : theatre - [12, 3, 3, 1, 4, 1]
# Word # 680 : company - [16, 2, 5, 0, 7, 2]
# Word # 681 : invigorate - [2, 0, 0, 0, 1, 1]
# Word # 682 : surreal - [7, 0, 1, 1, 3, 2]
# Word # 683 : resonant - [9, 1, 0, 0, 5, 3]
# Word # 684 : rainbow - [2, 0, 0, 0, 1, 1]
# Word # 685 : emotion - [36, 4, 4, 10, 12, 6]
# Word # 686 : analyze - [11, 2, 1, 5, 3, 0]
# Word # 687 : crass - [7, 3, 1, 1, 1, 1]
# Word # 688 : contrive - [31, 10, 11, 8, 2, 0]
# Word # 689 : sequel - [41, 7, 12, 7, 7, 8]
# Word # 690 : fails - [21, 8, 11, 1, 1, 0]
# Word # 691 : secondguess - [1, 1, 0, 0, 0, 0]
# Word # 692 : affection - [12, 2, 0, 1, 6, 3]
# Word # 693 : original - [78, 11, 16, 20, 21, 10]
# Word # 694 : card - [5, 0, 3, 2, 0, 0]
# Word # 695 : exalt - [2, 0, 2, 0, 0, 0]
# Word # 696 : tagline - [2, 1, 1, 0, 0, 0]
# Word # 697 : definite - [2, 0, 1, 0, 1, 0]
# Word # 698 : room - [19, 6, 5, 2, 5, 1]
# Word # 699 : improvement - [4, 1, 1, 0, 2, 0]
# Word # 700 : neither - [38, 8, 14, 9, 7, 0]
# Word # 701 : monsterous - [1, 0, 0, 1, 0, 0]
# Word # 702 : tsai - [7, 0, 0, 3, 4, 0]
# Word # 703 : may - [181, 6, 44, 43, 61, 27]
# Word # 704 : plough - [1, 0, 0, 1, 0, 0]
# Word # 705 : furrow - [1, 0, 0, 1, 0, 0]
# Word # 706 : often - [99, 6, 27, 13, 37, 16]
# Word # 707 : green - [15, 2, 7, 3, 2, 1]
# Word # 708 : equivalent - [11, 2, 4, 4, 1, 0]
# Word # 709 : saddam - [1, 0, 1, 0, 0, 0]
# Word # 710 : hussein - [1, 0, 1, 0, 0, 0]
# Word # 711 : ready - [5, 0, 3, 2, 0, 0]
# Word # 712 : youn - [1, 0, 1, 0, 0, 0]
# Word # 713 : ask - [19, 1, 7, 7, 2, 2]
# Word # 714 : permission - [1, 0, 1, 0, 0, 0]
# Word # 715 : preemptive - [2, 1, 1, 0, 0, 0]
# Word # 716 : strike - [26, 1, 6, 1, 14, 4]
# Word # 717 : surprisingly - [44, 4, 7, 3, 21, 9]
# Word # 718 : solid - [37, 0, 0, 4, 16, 17]
# Word # 719 : achievement - [12, 2, 1, 0, 5, 4]
# Word # 720 : malcolm - [3, 0, 0, 1, 2, 0]
# Word # 721 : lee - [13, 2, 1, 1, 6, 3]
# Word # 722 : john - [39, 2, 10, 10, 14, 3]
# Word # 723 : ridley - [1, 0, 0, 0, 1, 0]
# Word # 724 : massouds - [1, 0, 0, 1, 0, 0]
# Word # 725 : record - [17, 0, 1, 4, 7, 5]
# Word # 726 : tenacious - [3, 0, 0, 2, 0, 1]
# Word # 727 : humane - [3, 0, 0, 1, 1, 1]
# Word # 728 : fighter - [3, 0, 2, 1, 0, 0]
# Word # 729 : prisoner - [2, 0, 1, 1, 0, 0]
# Word # 730 : victim - [15, 1, 4, 6, 3, 1]
# Word # 731 : change - [40, 4, 11, 4, 16, 5]
# Word # 732 : lane - [11, 0, 2, 0, 3, 6]
# Word # 733 : shyamalan - [7, 0, 1, 1, 4, 1]
# Word # 734 : stop - [15, 3, 3, 3, 5, 1]
# Word # 735 : please - [25, 2, 3, 3, 13, 4]
# Word # 736 : mom - [2, 0, 2, 0, 0, 0]
# Word # 737 : macabre - [3, 1, 0, 0, 1, 1]
# Word # 738 : stylize - [4, 0, 0, 2, 2, 0]
# Word # 739 : swedish - [3, 0, 0, 1, 2, 0]
# Word # 740 : fillm - [1, 0, 0, 0, 1, 0]
# Word # 741 : city - [23, 1, 5, 5, 9, 3]
# Word # 742 : religious - [4, 0, 1, 1, 2, 0]
# Word # 743 : civic - [2, 0, 0, 0, 2, 0]
# Word # 744 : virtue - [7, 0, 2, 3, 2, 0]
# Word # 745 : hold - [40, 1, 10, 8, 13, 8]
# Word # 746 : society - [13, 0, 2, 4, 5, 2]
# Word # 747 : tatter - [2, 0, 0, 0, 2, 0]
# Word # 748 : recent - [32, 4, 6, 1, 9, 12]
# Word # 749 : memory - [25, 5, 4, 4, 6, 6]
# Word # 750 : thoughtful - [26, 1, 1, 3, 6, 15]
# Word # 751 : art - [57, 7, 10, 5, 23, 12]
# Word # 752 : ethic - [2, 0, 0, 0, 0, 2]
# Word # 753 : cost - [7, 1, 1, 2, 2, 1]
# Word # 754 : moral - [23, 0, 5, 6, 9, 3]
# Word # 755 : compromise - [7, 0, 3, 1, 2, 1]
# Word # 756 : consistently - [13, 0, 1, 2, 5, 5]
# Word # 757 : unimaginative - [7, 3, 3, 1, 0, 0]
# Word # 758 : probably - [50, 2, 20, 10, 14, 4]
# Word # 759 : save - [28, 4, 11, 4, 8, 1]
# Word # 760 : aid - [5, 2, 1, 1, 0, 1]
# Word # 761 : wisecrack - [1, 0, 0, 1, 0, 0]
# Word # 762 : mystery - [34, 2, 12, 7, 5, 8]
# Word # 763 : science - [9, 1, 4, 1, 2, 1]
# Word # 764 : guy - [49, 6, 21, 12, 8, 2]
# Word # 765 : tian - [2, 0, 0, 1, 0, 1]
# Word # 766 : zhuangzhuang - [2, 0, 0, 0, 1, 1]
# Word # 767 : triumphantly - [2, 1, 0, 0, 0, 1]
# Word # 768 : return - [22, 1, 4, 2, 8, 7]
# Word # 769 : filmmaking - [40, 4, 9, 3, 10, 14]
# Word # 770 : visually - [29, 4, 3, 5, 8, 9]
# Word # 771 : masterful - [8, 0, 0, 1, 2, 5]
# Word # 772 : mawkish - [1, 0, 1, 0, 0, 0]
# Word # 773 : selfparody - [2, 1, 1, 0, 0, 0]
# Word # 774 : weird - [21, 2, 12, 2, 4, 1]
# Word # 775 : masterpiece - [20, 1, 4, 1, 4, 10]
# Word # 776 : sketch - [8, 2, 5, 1, 0, 0]
# Word # 777 : view - [37, 2, 6, 8, 14, 7]
# Word # 778 : compel - [48, 1, 8, 7, 18, 14]
# Word # 779 : believe - [44, 10, 7, 8, 14, 5]
# Word # 780 : put - [61, 9, 16, 7, 18, 11]
# Word # 781 : battle - [19, 1, 6, 3, 5, 4]
# Word # 782 : will - [2, 0, 0, 2, 0, 0]
# Word # 783 : care - [63, 15, 20, 6, 13, 9]
# Word # 784 : appreciate - [14, 1, 1, 4, 5, 3]
# Word # 785 : onesided - [3, 0, 2, 1, 0, 0]
# Word # 786 : theme - [35, 2, 7, 4, 14, 8]
# Word # 787 : lawrence - [13, 4, 7, 1, 1, 0]
# Word # 788 : overindulgent - [1, 0, 1, 0, 0, 0]
# Word # 789 : tirade - [1, 0, 1, 0, 0, 0]
# Word # 790 : knock - [3, 0, 3, 0, 0, 0]
# Word # 791 : postcard - [4, 2, 1, 0, 1, 0]
# Word # 792 : selfglorified - [1, 0, 1, 0, 0, 0]
# Word # 793 : martin - [15, 2, 3, 4, 5, 1]
# Word # 794 : lovefest - [1, 0, 1, 0, 0, 0]
# Word # 795 : whole - [53, 9, 22, 11, 5, 6]
# Word # 796 : sneaky - [2, 1, 0, 0, 0, 1]
# Word # 797 : dupe - [1, 1, 0, 0, 0, 0]
# Word # 798 : viewer - [59, 12, 18, 9, 15, 5]
# Word # 799 : important - [19, 1, 3, 2, 7, 6]
# Word # 800 : simply - [55, 7, 19, 12, 4, 13]
# Word # 801 : ugly - [20, 12, 5, 1, 0, 2]
# Word # 802 : product - [13, 3, 9, 1, 0, 0]
# Word # 803 : whenever - [7, 2, 3, 0, 2, 0]
# Word # 804 : threaten - [3, 0, 0, 1, 2, 0]
# Word # 805 : bogged - [4, 0, 2, 1, 1, 0]
# Word # 806 : dramaturgy - [1, 0, 0, 0, 1, 0]
# Word # 807 : stir - [12, 0, 0, 2, 4, 6]
# Word # 808 : sequence - [40, 2, 14, 6, 9, 9]
# Word # 809 : surge - [1, 0, 0, 0, 1, 0]
# Word # 810 : swirl - [2, 0, 1, 0, 1, 0]
# Word # 811 : rapid - [2, 0, 0, 0, 2, 0]
# Word # 812 : leap - [7, 0, 0, 2, 3, 2]
# Word # 813 : pinnacle - [2, 0, 0, 0, 2, 0]
# Word # 814 : rouse - [3, 0, 0, 1, 2, 0]
# Word # 815 : swing - [6, 0, 3, 1, 2, 0]
# Word # 816 : seem - [172, 30, 70, 27, 33, 12]
# Word # 817 : hobby - [1, 0, 1, 0, 0, 0]
# Word # 818 : attracts - [1, 0, 1, 0, 0, 0]
# Word # 819 : fit - [22, 3, 4, 6, 7, 2]
# Word # 820 : entirely - [29, 5, 4, 6, 12, 2]
# Word # 821 : unprepared - [1, 0, 0, 1, 0, 0]
# Word # 822 : devos - [2, 0, 0, 0, 1, 1]
# Word # 823 : delivers - [29, 0, 2, 5, 19, 3]
# Word # 824 : perfect - [31, 1, 3, 3, 10, 14]
# Word # 825 : capture - [40, 2, 1, 5, 19, 13]
# Word # 826 : innocence - [8, 0, 2, 1, 4, 1]
# Word # 827 : bud - [2, 0, 1, 0, 1, 0]
# Word # 828 : demon - [5, 0, 0, 0, 4, 1]
# Word # 829 : within - [9, 2, 1, 0, 5, 1]
# Word # 830 : wallflower - [1, 0, 0, 0, 1, 0]
# Word # 831 : russian - [9, 0, 0, 2, 5, 2]
# Word # 832 : culture - [44, 1, 4, 9, 20, 10]
# Word # 833 : compress - [1, 0, 0, 0, 0, 1]
# Word # 834 : evanescent - [1, 0, 0, 0, 0, 1]
# Word # 835 : seamless - [1, 0, 0, 0, 0, 1]
# Word # 836 : sumptuous - [5, 0, 1, 1, 1, 2]
# Word # 837 : stream - [3, 0, 0, 0, 1, 2]
# Word # 838 : consciousness - [5, 0, 2, 0, 2, 1]
# Word # 839 : want - [105, 16, 29, 30, 22, 8]
# Word # 840 : else - [41, 4, 13, 12, 8, 4]
# Word # 841 : cheap - [22, 4, 7, 4, 5, 2]
# Word # 842 : b - [12, 0, 3, 2, 5, 2]
# Word # 843 : succeed - [30, 0, 7, 4, 16, 3]
# Word # 844 : polanski - [8, 0, 1, 1, 4, 2]
# Word # 845 : element - [35, 2, 10, 9, 11, 3]
# Word # 846 : alone - [18, 4, 5, 3, 2, 4]
# Word # 847 : abandon - [10, 3, 3, 1, 3, 0]
# Word # 848 : console - [1, 0, 0, 0, 1, 0]
# Word # 849 : reveal - [19, 1, 1, 4, 9, 4]
# Word # 850 : spiritual - [12, 1, 2, 2, 4, 3]
# Word # 851 : survival - [4, 0, 0, 2, 2, 0]
# Word # 852 : spiderman - [11, 0, 2, 2, 1, 6]
# Word # 853 : summer - [37, 1, 6, 4, 15, 11]
# Word # 854 : blockbuster - [7, 0, 2, 0, 1, 4]
# Word # 855 : endure - [8, 0, 2, 0, 5, 1]
# Word # 856 : last - [61, 7, 15, 14, 11, 14]
# Word # 857 : hopefully - [4, 0, 0, 1, 1, 2]
# Word # 858 : set - [73, 17, 15, 10, 18, 13]
# Word # 859 : tone - [40, 1, 14, 5, 14, 6]
# Word # 860 : stuff - [38, 4, 10, 6, 13, 5]
# Word # 861 : vulgar - [11, 3, 4, 3, 0, 1]
# Word # 862 : forgettably - [2, 0, 1, 1, 0, 0]
# Word # 863 : unsettling - [13, 1, 3, 2, 5, 2]
# Word # 864 : image - [38, 1, 6, 10, 13, 8]
# Word # 865 : warravaged - [1, 0, 0, 1, 0, 0]
# Word # 866 : land - [11, 0, 3, 2, 4, 2]
# Word # 867 : prove - [37, 2, 11, 7, 9, 8]
# Word # 868 : potent - [7, 0, 0, 2, 2, 3]
# Word # 869 : rivet - [15, 0, 0, 3, 3, 9]
# Word # 870 : unlikely - [10, 1, 2, 2, 4, 1]
# Word # 871 : sarah - [2, 0, 0, 2, 0, 0]
# Word # 872 : harrison - [2, 0, 1, 1, 0, 0]
# Word # 873 : wind - [19, 3, 8, 3, 3, 2]
# Word # 874 : revelatory - [8, 1, 1, 0, 3, 3]
# Word # 875 : narcissistic - [1, 0, 0, 0, 1, 0]
# Word # 876 : achieve - [13, 0, 5, 2, 5, 1]
# Word # 877 : honest - [29, 2, 1, 5, 11, 10]
# Word # 878 : insight - [26, 3, 8, 4, 10, 1]
# Word # 879 : highconcept - [3, 0, 1, 0, 2, 0]
# Word # 880 : candycoat - [1, 0, 0, 0, 1, 0]
# Word # 881 : storyline - [17, 3, 4, 2, 6, 2]
# Word # 882 : precious - [9, 2, 1, 1, 4, 1]
# Word # 883 : circumstance - [3, 1, 0, 0, 2, 0]
# Word # 884 : beautiful - [42, 0, 4, 6, 15, 17]
# Word # 885 : star - [76, 9, 25, 12, 24, 6]
# Word # 886 : mostly - [40, 1, 11, 12, 11, 5]
# Word # 887 : martha - [8, 1, 0, 1, 3, 3]
# Word # 888 : unsurprising - [3, 0, 0, 1, 2, 0]
# Word # 889 : delectable - [2, 0, 0, 0, 2, 0]
# Word # 890 : diversion - [7, 0, 0, 0, 7, 0]
# Word # 891 : affect - [17, 2, 4, 2, 4, 5]
# Word # 892 : portrait - [46, 0, 3, 8, 23, 12]
# Word # 893 : screwedup - [2, 0, 0, 0, 1, 1]
# Word # 894 : dare - [18, 0, 4, 5, 5, 4]
# Word # 895 : powerful - [42, 0, 0, 6, 14, 22]
# Word # 896 : people - [124, 17, 30, 20, 42, 15]
# Word # 897 : eye - [43, 0, 5, 5, 18, 15]
# Word # 898 : idealistic - [2, 0, 0, 0, 1, 1]
# Word # 899 : kid - [81, 4, 26, 11, 23, 17]
# Word # 900 : choose - [14, 3, 3, 5, 1, 2]
# Word # 901 : champion - [3, 0, 0, 1, 0, 2]
# Word # 902 : lose - [49, 10, 16, 5, 11, 7]
# Word # 903 : keenly - [1, 0, 0, 0, 1, 0]
# Word # 904 : observe - [3, 0, 1, 0, 2, 0]
# Word # 905 : refreshingly - [10, 0, 0, 0, 8, 2]
# Word # 906 : natural - [11, 1, 2, 2, 1, 5]
# Word # 907 : promenade - [1, 0, 0, 0, 1, 0]
# Word # 908 : clad - [2, 0, 1, 0, 1, 0]
# Word # 909 : body - [19, 3, 8, 3, 4, 1]
# Word # 910 : myrtle - [1, 0, 0, 0, 1, 0]
# Word # 911 : beach - [6, 0, 2, 0, 3, 1]
# Word # 912 : sc - [1, 0, 0, 0, 1, 0]
# Word # 913 : adrenaline - [2, 0, 0, 0, 2, 0]
# Word # 914 : jolt - [9, 0, 0, 2, 5, 2]
# Word # 915 : sudden - [5, 0, 1, 1, 3, 0]
# Word # 916 : lunch - [3, 1, 0, 1, 1, 0]
# Word # 917 : rush - [12, 3, 5, 2, 2, 0]
# Word # 918 : diner - [1, 0, 0, 0, 1, 0]
# Word # 919 : brilliant - [27, 1, 2, 5, 7, 12]
# Word # 920 : expense - [5, 1, 1, 1, 2, 0]
# Word # 921 : pay - [36, 9, 10, 10, 5, 2]
# Word # 922 : triumph - [17, 0, 4, 3, 6, 4]
# Word # 923 : hew - [1, 0, 0, 0, 0, 1]
# Word # 924 : carry - [28, 1, 7, 2, 10, 8]
# Word # 925 : effortlessly - [6, 0, 0, 2, 1, 3]
# Word # 926 : darkness - [4, 0, 1, 0, 2, 1]
# Word # 927 : light - [45, 5, 7, 10, 17, 6]
# Word # 928 : everyone - [38, 6, 9, 5, 10, 8]
# Word # 929 : coast - [3, 0, 1, 1, 1, 0]
# Word # 930 : hook - [9, 1, 2, 2, 3, 1]
# Word # 931 : delicious - [6, 0, 0, 0, 2, 4]
# Word # 932 : pulpiness - [1, 0, 0, 0, 1, 0]
# Word # 933 : lurid - [5, 0, 2, 0, 3, 0]
# Word # 934 : fiction - [15, 0, 6, 3, 4, 2]
# Word # 935 : kind - [104, 18, 35, 14, 22, 15]
# Word # 936 : production - [33, 5, 8, 5, 6, 9]
# Word # 937 : funnier - [7, 1, 4, 1, 1, 0]
# Word # 938 : release - [25, 3, 8, 5, 2, 7]
# Word # 939 : outtake - [2, 1, 1, 0, 0, 0]
# Word # 940 : theatrically - [1, 0, 1, 0, 0, 0]
# Word # 941 : use - [71, 7, 16, 13, 21, 14]
# Word # 942 : bonus - [2, 0, 1, 0, 1, 0]
# Word # 943 : dvd - [7, 1, 4, 1, 0, 1]
# Word # 944 : tolstoy - [1, 0, 1, 0, 0, 0]
# Word # 945 : groupie - [1, 0, 1, 0, 0, 0]
# Word # 946 : daughter - [7, 1, 3, 1, 1, 1]
# Word # 947 : danang - [2, 0, 1, 0, 1, 0]
# Word # 948 : reveals - [16, 1, 1, 3, 4, 7]
# Word # 949 : effort - [53, 7, 14, 8, 20, 4]
# Word # 950 : toward - [15, 3, 8, 0, 3, 1]
# Word # 951 : closure - [2, 0, 1, 1, 0, 0]
# Word # 952 : open - [27, 5, 6, 8, 6, 2]
# Word # 953 : wound - [6, 1, 1, 0, 4, 0]
# Word # 954 : weirdly - [5, 0, 1, 0, 3, 1]
# Word # 955 : unpredictable - [7, 0, 0, 0, 2, 5]
# Word # 956 : piece - [79, 11, 13, 8, 25, 22]
# Word # 957 : intoxicate - [9, 0, 0, 0, 3, 6]
# Word # 958 : although - [41, 1, 13, 7, 19, 1]
# Word # 959 : fairly - [26, 1, 7, 3, 12, 3]
# Word # 960 : fresh - [33, 4, 7, 4, 10, 8]
# Word # 961 : grow - [28, 2, 10, 5, 9, 2]
# Word # 962 : catholic - [4, 1, 1, 1, 1, 0]
# Word # 963 : really - [141, 23, 50, 24, 28, 16]
# Word # 964 : anything - [55, 14, 18, 7, 8, 8]
# Word # 965 : comprehension - [3, 2, 0, 0, 1, 0]
# Word # 966 : sleek - [2, 0, 1, 0, 1, 0]
# Word # 967 : arty - [5, 1, 2, 1, 1, 0]
# Word # 968 : poor - [17, 9, 3, 4, 1, 0]
# Word # 969 : edit - [21, 6, 9, 2, 2, 2]
# Word # 970 : bluescreen - [2, 1, 1, 0, 0, 0]
# Word # 971 : ultracheesy - [1, 1, 0, 0, 0, 0]
# Word # 972 : highlight - [6, 2, 0, 1, 2, 1]
# Word # 973 : radical - [5, 2, 2, 1, 0, 0]
# Word # 974 : chos - [5, 0, 0, 0, 3, 2]
# Word # 975 : face - [49, 4, 10, 7, 20, 8]
# Word # 976 : amaze - [11, 0, 1, 1, 3, 6]
# Word # 977 : slapstick - [14, 1, 6, 2, 5, 0]
# Word # 978 : instrument - [1, 0, 0, 0, 1, 0]
# Word # 979 : create - [57, 2, 14, 7, 17, 17]
# Word # 980 : scrapbook - [2, 0, 1, 0, 1, 0]
# Word # 981 : living - [5, 0, 0, 0, 3, 2]
# Word # 982 : mug - [7, 2, 3, 1, 1, 0]
# Word # 983 : shot - [48, 6, 14, 8, 10, 10]
# Word # 984 : frame - [22, 2, 6, 2, 7, 5]
# Word # 985 : completely - [36, 12, 8, 5, 6, 5]
# Word # 986 : miss - [40, 5, 21, 8, 2, 4]
# Word # 987 : initial - [5, 1, 2, 2, 0, 0]
# Word # 988 : strangeness - [4, 0, 1, 1, 2, 0]
# Word # 989 : inexorably - [1, 0, 0, 1, 0, 0]
# Word # 990 : rote - [7, 1, 4, 1, 1, 0]
# Word # 991 : sentimentality - [12, 0, 5, 4, 2, 1]
# Word # 992 : mystical - [2, 0, 0, 1, 1, 0]
# Word # 993 : tenderness - [3, 0, 0, 1, 1, 1]
# Word # 994 : become - [72, 7, 22, 21, 13, 9]
# Word # 995 : expedience - [2, 0, 0, 2, 0, 0]
# Word # 996 : brush - [3, 0, 0, 0, 2, 1]
# Word # 997 : humanity - [16, 1, 1, 3, 6, 5]
# Word # 998 : psycho - [4, 0, 0, 1, 3, 0]
# Word # 999 : without - [130, 16, 28, 24, 44, 18]
# Word # 1000 : hartley - [6, 1, 4, 0, 0, 1]
# Word # 1001 : monster - [24, 4, 10, 3, 4, 3]
# Word # 1002 : handle - [15, 0, 4, 2, 5, 4]
# Word # 1003 : cower - [2, 0, 0, 0, 1, 1]
# Word # 1004 : beg - [3, 2, 0, 0, 0, 1]
# Word # 1005 : foot - [7, 2, 2, 2, 0, 1]
# Word # 1006 : scruffy - [3, 1, 1, 0, 0, 1]
# Word # 1007 : giannini - [1, 0, 0, 0, 0, 1]
# Word # 1008 : madonna - [8, 1, 4, 1, 0, 2]
# Word # 1009 : since - [55, 8, 10, 11, 11, 15]
# Word # 1010 : abel - [2, 0, 0, 0, 0, 2]
# Word # 1011 : ferrara - [4, 0, 0, 0, 0, 4]
# Word # 1012 : beat - [17, 1, 3, 3, 6, 4]
# Word # 1013 : pulp - [6, 0, 1, 3, 1, 1]
# Word # 1014 : dangerous - [8, 0, 2, 1, 3, 2]
# Word # 1015 : clumsy - [9, 3, 3, 2, 1, 0]
# Word # 1016 : key - [9, 1, 3, 1, 2, 2]
# Word # 1017 : splash - [6, 2, 1, 0, 2, 1]
# Word # 1018 : eight - [13, 2, 3, 4, 2, 2]
# Word # 1019 : legged - [8, 0, 3, 2, 2, 1]
# Word # 1020 : freak - [11, 1, 4, 3, 2, 1]
# Word # 1021 : partly - [8, 2, 1, 3, 2, 0]
# Word # 1022 : homage - [11, 2, 4, 3, 2, 0]
# Word # 1023 : tarantula - [2, 0, 0, 1, 1, 0]
# Word # 1024 : low - [26, 10, 9, 1, 6, 0]
# Word # 1025 : budget - [13, 3, 4, 3, 3, 0]
# Word # 1026 : bmovie - [12, 1, 3, 3, 4, 1]
# Word # 1027 : sophomoric - [6, 2, 1, 1, 2, 0]
# Word # 1028 : romp - [10, 0, 1, 4, 3, 2]
# Word # 1029 : hellish - [2, 0, 1, 1, 0, 0]
# Word # 1030 : condition - [13, 2, 3, 2, 5, 1]
# Word # 1031 : errol - [2, 0, 1, 1, 0, 0]
# Word # 1032 : morris - [1, 0, 1, 0, 0, 0]
# Word # 1033 : focus - [18, 1, 6, 7, 2, 2]
# Word # 1034 : eccentricity - [2, 0, 1, 0, 1, 0]
# Word # 1035 : fail - [27, 6, 8, 7, 3, 3]
# Word # 1036 : oddball - [1, 0, 1, 0, 0, 0]
# Word # 1037 : nearfuture - [1, 0, 0, 0, 0, 1]
# Word # 1038 : america - [16, 0, 1, 2, 6, 7]
# Word # 1039 : scientific - [2, 1, 0, 1, 0, 0]
# Word # 1040 : law - [5, 1, 1, 2, 1, 0]
# Word # 1041 : discern - [4, 1, 0, 1, 1, 1]
# Word # 1042 : producer - [8, 2, 0, 2, 3, 1]
# Word # 1043 : heed - [1, 1, 0, 0, 0, 0]
# Word # 1044 : mediocre - [21, 4, 10, 6, 1, 0]
# Word # 1045 : drag - [25, 9, 10, 2, 4, 0]
# Word # 1046 : speed - [3, 2, 1, 0, 0, 0]
# Word # 1047 : explosion - [11, 1, 6, 4, 0, 0]
# Word # 1048 : fall - [48, 6, 20, 12, 6, 4]
# Word # 1049 : cool - [23, 0, 3, 5, 10, 5]
# Word # 1050 : never - [196, 19, 63, 40, 43, 31]
# Word # 1051 : aware - [3, 0, 0, 1, 1, 1]
# Word # 1052 : coolness - [1, 0, 0, 0, 1, 0]
# Word # 1053 : artist - [27, 0, 4, 6, 10, 7]
# Word # 1054 : tire - [15, 4, 8, 1, 2, 0]
# Word # 1055 : fight - [24, 1, 8, 3, 9, 3]
# Word # 1056 : weight - [12, 3, 7, 1, 1, 0]
# Word # 1057 : shoulder - [7, 0, 4, 0, 3, 0]
# Word # 1058 : form - [22, 0, 1, 3, 6, 12]
# Word # 1059 : stale - [14, 4, 8, 1, 1, 0]
# Word # 1060 : uninspired - [9, 1, 5, 2, 1, 0]
# Word # 1061 : cut - [35, 6, 6, 10, 11, 2]
# Word # 1062 : song - [17, 2, 3, 3, 8, 1]
# Word # 1063 : fully - [19, 0, 7, 5, 5, 2]
# Word # 1064 : example - [11, 1, 2, 1, 5, 2]
# Word # 1065 : lush - [6, 0, 2, 1, 3, 0]
# Word # 1066 : allenveloping - [1, 0, 0, 0, 1, 0]
# Word # 1067 : rhapsodizes - [1, 0, 0, 0, 1, 0]
# Word # 1068 : rare - [39, 1, 3, 5, 16, 14]
# Word # 1069 : capability - [3, 0, 0, 0, 3, 0]
# Word # 1070 : soothe - [2, 1, 0, 0, 1, 0]
# Word # 1071 : break - [29, 1, 9, 8, 10, 1]
# Word # 1072 : heart - [92, 1, 10, 12, 41, 28]
# Word # 1073 : single - [24, 8, 5, 5, 4, 2]
# Word # 1074 : stroke - [6, 0, 2, 0, 4, 0]
# Word # 1075 : eerily - [3, 0, 1, 0, 1, 1]
# Word # 1076 : accurate - [5, 0, 2, 1, 1, 1]
# Word # 1077 : depiction - [10, 0, 1, 1, 5, 3]
# Word # 1078 : depression - [3, 0, 1, 1, 1, 0]
# Word # 1079 : featurelength - [7, 0, 4, 2, 1, 0]
# Word # 1080 : wear - [21, 2, 12, 3, 3, 1]
# Word # 1081 : tryingly - [1, 0, 1, 0, 0, 0]
# Word # 1082 : uncluttered - [1, 0, 0, 0, 1, 0]
# Word # 1083 : gem - [12, 0, 0, 2, 6, 4]
# Word # 1084 : relay - [2, 0, 1, 0, 1, 0]
# Word # 1085 : universal - [14, 1, 1, 1, 3, 8]
# Word # 1086 : lecture - [4, 0, 2, 0, 1, 1]
# Word # 1087 : confrontation - [1, 0, 0, 0, 1, 0]
# Word # 1088 : scratch - [14, 1, 2, 1, 4, 6]
# Word # 1089 : hole - [17, 4, 9, 4, 0, 0]
# Word # 1090 : head - [36, 10, 10, 5, 8, 3]
# Word # 1091 : postcamp - [1, 0, 0, 0, 1, 0]
# Word # 1092 : oldtime - [1, 0, 0, 0, 1, 0]
# Word # 1093 : goodbad - [1, 0, 0, 0, 1, 0]
# Word # 1094 : perfectly - [26, 0, 0, 9, 8, 9]
# Word # 1095 : creaturefeature - [1, 0, 0, 1, 0, 0]
# Word # 1096 : cross - [15, 0, 5, 7, 1, 2]
# Word # 1097 : toxic - [1, 0, 0, 1, 0, 0]
# Word # 1098 : chemical - [1, 0, 0, 1, 0, 0]
# Word # 1099 : bunch - [11, 5, 1, 4, 0, 1]
# Word # 1100 : exotic - [6, 0, 0, 1, 4, 1]
# Word # 1101 : creature - [6, 0, 1, 1, 3, 1]
# Word # 1102 : around - [49, 10, 14, 10, 10, 5]
# Word # 1103 : scream - [13, 4, 6, 2, 1, 0]
# Word # 1104 : death - [37, 4, 12, 9, 10, 2]
# Word # 1105 : bet - [4, 0, 0, 2, 0, 2]
# Word # 1106 : convoluted - [1, 0, 0, 1, 0, 0]
# Word # 1107 : journey - [25, 1, 2, 3, 14, 5]
# Word # 1108 : turn - [93, 13, 23, 16, 26, 15]
# Word # 1109 : devolves - [4, 0, 3, 0, 1, 0]
# ...
# Word # 13544 : personable - [1, 0, 0, 0, 1, 0]
# Word # 13545 : ascension - [1, 0, 0, 1, 0, 0]
# Word # 13546 : unmotivated - [1, 1, 0, 0, 0, 0]
# Word # 13547 : inconclusive - [1, 1, 0, 0, 0, 0]
# Word # 13548 : zhang - [1, 0, 0, 0, 1, 0]
# Word # 13549 : ziyis - [1, 0, 0, 0, 1, 0]
# Word # 13550 : moving - [1, 0, 0, 0, 0, 1]
# Word # 13551 : englishman - [1, 0, 0, 0, 1, 0]
# Word # 13552 : mortality - [1, 0, 0, 0, 1, 0]
# Word # 13553 : affluence - [1, 0, 0, 0, 1, 0]
# Word # 13554 : openhearted - [1, 0, 0, 0, 0, 1]
# Word # 13555 : flog - [1, 1, 0, 0, 0, 0]
# Word # 13556 : sillylooking - [1, 0, 1, 0, 0, 0]
# Word # 13557 : morlocks - [1, 0, 1, 0, 0, 0]
# Word # 13558 : decadesspanning - [1, 0, 1, 0, 0, 0]
# Word # 13559 : socially - [1, 0, 1, 0, 0, 0]
# Word # 13560 : captivatingly - [1, 0, 0, 0, 1, 0]
# Word # 13561 : beattheclock - [1, 0, 0, 0, 1, 0]
# Word # 13562 : plaster - [1, 0, 1, 0, 0, 0]
# Word # 13563 : pseudointellectual - [1, 0, 1, 0, 0, 0]
# Word # 13564 : spill - [1, 1, 0, 0, 0, 0]
# Word # 13565 : projector - [1, 1, 0, 0, 0, 0]
# Word # 13566 : bespeaks - [1, 0, 1, 0, 0, 0]
# Word # 13567 : instilled - [1, 0, 0, 0, 1, 0]
# Word # 13568 : unsuccessfully - [1, 1, 0, 0, 0, 0]
# Word # 13569 : attempts - [1, 1, 0, 0, 0, 0]
# Word # 13570 : standoff - [1, 0, 0, 1, 0, 0]
# Word # 13571 : simulation - [1, 0, 1, 0, 0, 0]
# Word # 13572 : auschwitz - [1, 0, 1, 0, 0, 0]
# Word # 13573 : iibirkenau - [1, 0, 1, 0, 0, 0]
# Word # 13574 : tact - [1, 0, 0, 1, 0, 0]
# Word # 13575 : daunt - [1, 0, 0, 1, 0, 0]
# Word # 13576 : promotes - [1, 0, 0, 1, 0, 0]
# Word # 13577 : scattershot - [1, 0, 0, 1, 0, 0]
# Word # 13578 : terrorize - [1, 0, 0, 1, 0, 0]
# Word # 13579 : prozac - [1, 1, 0, 0, 0, 0]
# Word # 13580 : rampantly - [1, 1, 0, 0, 0, 0]
# Word # 13581 : unimpressively - [1, 1, 0, 0, 0, 0]
# Word # 13582 : fussy - [1, 1, 0, 0, 0, 0]
# Word # 13583 : scan - [1, 0, 0, 0, 0, 1]
# Word # 13584 : cheerfully - [1, 0, 0, 0, 1, 0]
# Word # 13585 : goggles - [1, 0, 0, 0, 1, 0]
# Word # 13586 : eyepopping - [2, 0, 0, 1, 1, 0]
# Word # 13587 : gregory - [1, 0, 1, 0, 0, 0]
# Word # 13588 : hinton - [1, 0, 1, 0, 0, 0]
# Word # 13589 : strongminded - [1, 0, 1, 0, 0, 0]
# Word # 13590 : viewpoint - [1, 0, 1, 0, 0, 0]
# Word # 13591 : brent - [1, 0, 0, 0, 0, 1]
# Word # 13592 : hanley - [1, 0, 0, 0, 0, 1]
# Word # 13593 : economics - [1, 0, 0, 0, 0, 1]
# Word # 13594 : fabulousness - [1, 0, 0, 0, 0, 1]
# Word # 13595 : egraveyard - [1, 0, 0, 0, 1, 0]
# Word # 13596 : chin - [1, 0, 0, 0, 1, 0]
# Word # 13597 : abagnales - [1, 0, 0, 1, 0, 0]
# Word # 13598 : ritters - [1, 0, 1, 0, 0, 0]
# Word # 13599 : nicky - [1, 0, 0, 1, 0, 0]
# Word # 13600 : jias - [1, 0, 0, 1, 0, 0]
# Word # 13601 : badboy - [1, 0, 0, 1, 0, 0]
# Word # 13602 : malleable - [1, 1, 0, 0, 0, 0]
# Word # 13603 : blatantly - [1, 0, 0, 0, 1, 0]
# Word # 13604 : preliminary - [1, 1, 0, 0, 0, 0]
# Word # 13605 : unturned - [1, 0, 1, 0, 0, 0]
# Word # 13606 : kidd - [1, 0, 0, 0, 1, 0]
# Word # 13607 : quaids - [1, 0, 0, 0, 1, 0]
# Word # 13608 : vainglorious - [1, 0, 0, 0, 1, 0]
# Word # 13609 : druggy - [2, 0, 1, 1, 0, 0]
# Word # 13610 : trancenoir - [1, 0, 0, 1, 0, 0]
# Word # 13611 : trumpedup - [1, 0, 0, 1, 0, 0]
# Word # 13612 : jake - [1, 0, 0, 0, 0, 1]
# Word # 13613 : parking - [1, 1, 0, 0, 0, 0]
# Word # 13614 : flounder - [2, 0, 1, 0, 1, 0]
# Word # 13615 : singercomposer - [1, 0, 0, 0, 1, 0]
# Word # 13616 : slew - [1, 0, 0, 0, 1, 0]
# Word # 13617 : intrusive - [1, 0, 0, 0, 1, 0]
# Word # 13618 : adept - [1, 0, 1, 0, 0, 0]
# Word # 13619 : prognosis - [1, 0, 1, 0, 0, 0]
# Word # 13620 : zeus - [1, 0, 1, 0, 0, 0]
# Word # 13621 : selfimportance - [1, 0, 0, 1, 0, 0]
# Word # 13622 : discretion - [1, 0, 0, 1, 0, 0]
# Word # 13623 : geddes - [1, 0, 0, 1, 0, 0]
# Word # 13624 : grisham - [1, 0, 0, 1, 0, 0]
# Word # 13625 : kincaid - [1, 0, 0, 1, 0, 0]
# Word # 13626 : steinis - [1, 0, 0, 0, 0, 1]
# Word # 13627 : wellformed - [1, 0, 0, 0, 0, 1]
# Word # 13628 : chardonnes - [1, 0, 0, 0, 1, 0]
# Word # 13629 : frances - [1, 0, 0, 0, 1, 0]
# Word # 13630 : unflattering - [1, 1, 0, 0, 0, 0]
# Word # 13631 : transvestite - [1, 1, 0, 0, 0, 0]
# Word # 13632 : ennuihobbled - [1, 0, 1, 0, 0, 0]
# Word # 13633 : conceptually - [1, 0, 0, 0, 1, 0]
# Word # 13634 : livingroom - [1, 0, 0, 0, 1, 0]
# Word # 13635 : fridas - [1, 0, 0, 1, 0, 0]
# Word # 13636 : underconfident - [1, 0, 0, 0, 1, 0]
# Word # 13637 : walken - [1, 0, 0, 0, 1, 0]
# Word # 13638 : cyndi - [1, 0, 0, 0, 1, 0]
# Word # 13639 : lauper - [1, 0, 0, 0, 1, 0]
# Word # 13640 : opportunist - [1, 0, 0, 0, 1, 0]
# Word # 13641 : papa - [1, 0, 0, 1, 0, 0]
# Word # 13642 : truetolife - [1, 0, 0, 0, 0, 1]
# Word # 13643 : unadorned - [1, 0, 0, 0, 0, 1]
# Word # 13644 : rural - [1, 0, 0, 0, 0, 1]
# Word # 13645 : hilary - [1, 0, 0, 0, 0, 1]
# Word # 13646 : birmingham - [1, 0, 0, 0, 0, 1]
# Word # 13647 : interlocked - [1, 0, 1, 0, 0, 0]
# Word # 13648 : misleading - [1, 0, 1, 0, 0, 0]
# Word # 13649 : unexplained - [1, 0, 1, 0, 0, 0]
# Word # 13650 : baboon - [1, 0, 1, 0, 0, 0]
# Word # 13651 : portraiture - [1, 0, 0, 0, 1, 0]
# Word # 13652 : tweener - [1, 1, 0, 0, 0, 0]
# Word # 13653 : sophistication - [1, 0, 1, 0, 0, 0]
# Word # 13654 : typically - [1, 0, 0, 1, 0, 0]
# Word # 13655 : selfmutilation - [1, 0, 0, 0, 0, 1]
# Word # 13656 : congrats - [1, 0, 0, 0, 0, 1]
# Word # 13657 : aggrandize - [1, 0, 0, 1, 0, 0]
# Word # 13658 : oozes - [1, 0, 0, 1, 0, 0]
# Word # 13659 : nosedive - [1, 0, 1, 0, 0, 0]
# Word # 13660 : inarticulate - [1, 0, 1, 0, 0, 0]
# Word # 13661 : mordant - [1, 0, 0, 0, 1, 0]
# Word # 13662 : catechism - [1, 0, 0, 1, 0, 0]
# Word # 13663 : affectingly - [1, 0, 0, 0, 1, 0]
# Word # 13664 : singerturned - [1, 0, 1, 0, 0, 0]
# Word # 13665 : coos - [1, 0, 0, 0, 1, 0]
# Word # 13666 : beseechingly - [1, 0, 0, 0, 1, 0]
# Word # 13667 : hellbent - [1, 0, 0, 0, 1, 0]
# Word # 13668 : imperious - [1, 0, 1, 0, 0, 0]
# Word # 13669 : katzenbergs - [1, 0, 1, 0, 0, 0]
# Word # 13670 : egypt - [1, 0, 1, 0, 0, 0]
# Word # 13671 : dehumanize - [1, 0, 0, 0, 1, 0]
# Word # 13672 : egodestroying - [1, 0, 0, 0, 1, 0]
# Word # 13673 : unemployment - [1, 0, 0, 0, 1, 0]
# Word # 13674 : backbone - [1, 0, 0, 0, 1, 0]
# Word # 13675 : dusty - [1, 0, 1, 0, 0, 0]
# Word # 13676 : leatherbound - [1, 0, 1, 0, 0, 0]
# Word # 13677 : jokester - [1, 0, 0, 0, 1, 0]
# Word # 13678 : satan - [1, 1, 0, 0, 0, 0]
# Word # 13679 : rd - [1, 1, 0, 0, 0, 0]
# Word # 13680 : caution - [1, 0, 0, 0, 1, 0]
# Word # 13681 : unrelieved - [1, 0, 0, 1, 0, 0]
# Word # 13682 : journalistically - [1, 1, 0, 0, 0, 0]
# Word # 13683 : lethally - [1, 1, 0, 0, 0, 0]
# Word # 13684 : sleaziness - [1, 1, 0, 0, 0, 0]
# Word # 13685 : spyaction - [1, 0, 0, 1, 0, 0]
# Word # 13686 : priggish - [1, 1, 0, 0, 0, 0]
# Word # 13687 : lethargically - [1, 1, 0, 0, 0, 0]
# Word # 13688 : renewal - [1, 1, 0, 0, 0, 0]
# Word # 13689 : regiment - [1, 0, 0, 1, 0, 0]
# Word # 13690 : loving - [1, 0, 0, 0, 0, 1]
# Word # 13691 : unforgivingly - [1, 0, 0, 0, 0, 1]
# Word # 13692 : eyeboggling - [1, 0, 0, 0, 1, 0]
# Word # 13693 : psychedelic - [1, 0, 0, 0, 1, 0]
# Word # 13694 : telanovela - [1, 0, 1, 0, 0, 0]
# Word # 13695 : highwattage - [1, 0, 0, 0, 0, 1]
# Word # 13696 : brainpower - [1, 0, 0, 0, 0, 1]
# Word # 13697 : unfakable - [1, 0, 0, 0, 0, 1]
# Word # 13698 : irans - [1, 0, 1, 0, 0, 0]
# Word # 13699 : electoral - [1, 0, 1, 0, 0, 0]
# Word # 13700 : broadcast - [1, 0, 1, 0, 0, 0]
# Word # 13701 : obstacles - [1, 0, 0, 1, 0, 0]
# Word # 13702 : merci - [1, 0, 0, 1, 0, 0]
# Word # 13703 : pour - [1, 0, 0, 1, 0, 0]
# Word # 13704 : cassel - [1, 0, 0, 0, 0, 1]
# Word # 13705 : vocalize - [1, 0, 0, 0, 0, 1]
# Word # 13706 : springbreak - [1, 0, 1, 0, 0, 0]
# Word # 13707 : sixtiesstyle - [1, 0, 0, 0, 1, 0]
# Word # 13708 : slickness - [1, 0, 0, 0, 1, 0]
# Word # 13709 : skilfully - [1, 0, 0, 0, 0, 1]
# Word # 13710 : aerial - [1, 0, 0, 0, 0, 1]
# Word # 13711 : kiltwearing - [1, 0, 0, 0, 1, 0]
# Word # 13712 : elie - [1, 0, 1, 0, 0, 0]
# Word # 13713 : cowrote - [1, 0, 1, 0, 0, 0]
# Word # 13714 : subjugate - [1, 0, 1, 0, 0, 0]
# Word # 13715 : tearjerking - [1, 0, 1, 0, 0, 0]
# Word # 13716 : doublepistoled - [1, 0, 1, 0, 0, 0]
# Word # 13717 : ballisticpyrotechnic - [1, 0, 1, 0, 0, 0]
# Word # 13718 : percentage - [1, 0, 1, 0, 0, 0]
# Word # 13719 : essay - [1, 0, 0, 0, 1, 0]
# Word # 13720 : specter - [1, 0, 0, 0, 1, 0]
# Word # 13721 : suicide - [1, 0, 0, 0, 1, 0]
# Word # 13722 : winged - [1, 0, 1, 0, 0, 0]
# Word # 13723 : assailant - [1, 0, 1, 0, 0, 0]
# Word # 13724 : evergreen - [1, 0, 0, 0, 1, 0]
# Word # 13725 : exuberant - [1, 0, 0, 0, 1, 0]
# Word # 13726 : disgracefully - [1, 0, 1, 0, 0, 0]
# Word # 13727 : scorchingly - [1, 0, 0, 1, 0, 0]
# Word # 13728 : intimidate - [1, 0, 1, 0, 0, 0]
# Word # 13729 : unhappiness - [1, 0, 0, 0, 1, 0]
# Word # 13730 : miserably - [1, 0, 0, 0, 1, 0]
# Word # 13731 : dreadfulness - [1, 0, 0, 0, 1, 0]
# Word # 13732 : comics - [1, 0, 0, 0, 0, 1]
# Word # 13733 : eroticize - [1, 1, 0, 0, 0, 0]
# Word # 13734 : glacially - [1, 0, 0, 1, 0, 0]
# Word # 13735 : iranianamerican - [1, 0, 0, 0, 1, 0]
# Word # 13736 : confuses - [1, 1, 0, 0, 0, 0]
# Word # 13737 : contort - [1, 1, 0, 0, 0, 0]
# Word # 13738 : actresses - [1, 1, 0, 0, 0, 0]
# Word # 13739 : sisterly - [1, 0, 0, 1, 0, 0]
# Word # 13740 : razorsided - [1, 0, 0, 1, 0, 0]
# Word # 13741 : globalizing - [1, 0, 0, 0, 1, 0]
# Word # 13742 : unclean - [1, 1, 0, 0, 0, 0]
# Word # 13743 : martinet - [1, 0, 0, 1, 0, 0]
# Word # 13744 : instructor - [1, 0, 0, 1, 0, 0]
# Word # 13745 : tormentor - [1, 0, 0, 1, 0, 0]
# Word # 13746 : unified - [1, 0, 1, 0, 0, 0]
# Word # 13747 : automatic - [1, 0, 0, 0, 1, 0]
# Word # 13748 : capitalism - [1, 0, 0, 0, 1, 0]
# Word # 13749 : laskers - [1, 0, 0, 0, 1, 0]
# Word # 13750 : byron - [1, 0, 0, 0, 1, 0]
# Word # 13751 : luther - [1, 0, 0, 0, 1, 0]
# Word # 13752 : satisfaction - [1, 0, 0, 0, 1, 0]
# Word # 13753 : angstridden - [1, 0, 1, 0, 0, 0]
# Word # 13754 : celebi - [1, 1, 0, 0, 0, 0]
# Word # 13755 : blasphemous - [1, 1, 0, 0, 0, 0]
# Word # 13756 : slain - [1, 0, 0, 1, 0, 0]
# Word # 13757 : taunt - [1, 0, 0, 1, 0, 0]
# Word # 13758 : lynchs - [1, 0, 0, 1, 0, 0]
# Word # 13759 : mulholland - [1, 0, 0, 1, 0, 0]
# Word # 13760 : harmlessly - [1, 0, 0, 0, 1, 0]
# Word # 13761 : popmusic - [1, 0, 1, 0, 0, 0]
# Word # 13762 : dogtag - [1, 0, 0, 0, 0, 1]
# Word # 13763 : badmovie - [1, 0, 1, 0, 0, 0]
# Word # 13764 : tighten - [1, 0, 1, 0, 0, 0]
# Word # 13765 : physician - [1, 0, 1, 0, 0, 0]
# Word # 13766 : shrivel - [1, 0, 1, 0, 0, 0]
# Word # 13767 : withholds - [1, 0, 1, 0, 0, 0]
# Word # 13768 : pellmell - [1, 0, 1, 0, 0, 0]
# Word # 13769 : welltimed - [1, 0, 1, 0, 0, 0]
# Word # 13770 : audaciousimpossible - [1, 0, 0, 0, 1, 0]
# Word # 13771 : disagreeable - [1, 0, 1, 0, 0, 0]
# Word # 13772 : blimp - [1, 0, 1, 0, 0, 0]
# Word # 13773 : grayish - [1, 1, 0, 0, 0, 0]
# Word # 13774 : lastminute - [2, 1, 1, 0, 0, 0]
# Word # 13775 : friends - [1, 0, 0, 0, 1, 0]
# Word # 13776 : moralcondundrum - [1, 0, 0, 0, 1, 0]
# Word # 13777 : chicagobased - [1, 0, 0, 0, 1, 0]
# Word # 13778 : overweight - [1, 0, 1, 0, 0, 0]
# Word # 13779 : fore - [1, 0, 0, 0, 1, 0]
# Word # 13780 : stillinestimable - [1, 0, 0, 0, 1, 0]
# Word # 13781 : shared - [1, 0, 0, 0, 1, 0]
# Word # 13782 : genrebusting - [1, 0, 1, 0, 0, 0]
# Word # 13783 : campaign - [1, 0, 0, 1, 0, 0]
# Word # 13784 : aloft - [1, 0, 0, 1, 0, 0]
# Word # 13785 : selfreferential - [1, 0, 0, 1, 0, 0]
# Word # 13786 : gondrys - [1, 0, 0, 0, 1, 0]
# Word # 13787 : snail - [1, 0, 1, 0, 0, 0]
# Word # 13788 : duvalls - [1, 0, 0, 0, 1, 0]
# Word # 13789 : throb - [1, 0, 0, 0, 1, 0]
# Word # 13790 : elderly - [1, 0, 0, 0, 1, 0]
# Word # 13791 : propensity - [1, 0, 0, 0, 1, 0]
# Word # 13792 : gellar - [1, 0, 0, 1, 0, 0]
# Word # 13793 : zoom - [1, 0, 0, 0, 1, 0]
# Word # 13794 : stillers - [1, 0, 0, 1, 0, 0]
# Word # 13795 : zoolander - [1, 0, 0, 1, 0, 0]
# Word # 13796 : secular - [1, 0, 0, 0, 1, 0]
# Word # 13797 : linear - [1, 0, 0, 0, 1, 0]
# Word # 13798 : makeupdeep - [1, 0, 0, 0, 1, 0]
# Word # 13799 : efficiency - [1, 0, 0, 0, 1, 0]
# Word # 13800 : markedly - [1, 1, 0, 0, 0, 0]
# Word # 13801 : inactive - [1, 1, 0, 0, 0, 0]
# Word # 13802 : conversational - [1, 1, 0, 0, 0, 0]
# Word # 13803 : bordering - [1, 1, 0, 0, 0, 0]
# Word # 13804 : confessional - [1, 1, 0, 0, 0, 0]
# Word # 13805 : uninitiated - [1, 0, 1, 0, 0, 0]
# Word # 13806 : romanek - [1, 0, 1, 0, 0, 0]
# Word # 13807 : cirulnick - [1, 0, 1, 0, 0, 0]
# Word # 13808 : novelist - [1, 0, 1, 0, 0, 0]
# Word # 13809 : thulani - [1, 0, 1, 0, 0, 0]
# Word # 13810 : nonchalantly - [1, 0, 0, 0, 0, 1]
# Word # 13811 : evenhandedness - [1, 0, 1, 0, 0, 0]
# Word # 13812 : rig - [1, 0, 1, 0, 0, 0]
# Word # 13813 : scenechewing - [1, 1, 0, 0, 0, 0]
# Word # 13814 : teethgnashing - [1, 1, 0, 0, 0, 0]
# Word # 13815 : actorliness - [1, 1, 0, 0, 0, 0]
# Word # 13816 : immersed - [1, 0, 0, 0, 0, 1]
# Word # 13817 : amused - [1, 0, 0, 0, 0, 1]
# Word # 13818 : captor - [1, 0, 0, 0, 0, 1]
# Word # 13819 : bondinspired - [1, 0, 0, 1, 0, 0]
# Word # 13820 : method - [1, 0, 0, 0, 0, 1]
# Word # 13821 : nolan - [1, 0, 0, 0, 0, 1]
# Word # 13822 : composure - [1, 0, 0, 0, 0, 1]
# Word # 13823 : gelati - [1, 0, 0, 0, 0, 1]
# Word # 13824 : battery - [1, 0, 0, 1, 0, 0]
# Word # 13825 : ensnare - [1, 0, 1, 0, 0, 0]
# Word # 13826 : dug - [1, 0, 1, 0, 0, 0]
# Word # 13827 : sputter - [1, 1, 0, 0, 0, 0]
# Word # 13828 : bladerunner - [1, 0, 0, 0, 1, 0]
# Word # 13829 : sci - [1, 0, 0, 0, 1, 0]
# Word # 13830 : fi - [1, 0, 0, 0, 1, 0]
# Word # 13831 : baker - [1, 0, 0, 0, 1, 0]
# Word # 13832 : boston - [1, 0, 0, 0, 1, 0]
# Word # 13833 : augustine - [1, 0, 0, 0, 1, 0]
# Word # 13834 : lurch - [1, 0, 1, 0, 0, 0]
# Word # 13835 : notveryfunny - [1, 0, 1, 0, 0, 0]
# Word # 13836 : dramatics - [1, 0, 1, 0, 0, 0]
# Word # 13837 : characterizes - [1, 0, 1, 0, 0, 0]
# Word # 13838 : abundantly - [1, 0, 0, 0, 1, 0]
# Word # 13839 : infantilized - [1, 0, 0, 0, 1, 0]
# Word # 13840 : ragbag - [1, 1, 0, 0, 0, 0]
# Word # 13841 : busby - [1, 0, 0, 0, 0, 1]
# Word # 13842 : berkeley - [1, 0, 0, 0, 0, 1]
# Word # 13843 : burntout - [1, 0, 0, 1, 0, 0]
# Word # 13844 : lifeembracing - [1, 0, 0, 0, 1, 0]
# Word # 13845 : progressive - [1, 0, 1, 0, 0, 0]
# Word # 13846 : provocateur - [1, 0, 1, 0, 0, 0]
# Word # 13847 : specialinterest - [1, 0, 1, 0, 0, 0]
# Word # 13848 : liberalism - [1, 0, 1, 0, 0, 0]
# Word # 13849 : thankless - [1, 0, 0, 1, 0, 0]
# Word # 13850 : ryoko - [1, 0, 0, 1, 0, 0]
# Word # 13851 : hirosue - [1, 0, 0, 1, 0, 0]
# Word # 13852 : culmination - [1, 0, 0, 1, 0, 0]
# Word # 13853 : pubescent - [1, 1, 0, 0, 0, 0]
# Word # 13854 : scandalous - [1, 1, 0, 0, 0, 0]
# Word # 13855 : highstrung - [1, 1, 0, 0, 0, 0]
# Word # 13856 : populates - [1, 0, 0, 0, 0, 1]
# Word # 13857 : dislocation - [1, 0, 0, 0, 1, 0]
# Word # 13858 : maladjusted - [1, 0, 0, 0, 1, 0]
# Word # 13859 : narcotize - [1, 0, 0, 0, 1, 0]
# Word # 13860 : pax - [1, 1, 0, 0, 0, 0]
# Word # 13861 : overtake - [1, 0, 0, 0, 1, 0]
# Word # 13862 : dissection - [1, 0, 0, 1, 0, 0]
# Word # 13863 : inanity - [1, 0, 0, 1, 0, 0]
# Word # 13864 : gracious - [1, 0, 0, 0, 0, 1]
# Word # 13865 : conceivable - [1, 1, 0, 0, 0, 0]
# Word # 13866 : altman - [1, 0, 0, 0, 0, 1]
# Word # 13867 : taxi - [2, 0, 0, 0, 1, 1]
# Word # 13868 : driveresque - [1, 0, 0, 0, 0, 1]
# Word # 13869 : teeter - [1, 0, 0, 0, 0, 1]
# Word # 13870 : sanity - [1, 0, 0, 0, 0, 1]
# Word # 13871 : campbell - [1, 0, 0, 0, 1, 0]
# Word # 13872 : outlet - [1, 0, 0, 0, 1, 0]
# Word # 13873 : flickknife - [1, 0, 0, 0, 1, 0]
# Word # 13874 : diction - [1, 0, 0, 0, 1, 0]
# Word # 13875 : swanson - [1, 0, 0, 0, 1, 0]
# Word # 13876 : ghoulish - [1, 0, 0, 0, 1, 0]
# Word # 13877 : perpetually - [1, 0, 1, 0, 0, 0]
# Word # 13878 : hazy - [1, 0, 1, 0, 0, 0]
# Word # 13879 : astonishing - [1, 0, 0, 0, 1, 0]
# Word # 13880 : benchmark - [1, 0, 1, 0, 0, 0]
# Word # 13881 : lameness - [1, 0, 1, 0, 0, 0]
# Word # 13882 : periodperfect - [1, 0, 0, 0, 1, 0]
# Word # 13883 : indefinitely - [1, 0, 1, 0, 0, 0]
# Word # 13884 : smallbudget - [1, 0, 0, 0, 1, 0]
# Word # 13885 : underworld - [1, 0, 0, 0, 1, 0]
# Word # 13886 : ganginfested - [1, 0, 0, 1, 0, 0]
# Word # 13887 : eastvs - [1, 0, 0, 1, 0, 0]
# Word # 13888 : servicable - [1, 0, 0, 0, 1, 0]
# Word # 13889 : goldie - [1, 0, 1, 0, 0, 0]
# Word # 13890 : laughingly - [1, 0, 0, 0, 1, 0]
# Word # 13891 : herrmann - [1, 0, 0, 1, 0, 0]
# Word # 13892 : avuncular - [1, 0, 0, 1, 0, 0]
# Word # 13893 : chortle - [1, 0, 0, 1, 0, 0]

# %%
df2 = df

# %%
df2
# Out:
#       PhraseId  SentenceId                                             Phrase  \
# 0            1           1  series escapades demonstrating adage good goos...
# 1           64           2  quiet introspective entertaining independent w...
# 2           82           3  even fan ismail merchant work suspect would ha...
# 3          117           4  positively thrill combination ethnography intr...
# 4          157           5  aggressive selfglorification manipulative whit...
# ...        ...         ...                                                ...
# 8524    155985        8540           either willing go claustrophobic concept
# 8525    155998        8541  despite annoyance capable clayburgh tambor rea...
# 8526    156022        8542  lrb try rrb parody genre already joke united s...
# 8527    156032        8543         movie downfall substitute plot personality
# 8528    156040        8544  film darkly atmospheric herrmann quietly sugge...
#
#       Sentiment
# 0             1
# 1             4
# 2             1
# 3             3
# 4             1
# ...         ...
# 8524          2
# 8525          2
# 8526          1
# 8527          1
# 8528          2
#
# [8529 rows x 4 columns]

# %%
def uniqueWords(df):
    list_of_words = ['SentenceId', 'Phrase', 'Sentiment']
    df_length = len(df.index)
    for index,row in df.iterrows():
        for i in row['Phrase'].split():
            if i not in list_of_words:
                list_of_words.append(i)
    ndf = pd.DataFrame(columns = list_of_words)
    ndf[len(ndf.index)] = np.zeros(df_length)
    return ndf

# %%
df3 = uniqueWords(df2)
df3
# Out:
#      SentenceId Phrase Sentiment series escapades demonstrating adage good  \
# 0           NaN    NaN       NaN    NaN       NaN           NaN   NaN  NaN
# 1           NaN    NaN       NaN    NaN       NaN           NaN   NaN  NaN
# 2           NaN    NaN       NaN    NaN       NaN           NaN   NaN  NaN
# 3           NaN    NaN       NaN    NaN       NaN           NaN   NaN  NaN
# 4           NaN    NaN       NaN    NaN       NaN           NaN   NaN  NaN
# ...         ...    ...       ...    ...       ...           ...   ...  ...
# 8524        NaN    NaN       NaN    NaN       NaN           NaN   NaN  NaN
# 8525        NaN    NaN       NaN    NaN       NaN           NaN   NaN  NaN
# 8526        NaN    NaN       NaN    NaN       NaN           NaN   NaN  NaN
# 8527        NaN    NaN       NaN    NaN       NaN           NaN   NaN  NaN
# 8528        NaN    NaN       NaN    NaN       NaN           NaN   NaN  NaN
#
#      goose also  ... underworld ganginfested eastvs servicable goldie  \
# 0      NaN  NaN  ...        NaN          NaN    NaN        NaN    NaN
# 1      NaN  NaN  ...        NaN          NaN    NaN        NaN    NaN
# 2      NaN  NaN  ...        NaN          NaN    NaN        NaN    NaN
# 3      NaN  NaN  ...        NaN          NaN    NaN        NaN    NaN
# 4      NaN  NaN  ...        NaN          NaN    NaN        NaN    NaN
# ...    ...  ...  ...        ...          ...    ...        ...    ...
# 8524   NaN  NaN  ...        NaN          NaN    NaN        NaN    NaN
# 8525   NaN  NaN  ...        NaN          NaN    NaN        NaN    NaN
# 8526   NaN  NaN  ...        NaN          NaN    NaN        NaN    NaN
# 8527   NaN  NaN  ...        NaN          NaN    NaN        NaN    NaN
# 8528   NaN  NaN  ...        NaN          NaN    NaN        NaN    NaN
#
#      laughingly herrmann avuncular chortle    0
# 0           NaN      NaN       NaN     NaN  0.0
# 1           NaN      NaN       NaN     NaN  0.0
# 2           NaN      NaN       NaN     NaN  0.0
# 3           NaN      NaN       NaN     NaN  0.0
# 4           NaN      NaN       NaN     NaN  0.0
# ...         ...      ...       ...     ...  ...
# 8524        NaN      NaN       NaN     NaN  0.0
# 8525        NaN      NaN       NaN     NaN  0.0
# 8526        NaN      NaN       NaN     NaN  0.0
# 8527        NaN      NaN       NaN     NaN  0.0
# 8528        NaN      NaN       NaN     NaN  0.0
#
# [8529 rows x 14116 columns]
